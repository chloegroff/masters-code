# %% [markdown]
# # UNET SEGMENTATION

# %%
## Imports
import os
import sys
import random
from glob import glob as glob
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import matplotlib
import matplotlib.image as Image
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split

tf.config.run_functions_eagerly(True)

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %% [markdown]
# ## Hyperparameters

# %%
dim = 224

# get image and mask files
image_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data_1plus\*_i*')
mask_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data_1plus\*_s*')

# splits into test and training datasets
train_imgs, test_imgs, train_masks, test_masks = train_test_split(image_files, mask_files, test_size = 0.33, random_state= 123)

print(len(train_imgs))

batch_size = 32

count = 0
ratios = None
# Out:
# 99

# %% [markdown]
# ## Data Generator

# %%
class DataGen(keras.utils.Sequence):
    def __init__(self, image_files, mask_files,  batch_size, hls = False):
        self.img_files = image_files
        self.mask_files = mask_files
        self.batch_size = batch_size
        self.num_files = len(image_files)

        self.hls = hls

        self.current_ratios = None

    def ratio_Imgs(self, masks):
        rs = []
        for i in masks:
            i = np.reshape(i, (dim, dim))

            r = sum(i > 0.5)/ dim **2

            rs.append(r)
        
        self.current_ratios = np.array(rs)
        global ratios
        ratios = self.current_ratios


    def __getitem__(self, index):
        'Returns batch of images and labels'

        this_batch = self.batch_size
        # Changes batch size for final batch (no data missed)
        if(index+1)*self.batch_size > self.num_files:
            this_batch = self.num_files - index*self.batch_size
        
        # sets limits for batch
        start = index*self.batch_size
        stop = start + this_batch

        # takes images and masks files within batch
        img_batch = self.img_files[start : stop]
        mask_batch = self.mask_files[start : stop]

        images = []
        masks  = []
        
        # loads images and files and adds them to list
        for i, (img_file, mask_file) in enumerate(zip(img_batch,mask_batch)):
            # Normalises
            img = cv2.imread(img_file) 
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            if self.hls:
                img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
            
            img = img / 255

            mask = cv2.imread(mask_file, 0) / 255
            mask = np.array(mask, dtype=np.float32)
            mask = np.reshape(mask, (mask.shape[0], mask.shape[1], 1))
            images.append(img)
            masks.append(mask)
            
        images = np.array(images)
        #image = np.reshape(image, (batch_size, 256, 256, 1))
        masks  = np.array(masks)
        
        self.ratio_Imgs(masks)

        return images, masks
    
    def on_epoch_end(self):
        global count
        count = 0
    
    def __len__(self):
        'Returns Number of batches'
        return int(np.ceil(self.num_files // self.batch_size))

# %%
# data loader obj is created with training images and masks
gen = DataGen(image_files=train_imgs, mask_files=train_masks, batch_size=batch_size)
x, y = gen.__getitem__(0)
print(x.shape, y.shape)
# Out:
# (32, 224, 224, 3) (32, 224, 224, 1)

# %%
r = random.randint(0, len(x)-1)

fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(1, 2, 1)
ax.imshow(x[r])
ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(y[r], (dim, dim)), cmap="gray")

# %% [markdown]
# ## Different Convolutional Blocks

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %% [markdown]
# ## UNet Model

# %%
def UNet(image_size):
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    bn = bottleneck(p4, f[4])
    
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(1, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %% [markdown]
# ## Loss Function

# %%
#from keras import saving

# @keras.saving.register_keras_serializable()
def weighted_bincrossentropy(true, pred):
    """
    Calculates weighted binary cross entropy. The weights are fixed.
        
    This can be useful for unbalanced catagories.
    
    Adjust the weights here depending on what is required.
    
    For example if there are 10x as many positive classes as negative classes,
        if you adjust weight_zero = 1.0, weight_one = 0.1, then false positives 
        will be penalize 10 times as much as false negatives.
    """
    # y = keras.backend.flatten(true)
    # r = np.max(((keras.backend.sum(y).numpy()/dim**2)**3, 1e-8))
    # calculate the binary cross entropy
    bin_crossentropy = keras.backend.binary_crossentropy(true, pred)
    
    # apply the weights
    weights = true * np.log(13) + (1. - true) * 0.5
    weighted_bin_crossentropy = weights * bin_crossentropy 

    return keras.backend.mean(weighted_bin_crossentropy)

# @keras.saving.register_keras_serializable()
def mean_iou_loss(y_true, y_pred):

    pred_sum = keras.backend.sum(y_pred)
    gt_sum = keras.backend.sum(y_true)
    intersection = keras.backend.sum(tf.math.multiply(y_true,y_pred))
    
    union = pred_sum + gt_sum - intersection

    iou = intersection/union
    return 1 - iou

# @keras.saving.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1):
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)
    intersection = keras.backend.sum(y_true * y_pred, axis=[1,2,3])
    union = keras.backend.sum(y_true, axis=[1,2,3]) + keras.backend.sum(y_pred, axis=[1,2,3])
    return keras.backend.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# @keras.saving.register_keras_serializable()
def dice_loss(in_gt, in_pred):
    return 1 - dice_coef(in_gt, in_pred)

# @keras.saving.register_keras_serializable()
def dice_p_bce(in_gt, in_pred):
    """combine DICE and BCE"""
    # 0.01*keras.losses.binary_crossentropy(in_gt, in_pred)
    return 0.01*weighted_bincrossentropy(in_gt, in_pred) + (1- dice_coef(in_gt, in_pred))

# @keras.saving.register_keras_serializable()
def true_positive_rate(y_true, y_pred):
    return keras.backend.sum(keras.backend.flatten(y_true)*keras.backend.flatten(keras.backend.round(y_pred)))/keras.backend.sum(y_true)

# @keras.saving.register_keras_serializable()
def dice_mean_iou(in_gt, in_pred):
    return (dice_loss(in_gt, in_pred) + mean_iou_loss(in_gt, in_pred)) / 2

# %%
model = UNet(dim)
# learning_rate = learning_rate=0.0001
learning_rate = 0.0001
opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# opt = tf.keras.optimizers.SGD(learning_rate = 0.00001)
# model.compile(optimizer = opt, loss=weighted_bincrossentropy, metrics=["acc"])
cce = keras.losses.CategoricalFocalCrossentropy()

use_loss = dice_mean_iou
print(use_loss.__name__)
model.compile(optimizer = opt, loss=use_loss, metrics=[dice_coef, 'binary_accuracy', dice_p_bce, dice_loss, true_positive_rate, weighted_bincrossentropy])
model.summary()
# Out:
# dice_mean_iou
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 224, 224,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 224, 224,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 112, 112,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 112, 112,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 112, 112,  │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 56, 56,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 28, 28,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 14, 14,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 14, 14,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 14, 14,    │    590,080 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 28, 28,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 28, 28,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │    147,584 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 56, 56,    │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 56, 56,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 56, 56,    │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 56, 56,    │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 112, 112,  │          0 │ conv2d_13[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 112, 112,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 112, 112,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 112, 112,  │      9,248 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 224, 224,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 224, 224,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 224, 224,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 224, 224,  │      2,320 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 224, 224,  │         17 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,625 (7.49 MB)
#  Trainable params: 1,962,625 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the model

# %%
train_gen = DataGen(train_imgs, train_masks, batch_size= batch_size, hls = False)
valid_gen = DataGen(test_imgs, test_masks, batch_size=batch_size, hls = False)

from sklearn.utils import class_weight
x, y = train_gen.__getitem__(5)

w1s = []
w2s = []
for i in y:
    i = np.reshape(i, (dim,dim))
    if np.sum(i) != 0:
        w1s.append(dim**2/(2 * np.sum(i)) )
        w2s.append(dim**2/(2 * (dim**2 - sum(i))))

print(np.mean(w1s), np.mean(w2s))


rs = []
for i in range(len(train_gen)):
    _, masks = train_gen.__getitem__(i)

    for j in masks:
        j = np.reshape(j, (dim,dim))
        r = sum(j > 0.5) / dim**2
        rs.append(r)

r = np.mean(rs)
print(r)
# Out:
# nan nan
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 0.00012880164054670417

# %%
model_num = 10

# %%
history = model.fit(train_gen, batch_size=batch_size, epochs = 500, validation_data= valid_gen)
# Out:
# Epoch 1/1000
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9439 - dice_coef: 0.0528 - dice_loss: 0.9472 - dice_p_bce: 0.9510 - loss: 0.9598 - true_positive_rate: 0.0573 - weighted_bincrossentropy: 0.3824 - val_binary_accuracy: 0.9547 - val_dice_coef: 0.0498 - val_dice_loss: 0.9502 - val_dice_p_bce: 0.9539 - val_loss: 0.9619 - val_true_positive_rate: 0.0139 - val_weighted_bincrossentropy: 0.3769
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9551 - dice_coef: 0.0531 - dice_loss: 0.9469 - dice_p_bce: 0.9507 - loss: 0.9596 - true_positive_rate: 0.0113 - weighted_bincrossentropy: 0.3780 - val_binary_accuracy: 0.9597 - val_dice_coef: 0.0501 - val_dice_loss: 0.9499 - val_dice_p_bce: 0.9536 - val_loss: 0.9617 - val_true_positive_rate: 0.0034 - val_weighted_bincrossentropy: 0.3727
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - binary_accuracy: 0.9585 - dice_coef: 0.0540 - dice_loss: 0.9460 - dice_p_bce: 0.9497 - loss: 0.9589 - true_positive_rate: 0.0038 - weighted_bincrossentropy: 0.3746 - val_binary_accuracy: 0.9641 - val_dice_coef: 0.0503 - val_dice_loss: 0.9497 - val_dice_p_bce: 0.9534 - val_loss: 0.9616 - val_true_positive_rate: 0.0040 - val_weighted_bincrossentropy: 0.3702
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9623 - dice_coef: 0.0554 - dice_loss: 0.9446 - dice_p_bce: 0.9483 - loss: 0.9578 - true_positive_rate: 0.0046 - weighted_bincrossentropy: 0.3731 - val_binary_accuracy: 0.9683 - val_dice_coef: 0.0505 - val_dice_loss: 0.9495 - val_dice_p_bce: 0.9532 - val_loss: 0.9614 - val_true_positive_rate: 0.0071 - val_weighted_bincrossentropy: 0.3674
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9661 - dice_coef: 0.0557 - dice_loss: 0.9443 - dice_p_bce: 0.9480 - loss: 0.9576 - true_positive_rate: 0.0076 - weighted_bincrossentropy: 0.3702 - val_binary_accuracy: 0.9689 - val_dice_coef: 0.0507 - val_dice_loss: 0.9493 - val_dice_p_bce: 0.9529 - val_loss: 0.9612 - val_true_positive_rate: 0.0156 - val_weighted_bincrossentropy: 0.3641
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9675 - dice_coef: 0.0545 - dice_loss: 0.9455 - dice_p_bce: 0.9491 - loss: 0.9585 - true_positive_rate: 0.0188 - weighted_bincrossentropy: 0.3652 - val_binary_accuracy: 0.9694 - val_dice_coef: 0.0511 - val_dice_loss: 0.9489 - val_dice_p_bce: 0.9525 - val_loss: 0.9609 - val_true_positive_rate: 0.0465 - val_weighted_bincrossentropy: 0.3600
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9669 - dice_coef: 0.0559 - dice_loss: 0.9441 - dice_p_bce: 0.9477 - loss: 0.9574 - true_positive_rate: 0.0679 - weighted_bincrossentropy: 0.3618 - val_binary_accuracy: 0.9599 - val_dice_coef: 0.0517 - val_dice_loss: 0.9483 - val_dice_p_bce: 0.9519 - val_loss: 0.9605 - val_true_positive_rate: 0.1855 - val_weighted_bincrossentropy: 0.3555
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9485 - dice_coef: 0.0574 - dice_loss: 0.9426 - dice_p_bce: 0.9462 - loss: 0.9562 - true_positive_rate: 0.2314 - weighted_bincrossentropy: 0.3577 - val_binary_accuracy: 0.8945 - val_dice_coef: 0.0525 - val_dice_loss: 0.9475 - val_dice_p_bce: 0.9509 - val_loss: 0.9598 - val_true_positive_rate: 0.4460 - val_weighted_bincrossentropy: 0.3482
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8882 - dice_coef: 0.0568 - dice_loss: 0.9432 - dice_p_bce: 0.9466 - loss: 0.9567 - true_positive_rate: 0.5110 - weighted_bincrossentropy: 0.3481 - val_binary_accuracy: 0.8486 - val_dice_coef: 0.0545 - val_dice_loss: 0.9455 - val_dice_p_bce: 0.9489 - val_loss: 0.9583 - val_true_positive_rate: 0.6627 - val_weighted_bincrossentropy: 0.3385
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8639 - dice_coef: 0.0598 - dice_loss: 0.9402 - dice_p_bce: 0.9436 - loss: 0.9544 - true_positive_rate: 0.6596 - weighted_bincrossentropy: 0.3343 - val_binary_accuracy: 0.8014 - val_dice_coef: 0.0585 - val_dice_loss: 0.9415 - val_dice_p_bce: 0.9449 - val_loss: 0.9552 - val_true_positive_rate: 0.8300 - val_weighted_bincrossentropy: 0.3313
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8373 - dice_coef: 0.0651 - dice_loss: 0.9349 - dice_p_bce: 0.9381 - loss: 0.9502 - true_positive_rate: 0.7518 - weighted_bincrossentropy: 0.3165 - val_binary_accuracy: 0.8094 - val_dice_coef: 0.0669 - val_dice_loss: 0.9331 - val_dice_p_bce: 0.9361 - val_loss: 0.9486 - val_true_positive_rate: 0.7919 - val_weighted_bincrossentropy: 0.2987
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8381 - dice_coef: 0.0769 - dice_loss: 0.9231 - dice_p_bce: 0.9259 - loss: 0.9409 - true_positive_rate: 0.7370 - weighted_bincrossentropy: 0.2783 - val_binary_accuracy: 0.8291 - val_dice_coef: 0.0861 - val_dice_loss: 0.9139 - val_dice_p_bce: 0.9163 - val_loss: 0.9332 - val_true_positive_rate: 0.7303 - val_weighted_bincrossentropy: 0.2457
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8475 - dice_coef: 0.1030 - dice_loss: 0.8970 - dice_p_bce: 0.8993 - loss: 0.9200 - true_positive_rate: 0.6438 - weighted_bincrossentropy: 0.2331 - val_binary_accuracy: 0.8557 - val_dice_coef: 0.1186 - val_dice_loss: 0.8814 - val_dice_p_bce: 0.8835 - val_loss: 0.9065 - val_true_positive_rate: 0.6341 - val_weighted_bincrossentropy: 0.2087
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8585 - dice_coef: 0.1441 - dice_loss: 0.8559 - dice_p_bce: 0.8581 - loss: 0.8867 - true_positive_rate: 0.6450 - weighted_bincrossentropy: 0.2196 - val_binary_accuracy: 0.8933 - val_dice_coef: 0.1464 - val_dice_loss: 0.8536 - val_dice_p_bce: 0.8560 - val_loss: 0.8823 - val_true_positive_rate: 0.4680 - val_weighted_bincrossentropy: 0.2374
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8880 - dice_coef: 0.1805 - dice_loss: 0.8195 - dice_p_bce: 0.8223 - loss: 0.8562 - true_positive_rate: 0.5410 - weighted_bincrossentropy: 0.2810 - val_binary_accuracy: 0.7961 - val_dice_coef: 0.1511 - val_dice_loss: 0.8489 - val_dice_p_bce: 0.8547 - val_loss: 0.8804 - val_true_positive_rate: 0.7942 - val_weighted_bincrossentropy: 0.5727
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8649 - dice_coef: 0.1667 - dice_loss: 0.8333 - dice_p_bce: 0.8387 - loss: 0.8649 - true_positive_rate: 0.5677 - weighted_bincrossentropy: 0.5408 - val_binary_accuracy: 0.7556 - val_dice_coef: 0.1390 - val_dice_loss: 0.8610 - val_dice_p_bce: 0.8697 - val_loss: 0.8905 - val_true_positive_rate: 0.8270 - val_weighted_bincrossentropy: 0.8690
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8014 - dice_coef: 0.1747 - dice_loss: 0.8253 - dice_p_bce: 0.8331 - loss: 0.8634 - true_positive_rate: 0.7608 - weighted_bincrossentropy: 0.7803 - val_binary_accuracy: 0.9385 - val_dice_coef: 0.1412 - val_dice_loss: 0.8588 - val_dice_p_bce: 0.8646 - val_loss: 0.8816 - val_true_positive_rate: 0.2480 - val_weighted_bincrossentropy: 0.5800
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9209 - dice_coef: 0.1700 - dice_loss: 0.8300 - dice_p_bce: 0.8367 - loss: 0.8626 - true_positive_rate: 0.3341 - weighted_bincrossentropy: 0.6679 - val_binary_accuracy: 0.8568 - val_dice_coef: 0.1793 - val_dice_loss: 0.8207 - val_dice_p_bce: 0.8279 - val_loss: 0.8555 - val_true_positive_rate: 0.6726 - val_weighted_bincrossentropy: 0.7237
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8503 - dice_coef: 0.1971 - dice_loss: 0.8029 - dice_p_bce: 0.8110 - loss: 0.8443 - true_positive_rate: 0.6722 - weighted_bincrossentropy: 0.8147 - val_binary_accuracy: 0.8809 - val_dice_coef: 0.1802 - val_dice_loss: 0.8198 - val_dice_p_bce: 0.8266 - val_loss: 0.8537 - val_true_positive_rate: 0.5700 - val_weighted_bincrossentropy: 0.6897
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8979 - dice_coef: 0.2024 - dice_loss: 0.7976 - dice_p_bce: 0.8047 - loss: 0.8386 - true_positive_rate: 0.4984 - weighted_bincrossentropy: 0.7080 - val_binary_accuracy: 0.8938 - val_dice_coef: 0.1790 - val_dice_loss: 0.8210 - val_dice_p_bce: 0.8278 - val_loss: 0.8538 - val_true_positive_rate: 0.5119 - val_weighted_bincrossentropy: 0.6854
# Epoch 21/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8764 - dice_coef: 0.2056 - dice_loss: 0.7944 - dice_p_bce: 0.8023 - loss: 0.8378 - true_positive_rate: 0.5892 - weighted_bincrossentropy: 0.7911 - val_binary_accuracy: 0.8391 - val_dice_coef: 0.1772 - val_dice_loss: 0.8228 - val_dice_p_bce: 0.8318 - val_loss: 0.8574 - val_true_positive_rate: 0.7357 - val_weighted_bincrossentropy: 0.8967
# Epoch 22/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8632 - dice_coef: 0.2026 - dice_loss: 0.7974 - dice_p_bce: 0.8059 - loss: 0.8399 - true_positive_rate: 0.6513 - weighted_bincrossentropy: 0.8583 - val_binary_accuracy: 0.9066 - val_dice_coef: 0.1777 - val_dice_loss: 0.8223 - val_dice_p_bce: 0.8291 - val_loss: 0.8536 - val_true_positive_rate: 0.4594 - val_weighted_bincrossentropy: 0.6829
# Epoch 23/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9030 - dice_coef: 0.2096 - dice_loss: 0.7904 - dice_p_bce: 0.7977 - loss: 0.8330 - true_positive_rate: 0.4898 - weighted_bincrossentropy: 0.7297 - val_binary_accuracy: 0.8734 - val_dice_coef: 0.1871 - val_dice_loss: 0.8129 - val_dice_p_bce: 0.8206 - val_loss: 0.8478 - val_true_positive_rate: 0.6337 - val_weighted_bincrossentropy: 0.7722
# Epoch 24/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8702 - dice_coef: 0.2115 - dice_loss: 0.7885 - dice_p_bce: 0.7969 - loss: 0.8328 - true_positive_rate: 0.6428 - weighted_bincrossentropy: 0.8406 - val_binary_accuracy: 0.8823 - val_dice_coef: 0.1891 - val_dice_loss: 0.8109 - val_dice_p_bce: 0.8184 - val_loss: 0.8455 - val_true_positive_rate: 0.6024 - val_weighted_bincrossentropy: 0.7404
# Epoch 25/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8884 - dice_coef: 0.2126 - dice_loss: 0.7874 - dice_p_bce: 0.7953 - loss: 0.8299 - true_positive_rate: 0.5568 - weighted_bincrossentropy: 0.7890 - val_binary_accuracy: 0.9180 - val_dice_coef: 0.1787 - val_dice_loss: 0.8213 - val_dice_p_bce: 0.8277 - val_loss: 0.8492 - val_true_positive_rate: 0.4318 - val_weighted_bincrossentropy: 0.6463
# Epoch 26/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9142 - dice_coef: 0.2151 - dice_loss: 0.7849 - dice_p_bce: 0.7920 - loss: 0.8243 - true_positive_rate: 0.4680 - weighted_bincrossentropy: 0.7060 - val_binary_accuracy: 0.8700 - val_dice_coef: 0.1906 - val_dice_loss: 0.8094 - val_dice_p_bce: 0.8171 - val_loss: 0.8446 - val_true_positive_rate: 0.6668 - val_weighted_bincrossentropy: 0.7698
# Epoch 27/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8819 - dice_coef: 0.2219 - dice_loss: 0.7781 - dice_p_bce: 0.7858 - loss: 0.8224 - true_positive_rate: 0.6281 - weighted_bincrossentropy: 0.7702 - val_binary_accuracy: 0.9377 - val_dice_coef: 0.1774 - val_dice_loss: 0.8226 - val_dice_p_bce: 0.8285 - val_loss: 0.8445 - val_true_positive_rate: 0.3696 - val_weighted_bincrossentropy: 0.5907
# Epoch 28/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9352 - dice_coef: 0.2223 - dice_loss: 0.7777 - dice_p_bce: 0.7840 - loss: 0.8132 - true_positive_rate: 0.4054 - weighted_bincrossentropy: 0.6305 - val_binary_accuracy: 0.8533 - val_dice_coef: 0.1851 - val_dice_loss: 0.8149 - val_dice_p_bce: 0.8230 - val_loss: 0.8496 - val_true_positive_rate: 0.7212 - val_weighted_bincrossentropy: 0.8058
# Epoch 29/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8646 - dice_coef: 0.2159 - dice_loss: 0.7841 - dice_p_bce: 0.7920 - loss: 0.8285 - true_positive_rate: 0.6997 - weighted_bincrossentropy: 0.7986 - val_binary_accuracy: 0.9590 - val_dice_coef: 0.1466 - val_dice_loss: 0.8534 - val_dice_p_bce: 0.8593 - val_loss: 0.8565 - val_true_positive_rate: 0.2520 - val_weighted_bincrossentropy: 0.5866
# Epoch 30/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9355 - dice_coef: 0.2184 - dice_loss: 0.7816 - dice_p_bce: 0.7878 - loss: 0.8108 - true_positive_rate: 0.4167 - weighted_bincrossentropy: 0.6151 - val_binary_accuracy: 0.9012 - val_dice_coef: 0.2055 - val_dice_loss: 0.7945 - val_dice_p_bce: 0.8003 - val_loss: 0.8285 - val_true_positive_rate: 0.5961 - val_weighted_bincrossentropy: 0.5770
# Epoch 31/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9216 - dice_coef: 0.2347 - dice_loss: 0.7653 - dice_p_bce: 0.7711 - loss: 0.8056 - true_positive_rate: 0.5115 - weighted_bincrossentropy: 0.5885 - val_binary_accuracy: 0.8713 - val_dice_coef: 0.1903 - val_dice_loss: 0.8097 - val_dice_p_bce: 0.8161 - val_loss: 0.8424 - val_true_positive_rate: 0.6917 - val_weighted_bincrossentropy: 0.6464
# Epoch 32/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8466 - dice_coef: 0.2105 - dice_loss: 0.7895 - dice_p_bce: 0.7971 - loss: 0.8342 - true_positive_rate: 0.7457 - weighted_bincrossentropy: 0.7597 - val_binary_accuracy: 0.8840 - val_dice_coef: 0.1926 - val_dice_loss: 0.8074 - val_dice_p_bce: 0.8133 - val_loss: 0.8383 - val_true_positive_rate: 0.6607 - val_weighted_bincrossentropy: 0.5810
# Epoch 33/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9154 - dice_coef: 0.2266 - dice_loss: 0.7734 - dice_p_bce: 0.7793 - loss: 0.8100 - true_positive_rate: 0.5159 - weighted_bincrossentropy: 0.5897 - val_binary_accuracy: 0.8944 - val_dice_coef: 0.2055 - val_dice_loss: 0.7945 - val_dice_p_bce: 0.7998 - val_loss: 0.8278 - val_true_positive_rate: 0.6442 - val_weighted_bincrossentropy: 0.5237
# Epoch 34/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.8703 - dice_coef: 0.2227 - dice_loss: 0.7773 - dice_p_bce: 0.7836 - loss: 0.8201 - true_positive_rate: 0.6978 - weighted_bincrossentropy: 0.6315 - val_binary_accuracy: 0.8648 - val_dice_coef: 0.1940 - val_dice_loss: 0.8060 - val_dice_p_bce: 0.8118 - val_loss: 0.8415 - val_true_positive_rate: 0.7139 - val_weighted_bincrossentropy: 0.5764
# Epoch 35/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.8975 - dice_coef: 0.2382 - dice_loss: 0.7618 - dice_p_bce: 0.7673 - loss: 0.8048 - true_positive_rate: 0.6227 - weighted_bincrossentropy: 0.5461 - val_binary_accuracy: 0.9680 - val_dice_coef: 0.1515 - val_dice_loss: 0.8485 - val_dice_p_bce: 0.8539 - val_loss: 0.8464 - val_true_positive_rate: 0.2239 - val_weighted_bincrossentropy: 0.5378
# Epoch 36/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9496 - dice_coef: 0.2335 - dice_loss: 0.7665 - dice_p_bce: 0.7716 - loss: 0.7923 - true_positive_rate: 0.3902 - weighted_bincrossentropy: 0.5103 - val_binary_accuracy: 0.9281 - val_dice_coef: 0.2153 - val_dice_loss: 0.7847 - val_dice_p_bce: 0.7889 - val_loss: 0.8104 - val_true_positive_rate: 0.5453 - val_weighted_bincrossentropy: 0.4199
# Epoch 37/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9346 - dice_coef: 0.2594 - dice_loss: 0.7406 - dice_p_bce: 0.7451 - loss: 0.7824 - true_positive_rate: 0.5017 - weighted_bincrossentropy: 0.4474 - val_binary_accuracy: 0.9478 - val_dice_coef: 0.2187 - val_dice_loss: 0.7813 - val_dice_p_bce: 0.7852 - val_loss: 0.7993 - val_true_positive_rate: 0.4577 - val_weighted_bincrossentropy: 0.3972
# Epoch 38/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9380 - dice_coef: 0.2730 - dice_loss: 0.7270 - dice_p_bce: 0.7310 - loss: 0.7660 - true_positive_rate: 0.5279 - weighted_bincrossentropy: 0.4051 - val_binary_accuracy: 0.9626 - val_dice_coef: 0.2141 - val_dice_loss: 0.7859 - val_dice_p_bce: 0.7898 - val_loss: 0.7938 - val_true_positive_rate: 0.3765 - val_weighted_bincrossentropy: 0.3951
# Epoch 39/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9579 - dice_coef: 0.2722 - dice_loss: 0.7278 - dice_p_bce: 0.7319 - loss: 0.7617 - true_positive_rate: 0.3957 - weighted_bincrossentropy: 0.4180 - val_binary_accuracy: 0.9544 - val_dice_coef: 0.2371 - val_dice_loss: 0.7629 - val_dice_p_bce: 0.7662 - val_loss: 0.7804 - val_true_positive_rate: 0.4760 - val_weighted_bincrossentropy: 0.3366
# Epoch 40/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9538 - dice_coef: 0.2916 - dice_loss: 0.7084 - dice_p_bce: 0.7119 - loss: 0.7460 - true_positive_rate: 0.4788 - weighted_bincrossentropy: 0.3440 - val_binary_accuracy: 0.9578 - val_dice_coef: 0.2416 - val_dice_loss: 0.7584 - val_dice_p_bce: 0.7616 - val_loss: 0.7736 - val_true_positive_rate: 0.4733 - val_weighted_bincrossentropy: 0.3184
# Epoch 41/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9518 - dice_coef: 0.2986 - dice_loss: 0.7014 - dice_p_bce: 0.7045 - loss: 0.7398 - true_positive_rate: 0.5169 - weighted_bincrossentropy: 0.3097 - val_binary_accuracy: 0.9690 - val_dice_coef: 0.2375 - val_dice_loss: 0.7625 - val_dice_p_bce: 0.7659 - val_loss: 0.7709 - val_true_positive_rate: 0.3626 - val_weighted_bincrossentropy: 0.3470
# Epoch 42/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9628 - dice_coef: 0.3071 - dice_loss: 0.6929 - dice_p_bce: 0.6962 - loss: 0.7270 - true_positive_rate: 0.4408 - weighted_bincrossentropy: 0.3226 - val_binary_accuracy: 0.9607 - val_dice_coef: 0.2637 - val_dice_loss: 0.7363 - val_dice_p_bce: 0.7394 - val_loss: 0.7563 - val_true_positive_rate: 0.4780 - val_weighted_bincrossentropy: 0.3095
# Epoch 43/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9592 - dice_coef: 0.3178 - dice_loss: 0.6822 - dice_p_bce: 0.6853 - loss: 0.7203 - true_positive_rate: 0.4923 - weighted_bincrossentropy: 0.3116 - val_binary_accuracy: 0.9533 - val_dice_coef: 0.2648 - val_dice_loss: 0.7352 - val_dice_p_bce: 0.7383 - val_loss: 0.7571 - val_true_positive_rate: 0.5455 - val_weighted_bincrossentropy: 0.3069
# Epoch 44/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9567 - dice_coef: 0.3226 - dice_loss: 0.6774 - dice_p_bce: 0.6806 - loss: 0.7176 - true_positive_rate: 0.5194 - weighted_bincrossentropy: 0.3214 - val_binary_accuracy: 0.9442 - val_dice_coef: 0.2671 - val_dice_loss: 0.7329 - val_dice_p_bce: 0.7359 - val_loss: 0.7607 - val_true_positive_rate: 0.6086 - val_weighted_bincrossentropy: 0.2995
# Epoch 45/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9449 - dice_coef: 0.3113 - dice_loss: 0.6887 - dice_p_bce: 0.6918 - loss: 0.7307 - true_positive_rate: 0.6008 - weighted_bincrossentropy: 0.3071 - val_binary_accuracy: 0.9684 - val_dice_coef: 0.2804 - val_dice_loss: 0.7196 - val_dice_p_bce: 0.7230 - val_loss: 0.7299 - val_true_positive_rate: 0.4524 - val_weighted_bincrossentropy: 0.3398
# Epoch 46/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9571 - dice_coef: 0.3343 - dice_loss: 0.6657 - dice_p_bce: 0.6689 - loss: 0.7068 - true_positive_rate: 0.5301 - weighted_bincrossentropy: 0.3204 - val_binary_accuracy: 0.9728 - val_dice_coef: 0.2733 - val_dice_loss: 0.7267 - val_dice_p_bce: 0.7302 - val_loss: 0.7341 - val_true_positive_rate: 0.3864 - val_weighted_bincrossentropy: 0.3578
# Epoch 47/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9675 - dice_coef: 0.3430 - dice_loss: 0.6570 - dice_p_bce: 0.6602 - loss: 0.6919 - true_positive_rate: 0.4523 - weighted_bincrossentropy: 0.3201 - val_binary_accuracy: 0.9612 - val_dice_coef: 0.3061 - val_dice_loss: 0.6939 - val_dice_p_bce: 0.6966 - val_loss: 0.7202 - val_true_positive_rate: 0.5500 - val_weighted_bincrossentropy: 0.2667
# Epoch 48/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9602 - dice_coef: 0.3570 - dice_loss: 0.6430 - dice_p_bce: 0.6458 - loss: 0.6861 - true_positive_rate: 0.5408 - weighted_bincrossentropy: 0.2837 - val_binary_accuracy: 0.9723 - val_dice_coef: 0.3057 - val_dice_loss: 0.6943 - val_dice_p_bce: 0.6975 - val_loss: 0.7074 - val_true_positive_rate: 0.4449 - val_weighted_bincrossentropy: 0.3216
# Epoch 49/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9636 - dice_coef: 0.3619 - dice_loss: 0.6381 - dice_p_bce: 0.6411 - loss: 0.6783 - true_positive_rate: 0.5254 - weighted_bincrossentropy: 0.2941 - val_binary_accuracy: 0.9739 - val_dice_coef: 0.3044 - val_dice_loss: 0.6956 - val_dice_p_bce: 0.6989 - val_loss: 0.7054 - val_true_positive_rate: 0.4248 - val_weighted_bincrossentropy: 0.3332
# Epoch 50/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9688 - dice_coef: 0.3795 - dice_loss: 0.6205 - dice_p_bce: 0.6235 - loss: 0.6652 - true_positive_rate: 0.4817 - weighted_bincrossentropy: 0.3015 - val_binary_accuracy: 0.9615 - val_dice_coef: 0.3300 - val_dice_loss: 0.6700 - val_dice_p_bce: 0.6724 - val_loss: 0.6980 - val_true_positive_rate: 0.6001 - val_weighted_bincrossentropy: 0.2395
# Epoch 51/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9627 - dice_coef: 0.3828 - dice_loss: 0.6172 - dice_p_bce: 0.6199 - loss: 0.6622 - true_positive_rate: 0.5635 - weighted_bincrossentropy: 0.2659 - val_binary_accuracy: 0.9676 - val_dice_coef: 0.3446 - val_dice_loss: 0.6554 - val_dice_p_bce: 0.6578 - val_loss: 0.6804 - val_true_positive_rate: 0.5660 - val_weighted_bincrossentropy: 0.2386
# Epoch 52/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9632 - dice_coef: 0.4115 - dice_loss: 0.5885 - dice_p_bce: 0.5905 - loss: 0.6424 - true_positive_rate: 0.6205 - weighted_bincrossentropy: 0.2085 - val_binary_accuracy: 0.9748 - val_dice_coef: 0.3330 - val_dice_loss: 0.6670 - val_dice_p_bce: 0.6697 - val_loss: 0.6828 - val_true_positive_rate: 0.4548 - val_weighted_bincrossentropy: 0.2740
# Epoch 53/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9679 - dice_coef: 0.4079 - dice_loss: 0.5921 - dice_p_bce: 0.5944 - loss: 0.6378 - true_positive_rate: 0.5564 - weighted_bincrossentropy: 0.2251 - val_binary_accuracy: 0.9716 - val_dice_coef: 0.3650 - val_dice_loss: 0.6350 - val_dice_p_bce: 0.6372 - val_loss: 0.6608 - val_true_positive_rate: 0.5502 - val_weighted_bincrossentropy: 0.2184
# Epoch 54/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9701 - dice_coef: 0.4215 - dice_loss: 0.5785 - dice_p_bce: 0.5808 - loss: 0.6255 - true_positive_rate: 0.5488 - weighted_bincrossentropy: 0.2290 - val_binary_accuracy: 0.9659 - val_dice_coef: 0.3821 - val_dice_loss: 0.6179 - val_dice_p_bce: 0.6198 - val_loss: 0.6545 - val_true_positive_rate: 0.6387 - val_weighted_bincrossentropy: 0.1840
# Epoch 55/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9651 - dice_coef: 0.4406 - dice_loss: 0.5594 - dice_p_bce: 0.5611 - loss: 0.6166 - true_positive_rate: 0.6624 - weighted_bincrossentropy: 0.1763 - val_binary_accuracy: 0.9749 - val_dice_coef: 0.3821 - val_dice_loss: 0.6179 - val_dice_p_bce: 0.6201 - val_loss: 0.6430 - val_true_positive_rate: 0.5183 - val_weighted_bincrossentropy: 0.2219
# Epoch 56/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9695 - dice_coef: 0.4542 - dice_loss: 0.5458 - dice_p_bce: 0.5477 - loss: 0.6016 - true_positive_rate: 0.6142 - weighted_bincrossentropy: 0.1853 - val_binary_accuracy: 0.9753 - val_dice_coef: 0.4057 - val_dice_loss: 0.5943 - val_dice_p_bce: 0.5963 - val_loss: 0.6261 - val_true_positive_rate: 0.5442 - val_weighted_bincrossentropy: 0.1922
# Epoch 57/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9734 - dice_coef: 0.4719 - dice_loss: 0.5281 - dice_p_bce: 0.5299 - loss: 0.5829 - true_positive_rate: 0.5867 - weighted_bincrossentropy: 0.1761 - val_binary_accuracy: 0.9650 - val_dice_coef: 0.4250 - val_dice_loss: 0.5750 - val_dice_p_bce: 0.5763 - val_loss: 0.6244 - val_true_positive_rate: 0.7229 - val_weighted_bincrossentropy: 0.1361
# Epoch 58/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9674 - dice_coef: 0.4714 - dice_loss: 0.5286 - dice_p_bce: 0.5301 - loss: 0.5886 - true_positive_rate: 0.6863 - weighted_bincrossentropy: 0.1505 - val_binary_accuracy: 0.9715 - val_dice_coef: 0.4521 - val_dice_loss: 0.5479 - val_dice_p_bce: 0.5493 - val_loss: 0.5950 - val_true_positive_rate: 0.6737 - val_weighted_bincrossentropy: 0.1412
# Epoch 59/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9694 - dice_coef: 0.4940 - dice_loss: 0.5060 - dice_p_bce: 0.5075 - loss: 0.5682 - true_positive_rate: 0.6863 - weighted_bincrossentropy: 0.1426 - val_binary_accuracy: 0.9767 - val_dice_coef: 0.4545 - val_dice_loss: 0.5455 - val_dice_p_bce: 0.5472 - val_loss: 0.5872 - val_true_positive_rate: 0.5769 - val_weighted_bincrossentropy: 0.1620
# Epoch 60/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9733 - dice_coef: 0.5104 - dice_loss: 0.4896 - dice_p_bce: 0.4910 - loss: 0.5518 - true_positive_rate: 0.6585 - weighted_bincrossentropy: 0.1456 - val_binary_accuracy: 0.9750 - val_dice_coef: 0.4720 - val_dice_loss: 0.5280 - val_dice_p_bce: 0.5296 - val_loss: 0.5714 - val_true_positive_rate: 0.6386 - val_weighted_bincrossentropy: 0.1646
# Epoch 61/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9729 - dice_coef: 0.5215 - dice_loss: 0.4785 - dice_p_bce: 0.4800 - loss: 0.5412 - true_positive_rate: 0.6784 - weighted_bincrossentropy: 0.1496 - val_binary_accuracy: 0.9782 - val_dice_coef: 0.4722 - val_dice_loss: 0.5278 - val_dice_p_bce: 0.5294 - val_loss: 0.5728 - val_true_positive_rate: 0.5629 - val_weighted_bincrossentropy: 0.1610
# Epoch 62/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9752 - dice_coef: 0.5274 - dice_loss: 0.4726 - dice_p_bce: 0.4740 - loss: 0.5356 - true_positive_rate: 0.6484 - weighted_bincrossentropy: 0.1373 - val_binary_accuracy: 0.9791 - val_dice_coef: 0.4679 - val_dice_loss: 0.5321 - val_dice_p_bce: 0.5339 - val_loss: 0.5688 - val_true_positive_rate: 0.5561 - val_weighted_bincrossentropy: 0.1785
# Epoch 63/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9756 - dice_coef: 0.5245 - dice_loss: 0.4755 - dice_p_bce: 0.4771 - loss: 0.5358 - true_positive_rate: 0.6266 - weighted_bincrossentropy: 0.1574 - val_binary_accuracy: 0.9746 - val_dice_coef: 0.5083 - val_dice_loss: 0.4917 - val_dice_p_bce: 0.4931 - val_loss: 0.5431 - val_true_positive_rate: 0.7152 - val_weighted_bincrossentropy: 0.1322
# Epoch 64/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9751 - dice_coef: 0.5497 - dice_loss: 0.4503 - dice_p_bce: 0.4518 - loss: 0.5136 - true_positive_rate: 0.6731 - weighted_bincrossentropy: 0.1495 - val_binary_accuracy: 0.9693 - val_dice_coef: 0.4970 - val_dice_loss: 0.5030 - val_dice_p_bce: 0.5041 - val_loss: 0.5629 - val_true_positive_rate: 0.7913 - val_weighted_bincrossentropy: 0.1035
# Epoch 65/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - binary_accuracy: 0.9729 - dice_coef: 0.5496 - dice_loss: 0.4504 - dice_p_bce: 0.4515 - loss: 0.5201 - true_positive_rate: 0.7468 - weighted_bincrossentropy: 0.1099 - val_binary_accuracy: 0.9753 - val_dice_coef: 0.5245 - val_dice_loss: 0.4755 - val_dice_p_bce: 0.4766 - val_loss: 0.5318 - val_true_positive_rate: 0.7313 - val_weighted_bincrossentropy: 0.1132
# Epoch 66/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9732 - dice_coef: 0.5708 - dice_loss: 0.4292 - dice_p_bce: 0.4304 - loss: 0.4987 - true_positive_rate: 0.7575 - weighted_bincrossentropy: 0.1170 - val_binary_accuracy: 0.9799 - val_dice_coef: 0.4793 - val_dice_loss: 0.5207 - val_dice_p_bce: 0.5226 - val_loss: 0.5559 - val_true_positive_rate: 0.5552 - val_weighted_bincrossentropy: 0.1924
# Epoch 67/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9767 - dice_coef: 0.5555 - dice_loss: 0.4445 - dice_p_bce: 0.4460 - loss: 0.5072 - true_positive_rate: 0.6731 - weighted_bincrossentropy: 0.1442 - val_binary_accuracy: 0.9800 - val_dice_coef: 0.5255 - val_dice_loss: 0.4745 - val_dice_p_bce: 0.4756 - val_loss: 0.5241 - val_true_positive_rate: 0.6449 - val_weighted_bincrossentropy: 0.1186
# Epoch 68/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9795 - dice_coef: 0.5754 - dice_loss: 0.4246 - dice_p_bce: 0.4257 - loss: 0.4888 - true_positive_rate: 0.6650 - weighted_bincrossentropy: 0.1171 - val_binary_accuracy: 0.9750 - val_dice_coef: 0.5425 - val_dice_loss: 0.4575 - val_dice_p_bce: 0.4585 - val_loss: 0.5159 - val_true_positive_rate: 0.7713 - val_weighted_bincrossentropy: 0.1070
# Epoch 69/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9772 - dice_coef: 0.5927 - dice_loss: 0.4073 - dice_p_bce: 0.4085 - loss: 0.4737 - true_positive_rate: 0.7366 - weighted_bincrossentropy: 0.1208 - val_binary_accuracy: 0.9743 - val_dice_coef: 0.5445 - val_dice_loss: 0.4555 - val_dice_p_bce: 0.4566 - val_loss: 0.5157 - val_true_positive_rate: 0.7904 - val_weighted_bincrossentropy: 0.1013
# Epoch 70/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9769 - dice_coef: 0.5977 - dice_loss: 0.4023 - dice_p_bce: 0.4033 - loss: 0.4719 - true_positive_rate: 0.7677 - weighted_bincrossentropy: 0.0998 - val_binary_accuracy: 0.9790 - val_dice_coef: 0.5545 - val_dice_loss: 0.4455 - val_dice_p_bce: 0.4465 - val_loss: 0.5007 - val_true_positive_rate: 0.7212 - val_weighted_bincrossentropy: 0.1035
# Epoch 71/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9785 - dice_coef: 0.6149 - dice_loss: 0.3851 - dice_p_bce: 0.3861 - loss: 0.4548 - true_positive_rate: 0.7497 - weighted_bincrossentropy: 0.0995 - val_binary_accuracy: 0.9804 - val_dice_coef: 0.5561 - val_dice_loss: 0.4439 - val_dice_p_bce: 0.4453 - val_loss: 0.4940 - val_true_positive_rate: 0.6684 - val_weighted_bincrossentropy: 0.1338
# Epoch 72/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9786 - dice_coef: 0.6208 - dice_loss: 0.3792 - dice_p_bce: 0.3803 - loss: 0.4482 - true_positive_rate: 0.7392 - weighted_bincrossentropy: 0.1179 - val_binary_accuracy: 0.9812 - val_dice_coef: 0.5454 - val_dice_loss: 0.4546 - val_dice_p_bce: 0.4562 - val_loss: 0.5005 - val_true_positive_rate: 0.6257 - val_weighted_bincrossentropy: 0.1551
# Epoch 73/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9795 - dice_coef: 0.6145 - dice_loss: 0.3855 - dice_p_bce: 0.3868 - loss: 0.4515 - true_positive_rate: 0.7057 - weighted_bincrossentropy: 0.1329 - val_binary_accuracy: 0.9818 - val_dice_coef: 0.5613 - val_dice_loss: 0.4387 - val_dice_p_bce: 0.4399 - val_loss: 0.4903 - val_true_positive_rate: 0.6447 - val_weighted_bincrossentropy: 0.1214
# Epoch 74/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9807 - dice_coef: 0.6227 - dice_loss: 0.3773 - dice_p_bce: 0.3784 - loss: 0.4444 - true_positive_rate: 0.7042 - weighted_bincrossentropy: 0.1118 - val_binary_accuracy: 0.9812 - val_dice_coef: 0.5781 - val_dice_loss: 0.4219 - val_dice_p_bce: 0.4230 - val_loss: 0.4764 - val_true_positive_rate: 0.6902 - val_weighted_bincrossentropy: 0.1137
# Epoch 75/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9813 - dice_coef: 0.6407 - dice_loss: 0.3593 - dice_p_bce: 0.3604 - loss: 0.4273 - true_positive_rate: 0.7230 - weighted_bincrossentropy: 0.1128 - val_binary_accuracy: 0.9800 - val_dice_coef: 0.5877 - val_dice_loss: 0.4123 - val_dice_p_bce: 0.4134 - val_loss: 0.4693 - val_true_positive_rate: 0.7335 - val_weighted_bincrossentropy: 0.1124
# Epoch 76/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9809 - dice_coef: 0.6452 - dice_loss: 0.3548 - dice_p_bce: 0.3559 - loss: 0.4228 - true_positive_rate: 0.7475 - weighted_bincrossentropy: 0.1080 - val_binary_accuracy: 0.9808 - val_dice_coef: 0.5922 - val_dice_loss: 0.4078 - val_dice_p_bce: 0.4089 - val_loss: 0.4641 - val_true_positive_rate: 0.7241 - val_weighted_bincrossentropy: 0.1092
# Epoch 77/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9806 - dice_coef: 0.6434 - dice_loss: 0.3566 - dice_p_bce: 0.3577 - loss: 0.4250 - true_positive_rate: 0.7386 - weighted_bincrossentropy: 0.1114 - val_binary_accuracy: 0.9808 - val_dice_coef: 0.5974 - val_dice_loss: 0.4026 - val_dice_p_bce: 0.4036 - val_loss: 0.4603 - val_true_positive_rate: 0.7357 - val_weighted_bincrossentropy: 0.1034
# Epoch 78/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9817 - dice_coef: 0.6502 - dice_loss: 0.3498 - dice_p_bce: 0.3508 - loss: 0.4187 - true_positive_rate: 0.7444 - weighted_bincrossentropy: 0.1035 - val_binary_accuracy: 0.9803 - val_dice_coef: 0.5999 - val_dice_loss: 0.4001 - val_dice_p_bce: 0.4012 - val_loss: 0.4583 - val_true_positive_rate: 0.7466 - val_weighted_bincrossentropy: 0.1062
# Epoch 79/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9816 - dice_coef: 0.6553 - dice_loss: 0.3447 - dice_p_bce: 0.3458 - loss: 0.4124 - true_positive_rate: 0.7497 - weighted_bincrossentropy: 0.1080 - val_binary_accuracy: 0.9792 - val_dice_coef: 0.6005 - val_dice_loss: 0.3995 - val_dice_p_bce: 0.4004 - val_loss: 0.4608 - val_true_positive_rate: 0.7849 - val_weighted_bincrossentropy: 0.0921
# Epoch 80/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9816 - dice_coef: 0.6578 - dice_loss: 0.3422 - dice_p_bce: 0.3432 - loss: 0.4105 - true_positive_rate: 0.7628 - weighted_bincrossentropy: 0.0989 - val_binary_accuracy: 0.9794 - val_dice_coef: 0.6039 - val_dice_loss: 0.3961 - val_dice_p_bce: 0.3970 - val_loss: 0.4580 - val_true_positive_rate: 0.7881 - val_weighted_bincrossentropy: 0.0874
# Epoch 81/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9816 - dice_coef: 0.6637 - dice_loss: 0.3363 - dice_p_bce: 0.3372 - loss: 0.4053 - true_positive_rate: 0.7823 - weighted_bincrossentropy: 0.0928 - val_binary_accuracy: 0.9817 - val_dice_coef: 0.6119 - val_dice_loss: 0.3881 - val_dice_p_bce: 0.3891 - val_loss: 0.4457 - val_true_positive_rate: 0.7353 - val_weighted_bincrossentropy: 0.1064
# Epoch 82/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9812 - dice_coef: 0.6663 - dice_loss: 0.3337 - dice_p_bce: 0.3348 - loss: 0.4034 - true_positive_rate: 0.7717 - weighted_bincrossentropy: 0.1033 - val_binary_accuracy: 0.9823 - val_dice_coef: 0.6145 - val_dice_loss: 0.3855 - val_dice_p_bce: 0.3867 - val_loss: 0.4434 - val_true_positive_rate: 0.7079 - val_weighted_bincrossentropy: 0.1162
# Epoch 83/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9819 - dice_coef: 0.6724 - dice_loss: 0.3276 - dice_p_bce: 0.3286 - loss: 0.3962 - true_positive_rate: 0.7613 - weighted_bincrossentropy: 0.1063 - val_binary_accuracy: 0.9826 - val_dice_coef: 0.6188 - val_dice_loss: 0.3812 - val_dice_p_bce: 0.3823 - val_loss: 0.4400 - val_true_positive_rate: 0.7070 - val_weighted_bincrossentropy: 0.1122
# Epoch 84/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9825 - dice_coef: 0.6762 - dice_loss: 0.3238 - dice_p_bce: 0.3248 - loss: 0.3926 - true_positive_rate: 0.7579 - weighted_bincrossentropy: 0.1035 - val_binary_accuracy: 0.9828 - val_dice_coef: 0.6212 - val_dice_loss: 0.3788 - val_dice_p_bce: 0.3799 - val_loss: 0.4362 - val_true_positive_rate: 0.7076 - val_weighted_bincrossentropy: 0.1143
# Epoch 85/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9831 - dice_coef: 0.6796 - dice_loss: 0.3204 - dice_p_bce: 0.3215 - loss: 0.3886 - true_positive_rate: 0.7592 - weighted_bincrossentropy: 0.1019 - val_binary_accuracy: 0.9828 - val_dice_coef: 0.6248 - val_dice_loss: 0.3752 - val_dice_p_bce: 0.3763 - val_loss: 0.4326 - val_true_positive_rate: 0.7169 - val_weighted_bincrossentropy: 0.1153
# Epoch 86/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9835 - dice_coef: 0.6888 - dice_loss: 0.3112 - dice_p_bce: 0.3123 - loss: 0.3794 - true_positive_rate: 0.7680 - weighted_bincrossentropy: 0.1011 - val_binary_accuracy: 0.9831 - val_dice_coef: 0.6288 - val_dice_loss: 0.3712 - val_dice_p_bce: 0.3724 - val_loss: 0.4295 - val_true_positive_rate: 0.7135 - val_weighted_bincrossentropy: 0.1118
# Epoch 87/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9830 - dice_coef: 0.6859 - dice_loss: 0.3141 - dice_p_bce: 0.3152 - loss: 0.3821 - true_positive_rate: 0.7594 - weighted_bincrossentropy: 0.1053 - val_binary_accuracy: 0.9808 - val_dice_coef: 0.6285 - val_dice_loss: 0.3715 - val_dice_p_bce: 0.3724 - val_loss: 0.4327 - val_true_positive_rate: 0.7950 - val_weighted_bincrossentropy: 0.0922
# Epoch 88/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9818 - dice_coef: 0.6849 - dice_loss: 0.3151 - dice_p_bce: 0.3161 - loss: 0.3846 - true_positive_rate: 0.7887 - weighted_bincrossentropy: 0.1016 - val_binary_accuracy: 0.9828 - val_dice_coef: 0.6326 - val_dice_loss: 0.3674 - val_dice_p_bce: 0.3686 - val_loss: 0.4246 - val_true_positive_rate: 0.7346 - val_weighted_bincrossentropy: 0.1135
# Epoch 89/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9830 - dice_coef: 0.6899 - dice_loss: 0.3101 - dice_p_bce: 0.3111 - loss: 0.3776 - true_positive_rate: 0.7694 - weighted_bincrossentropy: 0.1071 - val_binary_accuracy: 0.9840 - val_dice_coef: 0.6254 - val_dice_loss: 0.3746 - val_dice_p_bce: 0.3758 - val_loss: 0.4302 - val_true_positive_rate: 0.6765 - val_weighted_bincrossentropy: 0.1243
# Epoch 90/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9843 - dice_coef: 0.6946 - dice_loss: 0.3054 - dice_p_bce: 0.3064 - loss: 0.3729 - true_positive_rate: 0.7521 - weighted_bincrossentropy: 0.1052 - val_binary_accuracy: 0.9834 - val_dice_coef: 0.6368 - val_dice_loss: 0.3632 - val_dice_p_bce: 0.3643 - val_loss: 0.4202 - val_true_positive_rate: 0.7204 - val_weighted_bincrossentropy: 0.1175
# Epoch 91/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9839 - dice_coef: 0.7008 - dice_loss: 0.2992 - dice_p_bce: 0.3003 - loss: 0.3664 - true_positive_rate: 0.7746 - weighted_bincrossentropy: 0.1038 - val_binary_accuracy: 0.9828 - val_dice_coef: 0.6435 - val_dice_loss: 0.3565 - val_dice_p_bce: 0.3575 - val_loss: 0.4159 - val_true_positive_rate: 0.7678 - val_weighted_bincrossentropy: 0.0976
# Epoch 92/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9842 - dice_coef: 0.7020 - dice_loss: 0.2980 - dice_p_bce: 0.2990 - loss: 0.3658 - true_positive_rate: 0.7848 - weighted_bincrossentropy: 0.0945 - val_binary_accuracy: 0.9827 - val_dice_coef: 0.6447 - val_dice_loss: 0.3553 - val_dice_p_bce: 0.3563 - val_loss: 0.4149 - val_true_positive_rate: 0.7729 - val_weighted_bincrossentropy: 0.0984
# Epoch 93/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - binary_accuracy: 0.9840 - dice_coef: 0.7019 - dice_loss: 0.2981 - dice_p_bce: 0.2991 - loss: 0.3662 - true_positive_rate: 0.7907 - weighted_bincrossentropy: 0.0956 - val_binary_accuracy: 0.9842 - val_dice_coef: 0.6239 - val_dice_loss: 0.3761 - val_dice_p_bce: 0.3776 - val_loss: 0.4298 - val_true_positive_rate: 0.6575 - val_weighted_bincrossentropy: 0.1484
# Epoch 94/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9847 - dice_coef: 0.6988 - dice_loss: 0.3012 - dice_p_bce: 0.3024 - loss: 0.3673 - true_positive_rate: 0.7517 - weighted_bincrossentropy: 0.1127 - val_binary_accuracy: 0.9843 - val_dice_coef: 0.6441 - val_dice_loss: 0.3559 - val_dice_p_bce: 0.3571 - val_loss: 0.4116 - val_true_positive_rate: 0.7137 - val_weighted_bincrossentropy: 0.1137
# Epoch 95/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9849 - dice_coef: 0.7085 - dice_loss: 0.2915 - dice_p_bce: 0.2925 - loss: 0.3580 - true_positive_rate: 0.7737 - weighted_bincrossentropy: 0.0987 - val_binary_accuracy: 0.9841 - val_dice_coef: 0.6490 - val_dice_loss: 0.3510 - val_dice_p_bce: 0.3521 - val_loss: 0.4075 - val_true_positive_rate: 0.7325 - val_weighted_bincrossentropy: 0.1128
# Epoch 96/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9847 - dice_coef: 0.7106 - dice_loss: 0.2894 - dice_p_bce: 0.2904 - loss: 0.3560 - true_positive_rate: 0.7826 - weighted_bincrossentropy: 0.0993 - val_binary_accuracy: 0.9839 - val_dice_coef: 0.6541 - val_dice_loss: 0.3459 - val_dice_p_bce: 0.3470 - val_loss: 0.4049 - val_true_positive_rate: 0.7476 - val_weighted_bincrossentropy: 0.1089
# Epoch 97/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9850 - dice_coef: 0.7165 - dice_loss: 0.2835 - dice_p_bce: 0.2845 - loss: 0.3496 - true_positive_rate: 0.7871 - weighted_bincrossentropy: 0.0965 - val_binary_accuracy: 0.9841 - val_dice_coef: 0.6585 - val_dice_loss: 0.3415 - val_dice_p_bce: 0.3426 - val_loss: 0.4005 - val_true_positive_rate: 0.7526 - val_weighted_bincrossentropy: 0.1033
# Epoch 98/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9849 - dice_coef: 0.7174 - dice_loss: 0.2826 - dice_p_bce: 0.2836 - loss: 0.3485 - true_positive_rate: 0.7890 - weighted_bincrossentropy: 0.0965 - val_binary_accuracy: 0.9848 - val_dice_coef: 0.6513 - val_dice_loss: 0.3487 - val_dice_p_bce: 0.3499 - val_loss: 0.4050 - val_true_positive_rate: 0.7009 - val_weighted_bincrossentropy: 0.1232
# Epoch 99/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9848 - dice_coef: 0.7116 - dice_loss: 0.2884 - dice_p_bce: 0.2895 - loss: 0.3547 - true_positive_rate: 0.7643 - weighted_bincrossentropy: 0.1090 - val_binary_accuracy: 0.9805 - val_dice_coef: 0.6428 - val_dice_loss: 0.3572 - val_dice_p_bce: 0.3580 - val_loss: 0.4194 - val_true_positive_rate: 0.8387 - val_weighted_bincrossentropy: 0.0854
# Epoch 100/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9837 - dice_coef: 0.7046 - dice_loss: 0.2954 - dice_p_bce: 0.2964 - loss: 0.3636 - true_positive_rate: 0.8094 - weighted_bincrossentropy: 0.0948 - val_binary_accuracy: 0.9837 - val_dice_coef: 0.6627 - val_dice_loss: 0.3373 - val_dice_p_bce: 0.3383 - val_loss: 0.3962 - val_true_positive_rate: 0.7797 - val_weighted_bincrossentropy: 0.0996
# Epoch 101/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9848 - dice_coef: 0.7144 - dice_loss: 0.2856 - dice_p_bce: 0.2866 - loss: 0.3511 - true_positive_rate: 0.7900 - weighted_bincrossentropy: 0.0986 - val_binary_accuracy: 0.9837 - val_dice_coef: 0.6622 - val_dice_loss: 0.3378 - val_dice_p_bce: 0.3387 - val_loss: 0.3967 - val_true_positive_rate: 0.7841 - val_weighted_bincrossentropy: 0.0942
# Epoch 102/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9854 - dice_coef: 0.7191 - dice_loss: 0.2809 - dice_p_bce: 0.2818 - loss: 0.3472 - true_positive_rate: 0.7873 - weighted_bincrossentropy: 0.0942 - val_binary_accuracy: 0.9829 - val_dice_coef: 0.6590 - val_dice_loss: 0.3410 - val_dice_p_bce: 0.3419 - val_loss: 0.4007 - val_true_positive_rate: 0.8061 - val_weighted_bincrossentropy: 0.0907
# Epoch 103/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9849 - dice_coef: 0.7195 - dice_loss: 0.2805 - dice_p_bce: 0.2814 - loss: 0.3470 - true_positive_rate: 0.8030 - weighted_bincrossentropy: 0.0918 - val_binary_accuracy: 0.9836 - val_dice_coef: 0.6654 - val_dice_loss: 0.3346 - val_dice_p_bce: 0.3355 - val_loss: 0.3944 - val_true_positive_rate: 0.7939 - val_weighted_bincrossentropy: 0.0921
# Epoch 104/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9850 - dice_coef: 0.7240 - dice_loss: 0.2760 - dice_p_bce: 0.2770 - loss: 0.3411 - true_positive_rate: 0.8065 - weighted_bincrossentropy: 0.0922 - val_binary_accuracy: 0.9834 - val_dice_coef: 0.6670 - val_dice_loss: 0.3330 - val_dice_p_bce: 0.3339 - val_loss: 0.3937 - val_true_positive_rate: 0.8013 - val_weighted_bincrossentropy: 0.0902
# Epoch 105/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9854 - dice_coef: 0.7261 - dice_loss: 0.2739 - dice_p_bce: 0.2747 - loss: 0.3390 - true_positive_rate: 0.8086 - weighted_bincrossentropy: 0.0881 - val_binary_accuracy: 0.9845 - val_dice_coef: 0.6728 - val_dice_loss: 0.3272 - val_dice_p_bce: 0.3282 - val_loss: 0.3861 - val_true_positive_rate: 0.7758 - val_weighted_bincrossentropy: 0.0975
# Epoch 106/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9859 - dice_coef: 0.7308 - dice_loss: 0.2692 - dice_p_bce: 0.2702 - loss: 0.3347 - true_positive_rate: 0.7977 - weighted_bincrossentropy: 0.0921 - val_binary_accuracy: 0.9837 - val_dice_coef: 0.6704 - val_dice_loss: 0.3296 - val_dice_p_bce: 0.3305 - val_loss: 0.3894 - val_true_positive_rate: 0.7987 - val_weighted_bincrossentropy: 0.0939
# Epoch 107/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9856 - dice_coef: 0.7306 - dice_loss: 0.2694 - dice_p_bce: 0.2703 - loss: 0.3340 - true_positive_rate: 0.8086 - weighted_bincrossentropy: 0.0907 - val_binary_accuracy: 0.9848 - val_dice_coef: 0.6748 - val_dice_loss: 0.3252 - val_dice_p_bce: 0.3262 - val_loss: 0.3838 - val_true_positive_rate: 0.7688 - val_weighted_bincrossentropy: 0.1006
# Epoch 108/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9862 - dice_coef: 0.7347 - dice_loss: 0.2653 - dice_p_bce: 0.2663 - loss: 0.3303 - true_positive_rate: 0.7962 - weighted_bincrossentropy: 0.0917 - val_binary_accuracy: 0.9847 - val_dice_coef: 0.6761 - val_dice_loss: 0.3239 - val_dice_p_bce: 0.3249 - val_loss: 0.3822 - val_true_positive_rate: 0.7749 - val_weighted_bincrossentropy: 0.1008
# Epoch 109/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9862 - dice_coef: 0.7367 - dice_loss: 0.2633 - dice_p_bce: 0.2642 - loss: 0.3273 - true_positive_rate: 0.8017 - weighted_bincrossentropy: 0.0933 - val_binary_accuracy: 0.9854 - val_dice_coef: 0.6774 - val_dice_loss: 0.3226 - val_dice_p_bce: 0.3237 - val_loss: 0.3799 - val_true_positive_rate: 0.7531 - val_weighted_bincrossentropy: 0.1068
# Epoch 110/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9865 - dice_coef: 0.7389 - dice_loss: 0.2611 - dice_p_bce: 0.2620 - loss: 0.3251 - true_positive_rate: 0.7936 - weighted_bincrossentropy: 0.0933 - val_binary_accuracy: 0.9845 - val_dice_coef: 0.6782 - val_dice_loss: 0.3218 - val_dice_p_bce: 0.3227 - val_loss: 0.3808 - val_true_positive_rate: 0.7903 - val_weighted_bincrossentropy: 0.0957
# Epoch 111/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9856 - dice_coef: 0.7363 - dice_loss: 0.2637 - dice_p_bce: 0.2646 - loss: 0.3283 - true_positive_rate: 0.8095 - weighted_bincrossentropy: 0.0936 - val_binary_accuracy: 0.9859 - val_dice_coef: 0.6737 - val_dice_loss: 0.3263 - val_dice_p_bce: 0.3276 - val_loss: 0.3830 - val_true_positive_rate: 0.7099 - val_weighted_bincrossentropy: 0.1241
# Epoch 112/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9866 - dice_coef: 0.7373 - dice_loss: 0.2627 - dice_p_bce: 0.2637 - loss: 0.3273 - true_positive_rate: 0.7767 - weighted_bincrossentropy: 0.1006 - val_binary_accuracy: 0.9829 - val_dice_coef: 0.6702 - val_dice_loss: 0.3298 - val_dice_p_bce: 0.3307 - val_loss: 0.3903 - val_true_positive_rate: 0.8304 - val_weighted_bincrossentropy: 0.0874
# Epoch 113/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9854 - dice_coef: 0.7300 - dice_loss: 0.2700 - dice_p_bce: 0.2710 - loss: 0.3357 - true_positive_rate: 0.8173 - weighted_bincrossentropy: 0.0928 - val_binary_accuracy: 0.9849 - val_dice_coef: 0.6819 - val_dice_loss: 0.3181 - val_dice_p_bce: 0.3191 - val_loss: 0.3765 - val_true_positive_rate: 0.7846 - val_weighted_bincrossentropy: 0.0966
# Epoch 114/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9865 - dice_coef: 0.7416 - dice_loss: 0.2584 - dice_p_bce: 0.2593 - loss: 0.3218 - true_positive_rate: 0.8017 - weighted_bincrossentropy: 0.0922 - val_binary_accuracy: 0.9849 - val_dice_coef: 0.6823 - val_dice_loss: 0.3177 - val_dice_p_bce: 0.3187 - val_loss: 0.3758 - val_true_positive_rate: 0.7819 - val_weighted_bincrossentropy: 0.0992
# Epoch 115/1000
# ...
# Epoch 963/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9157 - dice_loss: 0.0843 - dice_p_bce: 0.0851 - loss: 0.1149 - true_positive_rate: 0.9225 - weighted_bincrossentropy: 0.0806 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7968 - val_dice_loss: 0.2032 - val_dice_p_bce: 0.2048 - val_loss: 0.2524 - val_true_positive_rate: 0.8194 - val_weighted_bincrossentropy: 0.1624
# Epoch 964/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9152 - dice_loss: 0.0848 - dice_p_bce: 0.0857 - loss: 0.1155 - true_positive_rate: 0.9243 - weighted_bincrossentropy: 0.0814 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7966 - val_dice_loss: 0.2034 - val_dice_p_bce: 0.2051 - val_loss: 0.2525 - val_true_positive_rate: 0.8132 - val_weighted_bincrossentropy: 0.1671
# Epoch 965/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9147 - dice_loss: 0.0853 - dice_p_bce: 0.0861 - loss: 0.1155 - true_positive_rate: 0.9233 - weighted_bincrossentropy: 0.0835 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7964 - val_dice_loss: 0.2036 - val_dice_p_bce: 0.2053 - val_loss: 0.2532 - val_true_positive_rate: 0.8150 - val_weighted_bincrossentropy: 0.1656
# Epoch 966/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9155 - dice_loss: 0.0845 - dice_p_bce: 0.0853 - loss: 0.1154 - true_positive_rate: 0.9235 - weighted_bincrossentropy: 0.0808 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7970 - val_dice_loss: 0.2030 - val_dice_p_bce: 0.2046 - val_loss: 0.2519 - val_true_positive_rate: 0.8151 - val_weighted_bincrossentropy: 0.1664
# Epoch 967/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9152 - dice_loss: 0.0848 - dice_p_bce: 0.0857 - loss: 0.1154 - true_positive_rate: 0.9236 - weighted_bincrossentropy: 0.0820 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7969 - val_dice_loss: 0.2031 - val_dice_p_bce: 0.2048 - val_loss: 0.2523 - val_true_positive_rate: 0.8199 - val_weighted_bincrossentropy: 0.1625
# Epoch 968/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9958 - dice_coef: 0.9166 - dice_loss: 0.0834 - dice_p_bce: 0.0842 - loss: 0.1137 - true_positive_rate: 0.9246 - weighted_bincrossentropy: 0.0803 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7967 - val_dice_loss: 0.2033 - val_dice_p_bce: 0.2050 - val_loss: 0.2527 - val_true_positive_rate: 0.8199 - val_weighted_bincrossentropy: 0.1619
# Epoch 969/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9147 - dice_loss: 0.0853 - dice_p_bce: 0.0861 - loss: 0.1154 - true_positive_rate: 0.9233 - weighted_bincrossentropy: 0.0826 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7970 - val_dice_loss: 0.2030 - val_dice_p_bce: 0.2047 - val_loss: 0.2521 - val_true_positive_rate: 0.8107 - val_weighted_bincrossentropy: 0.1702
# Epoch 970/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9154 - dice_loss: 0.0846 - dice_p_bce: 0.0854 - loss: 0.1153 - true_positive_rate: 0.9213 - weighted_bincrossentropy: 0.0813 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7962 - val_dice_loss: 0.2038 - val_dice_p_bce: 0.2055 - val_loss: 0.2531 - val_true_positive_rate: 0.8214 - val_weighted_bincrossentropy: 0.1619
# Epoch 971/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9154 - dice_loss: 0.0846 - dice_p_bce: 0.0854 - loss: 0.1152 - true_positive_rate: 0.9250 - weighted_bincrossentropy: 0.0815 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7967 - val_dice_loss: 0.2033 - val_dice_p_bce: 0.2050 - val_loss: 0.2527 - val_true_positive_rate: 0.8174 - val_weighted_bincrossentropy: 0.1647
# Epoch 972/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9145 - dice_loss: 0.0855 - dice_p_bce: 0.0863 - loss: 0.1168 - true_positive_rate: 0.9232 - weighted_bincrossentropy: 0.0807 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7962 - val_dice_loss: 0.2038 - val_dice_p_bce: 0.2055 - val_loss: 0.2529 - val_true_positive_rate: 0.8137 - val_weighted_bincrossentropy: 0.1677
# Epoch 973/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9151 - dice_loss: 0.0849 - dice_p_bce: 0.0857 - loss: 0.1155 - true_positive_rate: 0.9228 - weighted_bincrossentropy: 0.0807 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7968 - val_dice_loss: 0.2032 - val_dice_p_bce: 0.2048 - val_loss: 0.2523 - val_true_positive_rate: 0.8134 - val_weighted_bincrossentropy: 0.1667
# Epoch 974/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9151 - dice_loss: 0.0849 - dice_p_bce: 0.0857 - loss: 0.1157 - true_positive_rate: 0.9213 - weighted_bincrossentropy: 0.0807 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7960 - val_dice_loss: 0.2040 - val_dice_p_bce: 0.2057 - val_loss: 0.2529 - val_true_positive_rate: 0.8119 - val_weighted_bincrossentropy: 0.1699
# Epoch 975/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9142 - dice_loss: 0.0858 - dice_p_bce: 0.0867 - loss: 0.1160 - true_positive_rate: 0.9218 - weighted_bincrossentropy: 0.0844 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7967 - val_dice_loss: 0.2033 - val_dice_p_bce: 0.2050 - val_loss: 0.2527 - val_true_positive_rate: 0.8103 - val_weighted_bincrossentropy: 0.1683
# Epoch 976/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9134 - dice_loss: 0.0866 - dice_p_bce: 0.0874 - loss: 0.1179 - true_positive_rate: 0.9187 - weighted_bincrossentropy: 0.0821 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7964 - val_dice_loss: 0.2036 - val_dice_p_bce: 0.2053 - val_loss: 0.2524 - val_true_positive_rate: 0.8106 - val_weighted_bincrossentropy: 0.1707
# Epoch 977/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9958 - dice_coef: 0.9158 - dice_loss: 0.0842 - dice_p_bce: 0.0850 - loss: 0.1147 - true_positive_rate: 0.9222 - weighted_bincrossentropy: 0.0812 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7962 - val_dice_loss: 0.2038 - val_dice_p_bce: 0.2054 - val_loss: 0.2533 - val_true_positive_rate: 0.8153 - val_weighted_bincrossentropy: 0.1664
# Epoch 978/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9159 - dice_loss: 0.0841 - dice_p_bce: 0.0849 - loss: 0.1148 - true_positive_rate: 0.9241 - weighted_bincrossentropy: 0.0811 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7956 - val_dice_loss: 0.2044 - val_dice_p_bce: 0.2061 - val_loss: 0.2536 - val_true_positive_rate: 0.8200 - val_weighted_bincrossentropy: 0.1641
# Epoch 979/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9158 - dice_loss: 0.0842 - dice_p_bce: 0.0850 - loss: 0.1150 - true_positive_rate: 0.9248 - weighted_bincrossentropy: 0.0806 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7964 - val_dice_loss: 0.2036 - val_dice_p_bce: 0.2052 - val_loss: 0.2528 - val_true_positive_rate: 0.8271 - val_weighted_bincrossentropy: 0.1599
# Epoch 980/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9156 - dice_loss: 0.0844 - dice_p_bce: 0.0852 - loss: 0.1149 - true_positive_rate: 0.9262 - weighted_bincrossentropy: 0.0813 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7952 - val_dice_loss: 0.2048 - val_dice_p_bce: 0.2065 - val_loss: 0.2544 - val_true_positive_rate: 0.8186 - val_weighted_bincrossentropy: 0.1648
# Epoch 981/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9958 - dice_coef: 0.9170 - dice_loss: 0.0830 - dice_p_bce: 0.0838 - loss: 0.1134 - true_positive_rate: 0.9250 - weighted_bincrossentropy: 0.0797 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.7970 - val_dice_loss: 0.2030 - val_dice_p_bce: 0.2046 - val_loss: 0.2518 - val_true_positive_rate: 0.8160 - val_weighted_bincrossentropy: 0.1664
# Epoch 982/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9161 - dice_loss: 0.0839 - dice_p_bce: 0.0847 - loss: 0.1137 - true_positive_rate: 0.9235 - weighted_bincrossentropy: 0.0837 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7958 - val_dice_loss: 0.2042 - val_dice_p_bce: 0.2059 - val_loss: 0.2539 - val_true_positive_rate: 0.8204 - val_weighted_bincrossentropy: 0.1639
# Epoch 983/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9956 - dice_coef: 0.9159 - dice_loss: 0.0841 - dice_p_bce: 0.0850 - loss: 0.1140 - true_positive_rate: 0.9251 - weighted_bincrossentropy: 0.0836 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7963 - val_dice_loss: 0.2037 - val_dice_p_bce: 0.2053 - val_loss: 0.2532 - val_true_positive_rate: 0.8172 - val_weighted_bincrossentropy: 0.1654
# Epoch 984/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9156 - dice_loss: 0.0844 - dice_p_bce: 0.0852 - loss: 0.1143 - true_positive_rate: 0.9228 - weighted_bincrossentropy: 0.0836 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7962 - val_dice_loss: 0.2038 - val_dice_p_bce: 0.2055 - val_loss: 0.2529 - val_true_positive_rate: 0.8157 - val_weighted_bincrossentropy: 0.1678
# Epoch 985/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9162 - dice_loss: 0.0838 - dice_p_bce: 0.0846 - loss: 0.1141 - true_positive_rate: 0.9253 - weighted_bincrossentropy: 0.0822 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7957 - val_dice_loss: 0.2043 - val_dice_p_bce: 0.2060 - val_loss: 0.2537 - val_true_positive_rate: 0.8240 - val_weighted_bincrossentropy: 0.1616
# Epoch 986/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - binary_accuracy: 0.9958 - dice_coef: 0.9170 - dice_loss: 0.0830 - dice_p_bce: 0.0838 - loss: 0.1131 - true_positive_rate: 0.9256 - weighted_bincrossentropy: 0.0803 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7963 - val_dice_loss: 0.2037 - val_dice_p_bce: 0.2054 - val_loss: 0.2532 - val_true_positive_rate: 0.8214 - val_weighted_bincrossentropy: 0.1642
# Epoch 987/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9958 - dice_coef: 0.9166 - dice_loss: 0.0834 - dice_p_bce: 0.0842 - loss: 0.1140 - true_positive_rate: 0.9251 - weighted_bincrossentropy: 0.0798 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7961 - val_dice_loss: 0.2039 - val_dice_p_bce: 0.2055 - val_loss: 0.2529 - val_true_positive_rate: 0.8197 - val_weighted_bincrossentropy: 0.1648
# Epoch 988/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9164 - dice_loss: 0.0836 - dice_p_bce: 0.0844 - loss: 0.1139 - true_positive_rate: 0.9261 - weighted_bincrossentropy: 0.0821 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7961 - val_dice_loss: 0.2039 - val_dice_p_bce: 0.2055 - val_loss: 0.2533 - val_true_positive_rate: 0.8242 - val_weighted_bincrossentropy: 0.1619
# Epoch 989/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9959 - dice_coef: 0.9177 - dice_loss: 0.0823 - dice_p_bce: 0.0831 - loss: 0.1125 - true_positive_rate: 0.9261 - weighted_bincrossentropy: 0.0797 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7968 - val_dice_loss: 0.2032 - val_dice_p_bce: 0.2049 - val_loss: 0.2522 - val_true_positive_rate: 0.8199 - val_weighted_bincrossentropy: 0.1655
# Epoch 990/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9958 - dice_coef: 0.9169 - dice_loss: 0.0831 - dice_p_bce: 0.0839 - loss: 0.1135 - true_positive_rate: 0.9265 - weighted_bincrossentropy: 0.0805 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7956 - val_dice_loss: 0.2044 - val_dice_p_bce: 0.2061 - val_loss: 0.2537 - val_true_positive_rate: 0.8177 - val_weighted_bincrossentropy: 0.1666
# Epoch 991/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9959 - dice_coef: 0.9175 - dice_loss: 0.0825 - dice_p_bce: 0.0834 - loss: 0.1126 - true_positive_rate: 0.9249 - weighted_bincrossentropy: 0.0812 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7966 - val_dice_loss: 0.2034 - val_dice_p_bce: 0.2051 - val_loss: 0.2526 - val_true_positive_rate: 0.8214 - val_weighted_bincrossentropy: 0.1643
# Epoch 992/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9166 - dice_loss: 0.0834 - dice_p_bce: 0.0843 - loss: 0.1131 - true_positive_rate: 0.9257 - weighted_bincrossentropy: 0.0830 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7960 - val_dice_loss: 0.2040 - val_dice_p_bce: 0.2057 - val_loss: 0.2531 - val_true_positive_rate: 0.8175 - val_weighted_bincrossentropy: 0.1679
# Epoch 993/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9161 - dice_loss: 0.0839 - dice_p_bce: 0.0848 - loss: 0.1137 - true_positive_rate: 0.9245 - weighted_bincrossentropy: 0.0837 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7958 - val_dice_loss: 0.2042 - val_dice_p_bce: 0.2058 - val_loss: 0.2535 - val_true_positive_rate: 0.8221 - val_weighted_bincrossentropy: 0.1631
# Epoch 994/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9153 - dice_loss: 0.0847 - dice_p_bce: 0.0855 - loss: 0.1156 - true_positive_rate: 0.9240 - weighted_bincrossentropy: 0.0798 - val_binary_accuracy: 0.9905 - val_dice_coef: 0.7969 - val_dice_loss: 0.2031 - val_dice_p_bce: 0.2048 - val_loss: 0.2525 - val_true_positive_rate: 0.8224 - val_weighted_bincrossentropy: 0.1631
# Epoch 995/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9152 - dice_loss: 0.0848 - dice_p_bce: 0.0856 - loss: 0.1155 - true_positive_rate: 0.9247 - weighted_bincrossentropy: 0.0800 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7958 - val_dice_loss: 0.2042 - val_dice_p_bce: 0.2059 - val_loss: 0.2533 - val_true_positive_rate: 0.8178 - val_weighted_bincrossentropy: 0.1669
# Epoch 996/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - binary_accuracy: 0.9956 - dice_coef: 0.9147 - dice_loss: 0.0853 - dice_p_bce: 0.0861 - loss: 0.1155 - true_positive_rate: 0.9241 - weighted_bincrossentropy: 0.0834 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7953 - val_dice_loss: 0.2047 - val_dice_p_bce: 0.2064 - val_loss: 0.2543 - val_true_positive_rate: 0.8097 - val_weighted_bincrossentropy: 0.1705
# Epoch 997/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9955 - dice_coef: 0.9134 - dice_loss: 0.0866 - dice_p_bce: 0.0874 - loss: 0.1182 - true_positive_rate: 0.9213 - weighted_bincrossentropy: 0.0815 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7939 - val_dice_loss: 0.2061 - val_dice_p_bce: 0.2078 - val_loss: 0.2555 - val_true_positive_rate: 0.8071 - val_weighted_bincrossentropy: 0.1752
# Epoch 998/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9957 - dice_coef: 0.9143 - dice_loss: 0.0857 - dice_p_bce: 0.0865 - loss: 0.1168 - true_positive_rate: 0.9184 - weighted_bincrossentropy: 0.0819 - val_binary_accuracy: 0.9904 - val_dice_coef: 0.7953 - val_dice_loss: 0.2047 - val_dice_p_bce: 0.2063 - val_loss: 0.2541 - val_true_positive_rate: 0.8292 - val_weighted_bincrossentropy: 0.1584
# Epoch 999/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - binary_accuracy: 0.9955 - dice_coef: 0.9141 - dice_loss: 0.0859 - dice_p_bce: 0.0867 - loss: 0.1162 - true_positive_rate: 0.9232 - weighted_bincrossentropy: 0.0834 - val_binary_accuracy: 0.9904 - val_dice_coef: 0.7966 - val_dice_loss: 0.2034 - val_dice_p_bce: 0.2051 - val_loss: 0.2528 - val_true_positive_rate: 0.8276 - val_weighted_bincrossentropy: 0.1618
# Epoch 1000/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - binary_accuracy: 0.9955 - dice_coef: 0.9130 - dice_loss: 0.0870 - dice_p_bce: 0.0879 - loss: 0.1178 - true_positive_rate: 0.9244 - weighted_bincrossentropy: 0.0826 - val_binary_accuracy: 0.9906 - val_dice_coef: 0.7959 - val_dice_loss: 0.2041 - val_dice_p_bce: 0.2058 - val_loss: 0.2537 - val_true_positive_rate: 0.8144 - val_weighted_bincrossentropy: 0.1681

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('model dice coefficent')
plt.ylabel('dice coef')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# print("Max acc:", round(max(history.history['acc']),4))
# print("Max val_acc:", round(max(history.history['val_acc']),4))
# print("\nMin loss:", round(min(history.history['loss']),4))
# print("Min val_loss:", round(min(history.history['val_loss']),4))

# %% [markdown]
# ## Testing the model

# %%
## Save the Weights

#model.save_weights("UNetW.h5")

# %%
## Dataset for prediction
x, y = valid_gen.__getitem__(0)
result = model.predict(x)

result = result > 0.5
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)

r = random.randint(0, len(x)-1)


ax = fig.add_subplot(1, 2, 1)
ax.imshow(np.reshape(y[r]*255, (dim, dim)), cmap="gray")

ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(result[r]*255, (dim, dim)), cmap="gray")

# %%
fig, axes = plt.subplots(ncols = 3, )

fig.set_figwidth(3.6)
fig.set_figheight(2)


axes[0].imshow(x[0])
axes[0].set_xlabel('Raw Image')
axes[1].imshow(np.reshape(y[0]*255, (dim, dim)), cmap="gray")
axes[1].set_xlabel('Ground Truth')
axes[2].imshow(np.reshape(result[0]*255, (dim, dim)), cmap="gray")
axes[2].set_xlabel('Prediction')

matplotlib.rcParams.update({'font.size': 12, "font.family": "Times New Roman"})

for i, ax in enumerate(axes):
    axes[i].tick_params(
        axis='both',          # changes apply to the voth axis
        which='both', 
        left = False,   # both major and minor ticks are affected
        right = False,
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False) # labels along the bottom edge are off
    
    axes[i].xaxis.set_ticklabels([])
    axes[i].yaxis.set_ticklabels([])

    for j in ax.spines:
        axes[i].spines[j].set_visible(False)
        
    plt.savefig(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_example.pdf', dpi =300)

# %% [markdown]
# ## Save Model

# %%
import json

# %%
# !mkdir saved_models
# model.save(r'C:\Users\thoma\Desktop\CT_Segment_Full_v2.h5')

model.save(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}.keras')


save_dict = {'History': history.history, 'Loss Function': use_loss.__name__, 'Learning Rate': learning_rate, 'Num Training Images': len(train_imgs), 'Num Test Images': len(test_imgs), 'Batch Size': batch_size}

with open(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_history.json', 'w') as f:
    json.dump(save_dict, f)

# %%
# with open(r'C:\Users\chloe\DE4\Masters\Models\Model_3_history.pkl', 'r') as f:
#     hist = json.load(f)

# print(len(hist['History']['binary_accuray']))
