# %% [markdown]
# # UNET SEGMENTATION

# %%
## Imports
import os
import sys
import random
from glob import glob as glob
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import matplotlib
import matplotlib.image as Image
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split

tf.config.run_functions_eagerly(True)

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %% [markdown]
# ## Hyperparameters

# %%
dim = 224

# get image and mask files
image_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data_1plus\*_i*')
mask_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data_1plus\*_s*')

# splits into test and training datasets
train_imgs, test_imgs, train_masks, test_masks = train_test_split(image_files, mask_files, test_size = 0.33, random_state= 123)

print(len(train_imgs))

batch_size = 32

count = 0
ratios = None
# Out:
# 197

# %% [markdown]
# ## Data Generator

# %%
class DataGen(keras.utils.Sequence):
    def __init__(self, image_files, mask_files,  batch_size, hls = False):
        self.img_files = image_files
        self.mask_files = mask_files
        self.batch_size = batch_size
        self.num_files = len(image_files)

        self.hls = hls

        self.current_ratios = None

    def ratio_Imgs(self, masks):
        rs = []
        for i in masks:
            i = np.reshape(i, (dim, dim))

            r = sum(i > 0.5)/ dim **2

            rs.append(r)
        
        self.current_ratios = np.array(rs)
        global ratios
        ratios = self.current_ratios


    def __getitem__(self, index):
        'Returns batch of images and labels'

        this_batch = self.batch_size
        # Changes batch size for final batch (no data missed)
        if(index+1)*self.batch_size > self.num_files:
            this_batch = self.num_files - index*self.batch_size
        
        # sets limits for batch
        start = index*self.batch_size
        stop = start + this_batch

        # takes images and masks files within batch
        img_batch = self.img_files[start : stop]
        mask_batch = self.mask_files[start : stop]

        images = []
        masks  = []
        
        # loads images and files and adds them to list
        for i, (img_file, mask_file) in enumerate(zip(img_batch,mask_batch)):
            # Normalises
            img = cv2.imread(img_file) 
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            if self.hls:
                img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
            
            img = img / 255

            mask = cv2.imread(mask_file, 0) / 255
            mask = np.array(mask, dtype=np.float32)
            mask = np.reshape(mask, (mask.shape[0], mask.shape[1], 1))
            images.append(img)
            masks.append(mask)
            
        images = np.array(images)
        #image = np.reshape(image, (batch_size, 256, 256, 1))
        masks  = np.array(masks)
        
        self.ratio_Imgs(masks)

        return images, masks
    
    def on_epoch_end(self):
        global count
        count = 0
    
    def __len__(self):
        'Returns Number of batches'
        return int(np.ceil(self.num_files // self.batch_size))

# %%
# data loader obj is created with training images and masks
gen = DataGen(image_files=train_imgs, mask_files=train_masks, batch_size=batch_size)
x, y = gen.__getitem__(0)
print(x.shape, y.shape)
# Out:
# (32, 224, 224, 3) (32, 224, 224, 1)

# %%
r = random.randint(0, len(x)-1)

fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(1, 2, 1)
ax.imshow(x[r])
ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(y[r], (dim, dim)), cmap="gray")

# %% [markdown]
# ## Different Convolutional Blocks

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %% [markdown]
# ## UNet Model

# %%
def UNet(image_size):
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    bn = bottleneck(p4, f[4])
    
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(1, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %% [markdown]
# ## Loss Function

# %%
#from keras import saving

# @keras.saving.register_keras_serializable()
def weighted_bincrossentropy(true, pred):
    """
    Calculates weighted binary cross entropy. The weights are fixed.
        
    This can be useful for unbalanced catagories.
    
    Adjust the weights here depending on what is required.
    
    For example if there are 10x as many positive classes as negative classes,
        if you adjust weight_zero = 1.0, weight_one = 0.1, then false positives 
        will be penalize 10 times as much as false negatives.
    """
    # y = keras.backend.flatten(true)
    # r = np.max(((keras.backend.sum(y).numpy()/dim**2)**3, 1e-8))
    # calculate the binary cross entropy
    bin_crossentropy = keras.backend.binary_crossentropy(true, pred)
    
    # apply the weights
    weights = true * np.log(13) + (1. - true) * 0.5
    weighted_bin_crossentropy = weights * bin_crossentropy 

    return keras.backend.mean(weighted_bin_crossentropy)

# @keras.saving.register_keras_serializable()
def mean_iou_loss(y_true, y_pred):

    pred_sum = keras.backend.sum(y_pred)
    gt_sum = keras.backend.sum(y_true)
    intersection = keras.backend.sum(tf.math.multiply(y_true,y_pred))
    
    union = pred_sum + gt_sum - intersection

    iou = intersection/union
    return 1 - iou

# @keras.saving.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1):
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)
    intersection = keras.backend.sum(y_true * y_pred, axis=[1,2,3])
    union = keras.backend.sum(y_true, axis=[1,2,3]) + keras.backend.sum(y_pred, axis=[1,2,3])
    return keras.backend.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# @keras.saving.register_keras_serializable()
def dice_loss(in_gt, in_pred):
    return 1 - dice_coef(in_gt, in_pred)

# @keras.saving.register_keras_serializable()
def dice_p_bce(in_gt, in_pred):
    """combine DICE and BCE"""
    # 0.01*keras.losses.binary_crossentropy(in_gt, in_pred)
    return 0.01*weighted_bincrossentropy(in_gt, in_pred) + (1- dice_coef(in_gt, in_pred))

# @keras.saving.register_keras_serializable()
def true_positive_rate(y_true, y_pred):
    return keras.backend.sum(keras.backend.flatten(y_true)*keras.backend.flatten(keras.backend.round(y_pred)))/keras.backend.sum(y_true)

# @keras.saving.register_keras_serializable()
def dice_mean_iou(in_gt, in_pred):
    return (dice_loss(in_gt, in_pred) + mean_iou_loss(in_gt, in_pred)) / 2

# %%
model = UNet(dim)
# learning_rate = learning_rate=0.0001
learning_rate = 0.0001
opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# opt = tf.keras.optimizers.SGD(learning_rate = 0.00001)
# model.compile(optimizer = opt, loss=weighted_bincrossentropy, metrics=["acc"])
cce = keras.losses.CategoricalFocalCrossentropy()

use_loss = dice_mean_iou
print(use_loss.__name__)
model.compile(optimizer = opt, loss=use_loss, metrics=[dice_coef, 'binary_accuracy', dice_p_bce, dice_loss, true_positive_rate, weighted_bincrossentropy])
model.summary()
# Out:
# dice_mean_iou
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 224, 224,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 224, 224,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 112, 112,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 112, 112,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 112, 112,  │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 56, 56,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 28, 28,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 14, 14,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 14, 14,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 14, 14,    │    590,080 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 28, 28,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 28, 28,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │    147,584 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 56, 56,    │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 56, 56,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 56, 56,    │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 56, 56,    │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 112, 112,  │          0 │ conv2d_13[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 112, 112,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 112, 112,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 112, 112,  │      9,248 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 224, 224,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 224, 224,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 224, 224,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 224, 224,  │      2,320 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 224, 224,  │         17 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,625 (7.49 MB)
#  Trainable params: 1,962,625 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the model

# %%
train_gen = DataGen(train_imgs, train_masks, batch_size= batch_size, hls = False)
valid_gen = DataGen(test_imgs, test_masks, batch_size=batch_size, hls = False)

from sklearn.utils import class_weight
x, y = train_gen.__getitem__(5)

w1s = []
w2s = []
for i in y:
    i = np.reshape(i, (dim,dim))
    if np.sum(i) != 0:
        w1s.append(dim**2/(2 * np.sum(i)) )
        w2s.append(dim**2/(2 * (dim**2 - sum(i))))

print(np.mean(w1s), np.mean(w2s))


rs = []
for i in range(len(train_gen)):
    _, masks = train_gen.__getitem__(i)

    for j in masks:
        j = np.reshape(j, (dim,dim))
        r = sum(j > 0.5) / dim**2
        rs.append(r)

r = np.mean(rs)
print(r)
# Out:
# 20.169705912966954 0.50007147
# 0.00012771265383943755

# %%
model_num = 11

# %%
history = model.fit(train_gen, batch_size=batch_size, epochs = 500, validation_data= valid_gen)
# Out:
# Epoch 1/500
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - binary_accuracy: 0.0316 - dice_coef: 0.0519 - dice_loss: 0.9481 - dice_p_bce: 0.9520 - loss: 0.9604 - true_positive_rate: 0.9997 - weighted_bincrossentropy: 0.3962 - val_binary_accuracy: 0.0367 - val_dice_coef: 0.0584 - val_dice_loss: 0.9416 - val_dice_p_bce: 0.9456 - val_loss: 0.9555 - val_true_positive_rate: 0.9990 - val_weighted_bincrossentropy: 0.3969
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.0350 - dice_coef: 0.0517 - dice_loss: 0.9483 - dice_p_bce: 0.9522 - loss: 0.9606 - true_positive_rate: 0.9986 - weighted_bincrossentropy: 0.3907 - val_binary_accuracy: 0.0554 - val_dice_coef: 0.0588 - val_dice_loss: 0.9412 - val_dice_p_bce: 0.9452 - val_loss: 0.9551 - val_true_positive_rate: 0.9992 - val_weighted_bincrossentropy: 0.3950
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.1765 - dice_coef: 0.0520 - dice_loss: 0.9480 - dice_p_bce: 0.9518 - loss: 0.9604 - true_positive_rate: 0.9992 - weighted_bincrossentropy: 0.3890 - val_binary_accuracy: 0.4432 - val_dice_coef: 0.0594 - val_dice_loss: 0.9406 - val_dice_p_bce: 0.9446 - val_loss: 0.9547 - val_true_positive_rate: 0.9997 - val_weighted_bincrossentropy: 0.3942
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.4574 - dice_coef: 0.0546 - dice_loss: 0.9454 - dice_p_bce: 0.9493 - loss: 0.9584 - true_positive_rate: 0.9996 - weighted_bincrossentropy: 0.3901 - val_binary_accuracy: 0.4957 - val_dice_coef: 0.0604 - val_dice_loss: 0.9396 - val_dice_p_bce: 0.9436 - val_loss: 0.9539 - val_true_positive_rate: 0.9999 - val_weighted_bincrossentropy: 0.3944
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.5150 - dice_coef: 0.0557 - dice_loss: 0.9443 - dice_p_bce: 0.9482 - loss: 0.9575 - true_positive_rate: 0.9997 - weighted_bincrossentropy: 0.3902 - val_binary_accuracy: 0.5631 - val_dice_coef: 0.0630 - val_dice_loss: 0.9370 - val_dice_p_bce: 0.9409 - val_loss: 0.9519 - val_true_positive_rate: 0.9998 - val_weighted_bincrossentropy: 0.3939
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.5547 - dice_coef: 0.0591 - dice_loss: 0.9409 - dice_p_bce: 0.9448 - loss: 0.9549 - true_positive_rate: 0.9995 - weighted_bincrossentropy: 0.3925 - val_binary_accuracy: 0.5471 - val_dice_coef: 0.0745 - val_dice_loss: 0.9255 - val_dice_p_bce: 0.9296 - val_loss: 0.9429 - val_true_positive_rate: 0.9992 - val_weighted_bincrossentropy: 0.4174
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.6012 - dice_coef: 0.0776 - dice_loss: 0.9224 - dice_p_bce: 0.9268 - loss: 0.9406 - true_positive_rate: 0.9909 - weighted_bincrossentropy: 0.4388 - val_binary_accuracy: 0.7918 - val_dice_coef: 0.1123 - val_dice_loss: 0.8877 - val_dice_p_bce: 0.8918 - val_loss: 0.9132 - val_true_positive_rate: 0.7770 - val_weighted_bincrossentropy: 0.4070
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.7804 - dice_coef: 0.1101 - dice_loss: 0.8899 - dice_p_bce: 0.8948 - loss: 0.9150 - true_positive_rate: 0.7963 - weighted_bincrossentropy: 0.4905 - val_binary_accuracy: 0.7996 - val_dice_coef: 0.1786 - val_dice_loss: 0.8214 - val_dice_p_bce: 0.8281 - val_loss: 0.8620 - val_true_positive_rate: 0.7677 - val_weighted_bincrossentropy: 0.6656
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8170 - dice_coef: 0.1690 - dice_loss: 0.8310 - dice_p_bce: 0.8380 - loss: 0.8699 - true_positive_rate: 0.7097 - weighted_bincrossentropy: 0.7026 - val_binary_accuracy: 0.7631 - val_dice_coef: 0.1900 - val_dice_loss: 0.8100 - val_dice_p_bce: 0.8226 - val_loss: 0.8533 - val_true_positive_rate: 0.8901 - val_weighted_bincrossentropy: 1.2674
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8038 - dice_coef: 0.1862 - dice_loss: 0.8138 - dice_p_bce: 0.8246 - loss: 0.8557 - true_positive_rate: 0.7688 - weighted_bincrossentropy: 1.0775 - val_binary_accuracy: 0.7704 - val_dice_coef: 0.1963 - val_dice_loss: 0.8037 - val_dice_p_bce: 0.8172 - val_loss: 0.8482 - val_true_positive_rate: 0.8850 - val_weighted_bincrossentropy: 1.3558
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8200 - dice_coef: 0.1938 - dice_loss: 0.8062 - dice_p_bce: 0.8172 - loss: 0.8496 - true_positive_rate: 0.7297 - weighted_bincrossentropy: 1.1046 - val_binary_accuracy: 0.7704 - val_dice_coef: 0.1982 - val_dice_loss: 0.8018 - val_dice_p_bce: 0.8158 - val_loss: 0.8464 - val_true_positive_rate: 0.8948 - val_weighted_bincrossentropy: 1.4040
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8230 - dice_coef: 0.1942 - dice_loss: 0.8058 - dice_p_bce: 0.8170 - loss: 0.8494 - true_positive_rate: 0.7371 - weighted_bincrossentropy: 1.1279 - val_binary_accuracy: 0.7846 - val_dice_coef: 0.2066 - val_dice_loss: 0.7934 - val_dice_p_bce: 0.8066 - val_loss: 0.8395 - val_true_positive_rate: 0.8853 - val_weighted_bincrossentropy: 1.3245
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8246 - dice_coef: 0.2016 - dice_loss: 0.7984 - dice_p_bce: 0.8096 - loss: 0.8426 - true_positive_rate: 0.7543 - weighted_bincrossentropy: 1.1236 - val_binary_accuracy: 0.8297 - val_dice_coef: 0.2235 - val_dice_loss: 0.7765 - val_dice_p_bce: 0.7868 - val_loss: 0.8248 - val_true_positive_rate: 0.7901 - val_weighted_bincrossentropy: 1.0305
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8472 - dice_coef: 0.2136 - dice_loss: 0.7864 - dice_p_bce: 0.7954 - loss: 0.8329 - true_positive_rate: 0.7375 - weighted_bincrossentropy: 0.9017 - val_binary_accuracy: 0.8355 - val_dice_coef: 0.2295 - val_dice_loss: 0.7705 - val_dice_p_bce: 0.7788 - val_loss: 0.8176 - val_true_positive_rate: 0.8229 - val_weighted_bincrossentropy: 0.8325
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8475 - dice_coef: 0.2058 - dice_loss: 0.7942 - dice_p_bce: 0.8028 - loss: 0.8357 - true_positive_rate: 0.7200 - weighted_bincrossentropy: 0.8587 - val_binary_accuracy: 0.8830 - val_dice_coef: 0.2292 - val_dice_loss: 0.7708 - val_dice_p_bce: 0.7783 - val_loss: 0.8155 - val_true_positive_rate: 0.6077 - val_weighted_bincrossentropy: 0.7487
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8823 - dice_coef: 0.2190 - dice_loss: 0.7810 - dice_p_bce: 0.7883 - loss: 0.8267 - true_positive_rate: 0.6130 - weighted_bincrossentropy: 0.7338 - val_binary_accuracy: 0.8317 - val_dice_coef: 0.2334 - val_dice_loss: 0.7666 - val_dice_p_bce: 0.7759 - val_loss: 0.8157 - val_true_positive_rate: 0.8386 - val_weighted_bincrossentropy: 0.9289
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8590 - dice_coef: 0.2258 - dice_loss: 0.7742 - dice_p_bce: 0.7822 - loss: 0.8202 - true_positive_rate: 0.7310 - weighted_bincrossentropy: 0.8008 - val_binary_accuracy: 0.8745 - val_dice_coef: 0.2492 - val_dice_loss: 0.7508 - val_dice_p_bce: 0.7570 - val_loss: 0.7977 - val_true_positive_rate: 0.7371 - val_weighted_bincrossentropy: 0.6231
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8884 - dice_coef: 0.2436 - dice_loss: 0.7564 - dice_p_bce: 0.7618 - loss: 0.8003 - true_positive_rate: 0.6933 - weighted_bincrossentropy: 0.5472 - val_binary_accuracy: 0.9360 - val_dice_coef: 0.2795 - val_dice_loss: 0.7205 - val_dice_p_bce: 0.7242 - val_loss: 0.7535 - val_true_positive_rate: 0.5717 - val_weighted_bincrossentropy: 0.3761
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8633 - dice_coef: 0.1793 - dice_loss: 0.8207 - dice_p_bce: 0.8284 - loss: 0.8365 - true_positive_rate: 0.5641 - weighted_bincrossentropy: 0.7746 - val_binary_accuracy: 0.4681 - val_dice_coef: 0.1035 - val_dice_loss: 0.8965 - val_dice_p_bce: 0.9244 - val_loss: 0.9204 - val_true_positive_rate: 0.9986 - val_weighted_bincrossentropy: 2.7936
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.6030 - dice_coef: 0.1345 - dice_loss: 0.8655 - dice_p_bce: 0.8864 - loss: 0.8954 - true_positive_rate: 0.9545 - weighted_bincrossentropy: 2.0863 - val_binary_accuracy: 0.9580 - val_dice_coef: 0.1665 - val_dice_loss: 0.8335 - val_dice_p_bce: 0.8414 - val_loss: 0.8354 - val_true_positive_rate: 0.2639 - val_weighted_bincrossentropy: 0.7906
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9283 - dice_coef: 0.1917 - dice_loss: 0.8083 - dice_p_bce: 0.8150 - loss: 0.8309 - true_positive_rate: 0.4251 - weighted_bincrossentropy: 0.6711 - val_binary_accuracy: 0.7996 - val_dice_coef: 0.2264 - val_dice_loss: 0.7736 - val_dice_p_bce: 0.7823 - val_loss: 0.8231 - val_true_positive_rate: 0.9314 - val_weighted_bincrossentropy: 0.8753
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8086 - dice_coef: 0.2195 - dice_loss: 0.7805 - dice_p_bce: 0.7887 - loss: 0.8284 - true_positive_rate: 0.9106 - weighted_bincrossentropy: 0.8210 - val_binary_accuracy: 0.8796 - val_dice_coef: 0.2519 - val_dice_loss: 0.7481 - val_dice_p_bce: 0.7537 - val_loss: 0.7971 - val_true_positive_rate: 0.6986 - val_weighted_bincrossentropy: 0.5615
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9076 - dice_coef: 0.2383 - dice_loss: 0.7617 - dice_p_bce: 0.7670 - loss: 0.8032 - true_positive_rate: 0.5836 - weighted_bincrossentropy: 0.5232 - val_binary_accuracy: 0.9501 - val_dice_coef: 0.2740 - val_dice_loss: 0.7260 - val_dice_p_bce: 0.7307 - val_loss: 0.7474 - val_true_positive_rate: 0.4884 - val_weighted_bincrossentropy: 0.4672
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9402 - dice_coef: 0.2946 - dice_loss: 0.7054 - dice_p_bce: 0.7092 - loss: 0.7449 - true_positive_rate: 0.5792 - weighted_bincrossentropy: 0.3829 - val_binary_accuracy: 0.9571 - val_dice_coef: 0.3337 - val_dice_loss: 0.6663 - val_dice_p_bce: 0.6697 - val_loss: 0.6955 - val_true_positive_rate: 0.5421 - val_weighted_bincrossentropy: 0.3381
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9537 - dice_coef: 0.3110 - dice_loss: 0.6890 - dice_p_bce: 0.6923 - loss: 0.7274 - true_positive_rate: 0.5363 - weighted_bincrossentropy: 0.3238 - val_binary_accuracy: 0.9527 - val_dice_coef: 0.3828 - val_dice_loss: 0.6172 - val_dice_p_bce: 0.6204 - val_loss: 0.6681 - val_true_positive_rate: 0.6068 - val_weighted_bincrossentropy: 0.3122
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9546 - dice_coef: 0.3522 - dice_loss: 0.6478 - dice_p_bce: 0.6510 - loss: 0.6986 - true_positive_rate: 0.5655 - weighted_bincrossentropy: 0.3219 - val_binary_accuracy: 0.9603 - val_dice_coef: 0.3849 - val_dice_loss: 0.6151 - val_dice_p_bce: 0.6191 - val_loss: 0.6589 - val_true_positive_rate: 0.5431 - val_weighted_bincrossentropy: 0.3946
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9558 - dice_coef: 0.3820 - dice_loss: 0.6180 - dice_p_bce: 0.6217 - loss: 0.6703 - true_positive_rate: 0.5840 - weighted_bincrossentropy: 0.3725 - val_binary_accuracy: 0.9636 - val_dice_coef: 0.3768 - val_dice_loss: 0.6232 - val_dice_p_bce: 0.6273 - val_loss: 0.6568 - val_true_positive_rate: 0.5235 - val_weighted_bincrossentropy: 0.4142
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9591 - dice_coef: 0.3957 - dice_loss: 0.6043 - dice_p_bce: 0.6080 - loss: 0.6566 - true_positive_rate: 0.5841 - weighted_bincrossentropy: 0.3702 - val_binary_accuracy: 0.9586 - val_dice_coef: 0.4375 - val_dice_loss: 0.5625 - val_dice_p_bce: 0.5656 - val_loss: 0.6173 - val_true_positive_rate: 0.6521 - val_weighted_bincrossentropy: 0.3075
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9606 - dice_coef: 0.4159 - dice_loss: 0.5841 - dice_p_bce: 0.5873 - loss: 0.6386 - true_positive_rate: 0.6212 - weighted_bincrossentropy: 0.3139 - val_binary_accuracy: 0.9667 - val_dice_coef: 0.4141 - val_dice_loss: 0.5859 - val_dice_p_bce: 0.5896 - val_loss: 0.6312 - val_true_positive_rate: 0.5133 - val_weighted_bincrossentropy: 0.3697
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9639 - dice_coef: 0.4287 - dice_loss: 0.5713 - dice_p_bce: 0.5743 - loss: 0.6295 - true_positive_rate: 0.5901 - weighted_bincrossentropy: 0.3084 - val_binary_accuracy: 0.9462 - val_dice_coef: 0.4437 - val_dice_loss: 0.5563 - val_dice_p_bce: 0.5586 - val_loss: 0.6205 - val_true_positive_rate: 0.8106 - val_weighted_bincrossentropy: 0.2247
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9542 - dice_coef: 0.4359 - dice_loss: 0.5641 - dice_p_bce: 0.5667 - loss: 0.6264 - true_positive_rate: 0.7026 - weighted_bincrossentropy: 0.2522 - val_binary_accuracy: 0.9648 - val_dice_coef: 0.4780 - val_dice_loss: 0.5220 - val_dice_p_bce: 0.5245 - val_loss: 0.5814 - val_true_positive_rate: 0.6431 - val_weighted_bincrossentropy: 0.2498
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9666 - dice_coef: 0.4528 - dice_loss: 0.5472 - dice_p_bce: 0.5495 - loss: 0.6073 - true_positive_rate: 0.6299 - weighted_bincrossentropy: 0.2293 - val_binary_accuracy: 0.9707 - val_dice_coef: 0.4094 - val_dice_loss: 0.5906 - val_dice_p_bce: 0.5940 - val_loss: 0.6357 - val_true_positive_rate: 0.4475 - val_weighted_bincrossentropy: 0.3469
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9670 - dice_coef: 0.4503 - dice_loss: 0.5497 - dice_p_bce: 0.5523 - loss: 0.6121 - true_positive_rate: 0.5834 - weighted_bincrossentropy: 0.2585 - val_binary_accuracy: 0.9695 - val_dice_coef: 0.4642 - val_dice_loss: 0.5358 - val_dice_p_bce: 0.5385 - val_loss: 0.5866 - val_true_positive_rate: 0.5656 - val_weighted_bincrossentropy: 0.2725
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9688 - dice_coef: 0.4794 - dice_loss: 0.5206 - dice_p_bce: 0.5228 - loss: 0.5848 - true_positive_rate: 0.6346 - weighted_bincrossentropy: 0.2187 - val_binary_accuracy: 0.9703 - val_dice_coef: 0.4889 - val_dice_loss: 0.5111 - val_dice_p_bce: 0.5136 - val_loss: 0.5680 - val_true_positive_rate: 0.5838 - val_weighted_bincrossentropy: 0.2459
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9693 - dice_coef: 0.4960 - dice_loss: 0.5040 - dice_p_bce: 0.5061 - loss: 0.5709 - true_positive_rate: 0.6352 - weighted_bincrossentropy: 0.2052 - val_binary_accuracy: 0.9678 - val_dice_coef: 0.5333 - val_dice_loss: 0.4667 - val_dice_p_bce: 0.4684 - val_loss: 0.5348 - val_true_positive_rate: 0.7050 - val_weighted_bincrossentropy: 0.1681
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9680 - dice_coef: 0.5268 - dice_loss: 0.4732 - dice_p_bce: 0.4749 - loss: 0.5450 - true_positive_rate: 0.6938 - weighted_bincrossentropy: 0.1653 - val_binary_accuracy: 0.9698 - val_dice_coef: 0.5477 - val_dice_loss: 0.4523 - val_dice_p_bce: 0.4538 - val_loss: 0.5194 - val_true_positive_rate: 0.7104 - val_weighted_bincrossentropy: 0.1525
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9717 - dice_coef: 0.5381 - dice_loss: 0.4619 - dice_p_bce: 0.4634 - loss: 0.5319 - true_positive_rate: 0.6937 - weighted_bincrossentropy: 0.1482 - val_binary_accuracy: 0.9693 - val_dice_coef: 0.5608 - val_dice_loss: 0.4392 - val_dice_p_bce: 0.4406 - val_loss: 0.5078 - val_true_positive_rate: 0.7561 - val_weighted_bincrossentropy: 0.1396
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9735 - dice_coef: 0.5593 - dice_loss: 0.4407 - dice_p_bce: 0.4421 - loss: 0.5121 - true_positive_rate: 0.7075 - weighted_bincrossentropy: 0.1420 - val_binary_accuracy: 0.9606 - val_dice_coef: 0.5372 - val_dice_loss: 0.4628 - val_dice_p_bce: 0.4640 - val_loss: 0.5331 - val_true_positive_rate: 0.8744 - val_weighted_bincrossentropy: 0.1170
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9699 - dice_coef: 0.5597 - dice_loss: 0.4403 - dice_p_bce: 0.4416 - loss: 0.5124 - true_positive_rate: 0.7527 - weighted_bincrossentropy: 0.1313 - val_binary_accuracy: 0.9704 - val_dice_coef: 0.5833 - val_dice_loss: 0.4167 - val_dice_p_bce: 0.4180 - val_loss: 0.4858 - val_true_positive_rate: 0.7909 - val_weighted_bincrossentropy: 0.1250
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9741 - dice_coef: 0.5941 - dice_loss: 0.4059 - dice_p_bce: 0.4072 - loss: 0.4781 - true_positive_rate: 0.7404 - weighted_bincrossentropy: 0.1316 - val_binary_accuracy: 0.9766 - val_dice_coef: 0.5940 - val_dice_loss: 0.4060 - val_dice_p_bce: 0.4074 - val_loss: 0.4699 - val_true_positive_rate: 0.6887 - val_weighted_bincrossentropy: 0.1349
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9770 - dice_coef: 0.5887 - dice_loss: 0.4113 - dice_p_bce: 0.4125 - loss: 0.4810 - true_positive_rate: 0.7162 - weighted_bincrossentropy: 0.1198 - val_binary_accuracy: 0.9740 - val_dice_coef: 0.6113 - val_dice_loss: 0.3887 - val_dice_p_bce: 0.3898 - val_loss: 0.4567 - val_true_positive_rate: 0.7875 - val_weighted_bincrossentropy: 0.1159
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9766 - dice_coef: 0.6051 - dice_loss: 0.3949 - dice_p_bce: 0.3961 - loss: 0.4668 - true_positive_rate: 0.7285 - weighted_bincrossentropy: 0.1263 - val_binary_accuracy: 0.9783 - val_dice_coef: 0.6091 - val_dice_loss: 0.3909 - val_dice_p_bce: 0.3923 - val_loss: 0.4535 - val_true_positive_rate: 0.6819 - val_weighted_bincrossentropy: 0.1384
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9776 - dice_coef: 0.5953 - dice_loss: 0.4047 - dice_p_bce: 0.4059 - loss: 0.4743 - true_positive_rate: 0.7320 - weighted_bincrossentropy: 0.1207 - val_binary_accuracy: 0.9746 - val_dice_coef: 0.6241 - val_dice_loss: 0.3759 - val_dice_p_bce: 0.3769 - val_loss: 0.4442 - val_true_positive_rate: 0.8189 - val_weighted_bincrossentropy: 0.0984
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9779 - dice_coef: 0.6226 - dice_loss: 0.3774 - dice_p_bce: 0.3784 - loss: 0.4472 - true_positive_rate: 0.7720 - weighted_bincrossentropy: 0.1012 - val_binary_accuracy: 0.9775 - val_dice_coef: 0.6366 - val_dice_loss: 0.3634 - val_dice_p_bce: 0.3645 - val_loss: 0.4302 - val_true_positive_rate: 0.7630 - val_weighted_bincrossentropy: 0.1163
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9797 - dice_coef: 0.6356 - dice_loss: 0.3644 - dice_p_bce: 0.3655 - loss: 0.4337 - true_positive_rate: 0.7432 - weighted_bincrossentropy: 0.1114 - val_binary_accuracy: 0.9790 - val_dice_coef: 0.6452 - val_dice_loss: 0.3548 - val_dice_p_bce: 0.3559 - val_loss: 0.4198 - val_true_positive_rate: 0.7516 - val_weighted_bincrossentropy: 0.1126
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9806 - dice_coef: 0.6427 - dice_loss: 0.3573 - dice_p_bce: 0.3584 - loss: 0.4245 - true_positive_rate: 0.7454 - weighted_bincrossentropy: 0.1077 - val_binary_accuracy: 0.9790 - val_dice_coef: 0.6527 - val_dice_loss: 0.3473 - val_dice_p_bce: 0.3484 - val_loss: 0.4135 - val_true_positive_rate: 0.7644 - val_weighted_bincrossentropy: 0.1120
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9818 - dice_coef: 0.6540 - dice_loss: 0.3460 - dice_p_bce: 0.3470 - loss: 0.4146 - true_positive_rate: 0.7457 - weighted_bincrossentropy: 0.1050 - val_binary_accuracy: 0.9781 - val_dice_coef: 0.6576 - val_dice_loss: 0.3424 - val_dice_p_bce: 0.3434 - val_loss: 0.4085 - val_true_positive_rate: 0.8144 - val_weighted_bincrossentropy: 0.0963
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9802 - dice_coef: 0.6579 - dice_loss: 0.3421 - dice_p_bce: 0.3431 - loss: 0.4092 - true_positive_rate: 0.7863 - weighted_bincrossentropy: 0.1002 - val_binary_accuracy: 0.9799 - val_dice_coef: 0.6657 - val_dice_loss: 0.3343 - val_dice_p_bce: 0.3354 - val_loss: 0.3994 - val_true_positive_rate: 0.7745 - val_weighted_bincrossentropy: 0.1092
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9818 - dice_coef: 0.6707 - dice_loss: 0.3293 - dice_p_bce: 0.3302 - loss: 0.3976 - true_positive_rate: 0.7736 - weighted_bincrossentropy: 0.0985 - val_binary_accuracy: 0.9808 - val_dice_coef: 0.6712 - val_dice_loss: 0.3288 - val_dice_p_bce: 0.3299 - val_loss: 0.3922 - val_true_positive_rate: 0.7706 - val_weighted_bincrossentropy: 0.1061
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9818 - dice_coef: 0.6780 - dice_loss: 0.3220 - dice_p_bce: 0.3230 - loss: 0.3894 - true_positive_rate: 0.7797 - weighted_bincrossentropy: 0.0973 - val_binary_accuracy: 0.9794 - val_dice_coef: 0.6721 - val_dice_loss: 0.3279 - val_dice_p_bce: 0.3288 - val_loss: 0.3936 - val_true_positive_rate: 0.8200 - val_weighted_bincrossentropy: 0.0907
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9818 - dice_coef: 0.6857 - dice_loss: 0.3143 - dice_p_bce: 0.3153 - loss: 0.3812 - true_positive_rate: 0.7864 - weighted_bincrossentropy: 0.0974 - val_binary_accuracy: 0.9811 - val_dice_coef: 0.6822 - val_dice_loss: 0.3178 - val_dice_p_bce: 0.3187 - val_loss: 0.3813 - val_true_positive_rate: 0.7942 - val_weighted_bincrossentropy: 0.0985
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9832 - dice_coef: 0.6892 - dice_loss: 0.3108 - dice_p_bce: 0.3118 - loss: 0.3782 - true_positive_rate: 0.7805 - weighted_bincrossentropy: 0.0934 - val_binary_accuracy: 0.9818 - val_dice_coef: 0.6869 - val_dice_loss: 0.3131 - val_dice_p_bce: 0.3142 - val_loss: 0.3762 - val_true_positive_rate: 0.7820 - val_weighted_bincrossentropy: 0.1024
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9826 - dice_coef: 0.6886 - dice_loss: 0.3114 - dice_p_bce: 0.3124 - loss: 0.3782 - true_positive_rate: 0.7803 - weighted_bincrossentropy: 0.0990 - val_binary_accuracy: 0.9815 - val_dice_coef: 0.6905 - val_dice_loss: 0.3095 - val_dice_p_bce: 0.3105 - val_loss: 0.3729 - val_true_positive_rate: 0.8054 - val_weighted_bincrossentropy: 0.0937
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9831 - dice_coef: 0.6824 - dice_loss: 0.3176 - dice_p_bce: 0.3185 - loss: 0.3835 - true_positive_rate: 0.7902 - weighted_bincrossentropy: 0.0916 - val_binary_accuracy: 0.9833 - val_dice_coef: 0.6809 - val_dice_loss: 0.3191 - val_dice_p_bce: 0.3205 - val_loss: 0.3814 - val_true_positive_rate: 0.6989 - val_weighted_bincrossentropy: 0.1345
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9834 - dice_coef: 0.6871 - dice_loss: 0.3129 - dice_p_bce: 0.3140 - loss: 0.3799 - true_positive_rate: 0.7434 - weighted_bincrossentropy: 0.1104 - val_binary_accuracy: 0.9834 - val_dice_coef: 0.6910 - val_dice_loss: 0.3090 - val_dice_p_bce: 0.3101 - val_loss: 0.3695 - val_true_positive_rate: 0.7458 - val_weighted_bincrossentropy: 0.1093
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9843 - dice_coef: 0.6937 - dice_loss: 0.3063 - dice_p_bce: 0.3072 - loss: 0.3727 - true_positive_rate: 0.7775 - weighted_bincrossentropy: 0.0898 - val_binary_accuracy: 0.9792 - val_dice_coef: 0.6852 - val_dice_loss: 0.3148 - val_dice_p_bce: 0.3156 - val_loss: 0.3818 - val_true_positive_rate: 0.8636 - val_weighted_bincrossentropy: 0.0783
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9822 - dice_coef: 0.6824 - dice_loss: 0.3176 - dice_p_bce: 0.3185 - loss: 0.3851 - true_positive_rate: 0.8062 - weighted_bincrossentropy: 0.0870 - val_binary_accuracy: 0.9817 - val_dice_coef: 0.6987 - val_dice_loss: 0.3013 - val_dice_p_bce: 0.3024 - val_loss: 0.3646 - val_true_positive_rate: 0.8135 - val_weighted_bincrossentropy: 0.1022
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9834 - dice_coef: 0.6982 - dice_loss: 0.3018 - dice_p_bce: 0.3029 - loss: 0.3659 - true_positive_rate: 0.7783 - weighted_bincrossentropy: 0.1056 - val_binary_accuracy: 0.9835 - val_dice_coef: 0.7034 - val_dice_loss: 0.2966 - val_dice_p_bce: 0.2976 - val_loss: 0.3576 - val_true_positive_rate: 0.7811 - val_weighted_bincrossentropy: 0.0938
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step - binary_accuracy: 0.9851 - dice_coef: 0.7023 - dice_loss: 0.2977 - dice_p_bce: 0.2986 - loss: 0.3625 - true_positive_rate: 0.7782 - weighted_bincrossentropy: 0.0851 - val_binary_accuracy: 0.9822 - val_dice_coef: 0.7065 - val_dice_loss: 0.2935 - val_dice_p_bce: 0.2944 - val_loss: 0.3571 - val_true_positive_rate: 0.8238 - val_weighted_bincrossentropy: 0.0889
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9841 - dice_coef: 0.7124 - dice_loss: 0.2876 - dice_p_bce: 0.2886 - loss: 0.3522 - true_positive_rate: 0.7974 - weighted_bincrossentropy: 0.0906 - val_binary_accuracy: 0.9843 - val_dice_coef: 0.7115 - val_dice_loss: 0.2885 - val_dice_p_bce: 0.2895 - val_loss: 0.3496 - val_true_positive_rate: 0.7651 - val_weighted_bincrossentropy: 0.1009
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9849 - dice_coef: 0.7191 - dice_loss: 0.2809 - dice_p_bce: 0.2818 - loss: 0.3442 - true_positive_rate: 0.7868 - weighted_bincrossentropy: 0.0901 - val_binary_accuracy: 0.9841 - val_dice_coef: 0.7160 - val_dice_loss: 0.2840 - val_dice_p_bce: 0.2850 - val_loss: 0.3446 - val_true_positive_rate: 0.7810 - val_weighted_bincrossentropy: 0.1011
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9853 - dice_coef: 0.7235 - dice_loss: 0.2765 - dice_p_bce: 0.2774 - loss: 0.3403 - true_positive_rate: 0.7946 - weighted_bincrossentropy: 0.0895 - val_binary_accuracy: 0.9841 - val_dice_coef: 0.7204 - val_dice_loss: 0.2796 - val_dice_p_bce: 0.2805 - val_loss: 0.3414 - val_true_positive_rate: 0.7957 - val_weighted_bincrossentropy: 0.0931
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9851 - dice_coef: 0.7304 - dice_loss: 0.2696 - dice_p_bce: 0.2704 - loss: 0.3338 - true_positive_rate: 0.8025 - weighted_bincrossentropy: 0.0864 - val_binary_accuracy: 0.9849 - val_dice_coef: 0.7162 - val_dice_loss: 0.2838 - val_dice_p_bce: 0.2849 - val_loss: 0.3444 - val_true_positive_rate: 0.7421 - val_weighted_bincrossentropy: 0.1146
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9859 - dice_coef: 0.7240 - dice_loss: 0.2760 - dice_p_bce: 0.2769 - loss: 0.3392 - true_positive_rate: 0.7735 - weighted_bincrossentropy: 0.0969 - val_binary_accuracy: 0.9823 - val_dice_coef: 0.7170 - val_dice_loss: 0.2830 - val_dice_p_bce: 0.2838 - val_loss: 0.3466 - val_true_positive_rate: 0.8591 - val_weighted_bincrossentropy: 0.0774
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9851 - dice_coef: 0.7306 - dice_loss: 0.2694 - dice_p_bce: 0.2702 - loss: 0.3341 - true_positive_rate: 0.8236 - weighted_bincrossentropy: 0.0805 - val_binary_accuracy: 0.9853 - val_dice_coef: 0.7170 - val_dice_loss: 0.2830 - val_dice_p_bce: 0.2842 - val_loss: 0.3433 - val_true_positive_rate: 0.7282 - val_weighted_bincrossentropy: 0.1216
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9862 - dice_coef: 0.7243 - dice_loss: 0.2757 - dice_p_bce: 0.2766 - loss: 0.3377 - true_positive_rate: 0.7716 - weighted_bincrossentropy: 0.0953 - val_binary_accuracy: 0.9836 - val_dice_coef: 0.7273 - val_dice_loss: 0.2727 - val_dice_p_bce: 0.2735 - val_loss: 0.3345 - val_true_positive_rate: 0.8421 - val_weighted_bincrossentropy: 0.0808
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9853 - dice_coef: 0.7319 - dice_loss: 0.2681 - dice_p_bce: 0.2689 - loss: 0.3320 - true_positive_rate: 0.8220 - weighted_bincrossentropy: 0.0815 - val_binary_accuracy: 0.9826 - val_dice_coef: 0.7211 - val_dice_loss: 0.2789 - val_dice_p_bce: 0.2797 - val_loss: 0.3427 - val_true_positive_rate: 0.8621 - val_weighted_bincrossentropy: 0.0743
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9864 - dice_coef: 0.7256 - dice_loss: 0.2744 - dice_p_bce: 0.2752 - loss: 0.3373 - true_positive_rate: 0.8005 - weighted_bincrossentropy: 0.0851 - val_binary_accuracy: 0.9855 - val_dice_coef: 0.7316 - val_dice_loss: 0.2684 - val_dice_p_bce: 0.2694 - val_loss: 0.3280 - val_true_positive_rate: 0.7677 - val_weighted_bincrossentropy: 0.1051
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9866 - dice_coef: 0.7390 - dice_loss: 0.2610 - dice_p_bce: 0.2619 - loss: 0.3232 - true_positive_rate: 0.7882 - weighted_bincrossentropy: 0.0900 - val_binary_accuracy: 0.9848 - val_dice_coef: 0.7368 - val_dice_loss: 0.2632 - val_dice_p_bce: 0.2640 - val_loss: 0.3241 - val_true_positive_rate: 0.8207 - val_weighted_bincrossentropy: 0.0838
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9866 - dice_coef: 0.7452 - dice_loss: 0.2548 - dice_p_bce: 0.2556 - loss: 0.3182 - true_positive_rate: 0.8170 - weighted_bincrossentropy: 0.0766 - val_binary_accuracy: 0.9850 - val_dice_coef: 0.7389 - val_dice_loss: 0.2611 - val_dice_p_bce: 0.2620 - val_loss: 0.3210 - val_true_positive_rate: 0.8215 - val_weighted_bincrossentropy: 0.0846
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9867 - dice_coef: 0.7450 - dice_loss: 0.2550 - dice_p_bce: 0.2558 - loss: 0.3163 - true_positive_rate: 0.8065 - weighted_bincrossentropy: 0.0819 - val_binary_accuracy: 0.9854 - val_dice_coef: 0.7421 - val_dice_loss: 0.2579 - val_dice_p_bce: 0.2587 - val_loss: 0.3170 - val_true_positive_rate: 0.8118 - val_weighted_bincrossentropy: 0.0881
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step - binary_accuracy: 0.9870 - dice_coef: 0.7499 - dice_loss: 0.2501 - dice_p_bce: 0.2509 - loss: 0.3116 - true_positive_rate: 0.8141 - weighted_bincrossentropy: 0.0798 - val_binary_accuracy: 0.9858 - val_dice_coef: 0.7449 - val_dice_loss: 0.2551 - val_dice_p_bce: 0.2560 - val_loss: 0.3145 - val_true_positive_rate: 0.8032 - val_weighted_bincrossentropy: 0.0899
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9872 - dice_coef: 0.7525 - dice_loss: 0.2475 - dice_p_bce: 0.2484 - loss: 0.3095 - true_positive_rate: 0.8009 - weighted_bincrossentropy: 0.0841 - val_binary_accuracy: 0.9851 - val_dice_coef: 0.7450 - val_dice_loss: 0.2550 - val_dice_p_bce: 0.2558 - val_loss: 0.3145 - val_true_positive_rate: 0.8371 - val_weighted_bincrossentropy: 0.0807
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9867 - dice_coef: 0.7562 - dice_loss: 0.2438 - dice_p_bce: 0.2446 - loss: 0.3044 - true_positive_rate: 0.8226 - weighted_bincrossentropy: 0.0798 - val_binary_accuracy: 0.9857 - val_dice_coef: 0.7489 - val_dice_loss: 0.2511 - val_dice_p_bce: 0.2520 - val_loss: 0.3101 - val_true_positive_rate: 0.8203 - val_weighted_bincrossentropy: 0.0854
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9874 - dice_coef: 0.7609 - dice_loss: 0.2391 - dice_p_bce: 0.2399 - loss: 0.3002 - true_positive_rate: 0.8202 - weighted_bincrossentropy: 0.0776 - val_binary_accuracy: 0.9856 - val_dice_coef: 0.7501 - val_dice_loss: 0.2499 - val_dice_p_bce: 0.2508 - val_loss: 0.3092 - val_true_positive_rate: 0.8312 - val_weighted_bincrossentropy: 0.0820
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - binary_accuracy: 0.9874 - dice_coef: 0.7611 - dice_loss: 0.2389 - dice_p_bce: 0.2397 - loss: 0.2998 - true_positive_rate: 0.8165 - weighted_bincrossentropy: 0.0801 - val_binary_accuracy: 0.9856 - val_dice_coef: 0.7513 - val_dice_loss: 0.2487 - val_dice_p_bce: 0.2495 - val_loss: 0.3072 - val_true_positive_rate: 0.8393 - val_weighted_bincrossentropy: 0.0786
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9875 - dice_coef: 0.7621 - dice_loss: 0.2379 - dice_p_bce: 0.2386 - loss: 0.2980 - true_positive_rate: 0.8260 - weighted_bincrossentropy: 0.0753 - val_binary_accuracy: 0.9859 - val_dice_coef: 0.7533 - val_dice_loss: 0.2467 - val_dice_p_bce: 0.2475 - val_loss: 0.3058 - val_true_positive_rate: 0.8254 - val_weighted_bincrossentropy: 0.0835
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9873 - dice_coef: 0.7663 - dice_loss: 0.2337 - dice_p_bce: 0.2345 - loss: 0.2930 - true_positive_rate: 0.8240 - weighted_bincrossentropy: 0.0802 - val_binary_accuracy: 0.9860 - val_dice_coef: 0.7556 - val_dice_loss: 0.2444 - val_dice_p_bce: 0.2452 - val_loss: 0.3027 - val_true_positive_rate: 0.8361 - val_weighted_bincrossentropy: 0.0794
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9878 - dice_coef: 0.7649 - dice_loss: 0.2351 - dice_p_bce: 0.2359 - loss: 0.2938 - true_positive_rate: 0.8231 - weighted_bincrossentropy: 0.0774 - val_binary_accuracy: 0.9866 - val_dice_coef: 0.7593 - val_dice_loss: 0.2407 - val_dice_p_bce: 0.2415 - val_loss: 0.2981 - val_true_positive_rate: 0.8201 - val_weighted_bincrossentropy: 0.0844
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9881 - dice_coef: 0.7698 - dice_loss: 0.2302 - dice_p_bce: 0.2309 - loss: 0.2891 - true_positive_rate: 0.8250 - weighted_bincrossentropy: 0.0756 - val_binary_accuracy: 0.9852 - val_dice_coef: 0.7518 - val_dice_loss: 0.2482 - val_dice_p_bce: 0.2489 - val_loss: 0.3075 - val_true_positive_rate: 0.8631 - val_weighted_bincrossentropy: 0.0736
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9875 - dice_coef: 0.7663 - dice_loss: 0.2337 - dice_p_bce: 0.2345 - loss: 0.2930 - true_positive_rate: 0.8277 - weighted_bincrossentropy: 0.0791 - val_binary_accuracy: 0.9871 - val_dice_coef: 0.7579 - val_dice_loss: 0.2421 - val_dice_p_bce: 0.2430 - val_loss: 0.2990 - val_true_positive_rate: 0.7856 - val_weighted_bincrossentropy: 0.0975
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9883 - dice_coef: 0.7709 - dice_loss: 0.2291 - dice_p_bce: 0.2298 - loss: 0.2878 - true_positive_rate: 0.8167 - weighted_bincrossentropy: 0.0773 - val_binary_accuracy: 0.9872 - val_dice_coef: 0.7591 - val_dice_loss: 0.2409 - val_dice_p_bce: 0.2419 - val_loss: 0.2977 - val_true_positive_rate: 0.7775 - val_weighted_bincrossentropy: 0.1030
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9883 - dice_coef: 0.7693 - dice_loss: 0.2307 - dice_p_bce: 0.2315 - loss: 0.2894 - true_positive_rate: 0.8111 - weighted_bincrossentropy: 0.0831 - val_binary_accuracy: 0.9872 - val_dice_coef: 0.7574 - val_dice_loss: 0.2426 - val_dice_p_bce: 0.2436 - val_loss: 0.2997 - val_true_positive_rate: 0.7677 - val_weighted_bincrossentropy: 0.1072
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9884 - dice_coef: 0.7700 - dice_loss: 0.2300 - dice_p_bce: 0.2308 - loss: 0.2877 - true_positive_rate: 0.8120 - weighted_bincrossentropy: 0.0794 - val_binary_accuracy: 0.9874 - val_dice_coef: 0.7597 - val_dice_loss: 0.2403 - val_dice_p_bce: 0.2413 - val_loss: 0.2969 - val_true_positive_rate: 0.7694 - val_weighted_bincrossentropy: 0.1049
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9887 - dice_coef: 0.7735 - dice_loss: 0.2265 - dice_p_bce: 0.2273 - loss: 0.2841 - true_positive_rate: 0.8151 - weighted_bincrossentropy: 0.0781 - val_binary_accuracy: 0.9874 - val_dice_coef: 0.7567 - val_dice_loss: 0.2433 - val_dice_p_bce: 0.2445 - val_loss: 0.3014 - val_true_positive_rate: 0.7462 - val_weighted_bincrossentropy: 0.1145
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9887 - dice_coef: 0.7764 - dice_loss: 0.2236 - dice_p_bce: 0.2244 - loss: 0.2827 - true_positive_rate: 0.8061 - weighted_bincrossentropy: 0.0810 - val_binary_accuracy: 0.9860 - val_dice_coef: 0.7643 - val_dice_loss: 0.2357 - val_dice_p_bce: 0.2364 - val_loss: 0.2937 - val_true_positive_rate: 0.8691 - val_weighted_bincrossentropy: 0.0688
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9881 - dice_coef: 0.7742 - dice_loss: 0.2258 - dice_p_bce: 0.2266 - loss: 0.2835 - true_positive_rate: 0.8292 - weighted_bincrossentropy: 0.0787 - val_binary_accuracy: 0.9876 - val_dice_coef: 0.7690 - val_dice_loss: 0.2310 - val_dice_p_bce: 0.2319 - val_loss: 0.2868 - val_true_positive_rate: 0.8005 - val_weighted_bincrossentropy: 0.0887
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9888 - dice_coef: 0.7718 - dice_loss: 0.2282 - dice_p_bce: 0.2289 - loss: 0.2874 - true_positive_rate: 0.8221 - weighted_bincrossentropy: 0.0717 - val_binary_accuracy: 0.9855 - val_dice_coef: 0.7600 - val_dice_loss: 0.2400 - val_dice_p_bce: 0.2406 - val_loss: 0.2983 - val_true_positive_rate: 0.8785 - val_weighted_bincrossentropy: 0.0683
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9880 - dice_coef: 0.7770 - dice_loss: 0.2230 - dice_p_bce: 0.2237 - loss: 0.2819 - true_positive_rate: 0.8381 - weighted_bincrossentropy: 0.0745 - val_binary_accuracy: 0.9877 - val_dice_coef: 0.7624 - val_dice_loss: 0.2376 - val_dice_p_bce: 0.2386 - val_loss: 0.2933 - val_true_positive_rate: 0.7625 - val_weighted_bincrossentropy: 0.1073
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9888 - dice_coef: 0.7787 - dice_loss: 0.2213 - dice_p_bce: 0.2221 - loss: 0.2780 - true_positive_rate: 0.8073 - weighted_bincrossentropy: 0.0829 - val_binary_accuracy: 0.9869 - val_dice_coef: 0.7712 - val_dice_loss: 0.2288 - val_dice_p_bce: 0.2295 - val_loss: 0.2855 - val_true_positive_rate: 0.8495 - val_weighted_bincrossentropy: 0.0744
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9890 - dice_coef: 0.7830 - dice_loss: 0.2170 - dice_p_bce: 0.2177 - loss: 0.2741 - true_positive_rate: 0.8372 - weighted_bincrossentropy: 0.0682 - val_binary_accuracy: 0.9878 - val_dice_coef: 0.7720 - val_dice_loss: 0.2280 - val_dice_p_bce: 0.2289 - val_loss: 0.2839 - val_true_positive_rate: 0.7897 - val_weighted_bincrossentropy: 0.0965
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9896 - dice_coef: 0.7830 - dice_loss: 0.2170 - dice_p_bce: 0.2177 - loss: 0.2744 - true_positive_rate: 0.8196 - weighted_bincrossentropy: 0.0721 - val_binary_accuracy: 0.9876 - val_dice_coef: 0.7760 - val_dice_loss: 0.2240 - val_dice_p_bce: 0.2248 - val_loss: 0.2797 - val_true_positive_rate: 0.8282 - val_weighted_bincrossentropy: 0.0801
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9890 - dice_coef: 0.7927 - dice_loss: 0.2073 - dice_p_bce: 0.2080 - loss: 0.2631 - true_positive_rate: 0.8344 - weighted_bincrossentropy: 0.0734 - val_binary_accuracy: 0.9877 - val_dice_coef: 0.7787 - val_dice_loss: 0.2213 - val_dice_p_bce: 0.2221 - val_loss: 0.2767 - val_true_positive_rate: 0.8337 - val_weighted_bincrossentropy: 0.0790
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9894 - dice_coef: 0.7940 - dice_loss: 0.2060 - dice_p_bce: 0.2067 - loss: 0.2623 - true_positive_rate: 0.8356 - weighted_bincrossentropy: 0.0705 - val_binary_accuracy: 0.9875 - val_dice_coef: 0.7787 - val_dice_loss: 0.2213 - val_dice_p_bce: 0.2221 - val_loss: 0.2768 - val_true_positive_rate: 0.8421 - val_weighted_bincrossentropy: 0.0768
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9898 - dice_coef: 0.7903 - dice_loss: 0.2097 - dice_p_bce: 0.2104 - loss: 0.2661 - true_positive_rate: 0.8387 - weighted_bincrossentropy: 0.0677 - val_binary_accuracy: 0.9881 - val_dice_coef: 0.7778 - val_dice_loss: 0.2222 - val_dice_p_bce: 0.2232 - val_loss: 0.2776 - val_true_positive_rate: 0.7990 - val_weighted_bincrossentropy: 0.0921
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9898 - dice_coef: 0.7878 - dice_loss: 0.2122 - dice_p_bce: 0.2128 - loss: 0.2686 - true_positive_rate: 0.8301 - weighted_bincrossentropy: 0.0693 - val_binary_accuracy: 0.9882 - val_dice_coef: 0.7764 - val_dice_loss: 0.2236 - val_dice_p_bce: 0.2246 - val_loss: 0.2792 - val_true_positive_rate: 0.7826 - val_weighted_bincrossentropy: 0.0984
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9892 - dice_coef: 0.7943 - dice_loss: 0.2057 - dice_p_bce: 0.2065 - loss: 0.2610 - true_positive_rate: 0.8217 - weighted_bincrossentropy: 0.0810 - val_binary_accuracy: 0.9876 - val_dice_coef: 0.7807 - val_dice_loss: 0.2193 - val_dice_p_bce: 0.2201 - val_loss: 0.2748 - val_true_positive_rate: 0.8478 - val_weighted_bincrossentropy: 0.0748
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9895 - dice_coef: 0.7970 - dice_loss: 0.2030 - dice_p_bce: 0.2037 - loss: 0.2585 - true_positive_rate: 0.8391 - weighted_bincrossentropy: 0.0707 - val_binary_accuracy: 0.9881 - val_dice_coef: 0.7830 - val_dice_loss: 0.2170 - val_dice_p_bce: 0.2179 - val_loss: 0.2715 - val_true_positive_rate: 0.8241 - val_weighted_bincrossentropy: 0.0847
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9897 - dice_coef: 0.8020 - dice_loss: 0.1980 - dice_p_bce: 0.1987 - loss: 0.2529 - true_positive_rate: 0.8401 - weighted_bincrossentropy: 0.0709 - val_binary_accuracy: 0.9880 - val_dice_coef: 0.7831 - val_dice_loss: 0.2169 - val_dice_p_bce: 0.2178 - val_loss: 0.2716 - val_true_positive_rate: 0.8285 - val_weighted_bincrossentropy: 0.0831
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9896 - dice_coef: 0.8016 - dice_loss: 0.1984 - dice_p_bce: 0.1992 - loss: 0.2528 - true_positive_rate: 0.8405 - weighted_bincrossentropy: 0.0726 - val_binary_accuracy: 0.9882 - val_dice_coef: 0.7848 - val_dice_loss: 0.2152 - val_dice_p_bce: 0.2161 - val_loss: 0.2697 - val_true_positive_rate: 0.8235 - val_weighted_bincrossentropy: 0.0842
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9900 - dice_coef: 0.7976 - dice_loss: 0.2024 - dice_p_bce: 0.2031 - loss: 0.2568 - true_positive_rate: 0.8380 - weighted_bincrossentropy: 0.0694 - val_binary_accuracy: 0.9880 - val_dice_coef: 0.7848 - val_dice_loss: 0.2152 - val_dice_p_bce: 0.2160 - val_loss: 0.2703 - val_true_positive_rate: 0.8335 - val_weighted_bincrossentropy: 0.0820
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9902 - dice_coef: 0.7989 - dice_loss: 0.2011 - dice_p_bce: 0.2018 - loss: 0.2556 - true_positive_rate: 0.8399 - weighted_bincrossentropy: 0.0682 - val_binary_accuracy: 0.9880 - val_dice_coef: 0.7867 - val_dice_loss: 0.2133 - val_dice_p_bce: 0.2141 - val_loss: 0.2677 - val_true_positive_rate: 0.8446 - val_weighted_bincrossentropy: 0.0764
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9896 - dice_coef: 0.8031 - dice_loss: 0.1969 - dice_p_bce: 0.1976 - loss: 0.2508 - true_positive_rate: 0.8453 - weighted_bincrossentropy: 0.0726 - val_binary_accuracy: 0.9882 - val_dice_coef: 0.7878 - val_dice_loss: 0.2122 - val_dice_p_bce: 0.2129 - val_loss: 0.2662 - val_true_positive_rate: 0.8369 - val_weighted_bincrossentropy: 0.0791
# Epoch 104/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9905 - dice_coef: 0.8046 - dice_loss: 0.1954 - dice_p_bce: 0.1961 - loss: 0.2500 - true_positive_rate: 0.8450 - weighted_bincrossentropy: 0.0656 - val_binary_accuracy: 0.9886 - val_dice_coef: 0.7848 - val_dice_loss: 0.2152 - val_dice_p_bce: 0.2162 - val_loss: 0.2694 - val_true_positive_rate: 0.7966 - val_weighted_bincrossentropy: 0.0970
# Epoch 105/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9903 - dice_coef: 0.8058 - dice_loss: 0.1942 - dice_p_bce: 0.1949 - loss: 0.2485 - true_positive_rate: 0.8348 - weighted_bincrossentropy: 0.0722 - val_binary_accuracy: 0.9886 - val_dice_coef: 0.7877 - val_dice_loss: 0.2123 - val_dice_p_bce: 0.2132 - val_loss: 0.2654 - val_true_positive_rate: 0.8111 - val_weighted_bincrossentropy: 0.0905
# Epoch 106/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9894 - dice_coef: 0.7936 - dice_loss: 0.2064 - dice_p_bce: 0.2071 - loss: 0.2609 - true_positive_rate: 0.8423 - weighted_bincrossentropy: 0.0716 - val_binary_accuracy: 0.9883 - val_dice_coef: 0.7687 - val_dice_loss: 0.2313 - val_dice_p_bce: 0.2325 - val_loss: 0.2887 - val_true_positive_rate: 0.7336 - val_weighted_bincrossentropy: 0.1235
# Epoch 107/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9900 - dice_coef: 0.7883 - dice_loss: 0.2117 - dice_p_bce: 0.2125 - loss: 0.2668 - true_positive_rate: 0.8074 - weighted_bincrossentropy: 0.0804 - val_binary_accuracy: 0.9873 - val_dice_coef: 0.7812 - val_dice_loss: 0.2188 - val_dice_p_bce: 0.2195 - val_loss: 0.2754 - val_true_positive_rate: 0.8651 - val_weighted_bincrossentropy: 0.0700
# Epoch 108/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9898 - dice_coef: 0.8011 - dice_loss: 0.1989 - dice_p_bce: 0.1996 - loss: 0.2538 - true_positive_rate: 0.8465 - weighted_bincrossentropy: 0.0674 - val_binary_accuracy: 0.9885 - val_dice_coef: 0.7857 - val_dice_loss: 0.2143 - val_dice_p_bce: 0.2153 - val_loss: 0.2673 - val_true_positive_rate: 0.8109 - val_weighted_bincrossentropy: 0.0953
# Epoch 109/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9899 - dice_coef: 0.8020 - dice_loss: 0.1980 - dice_p_bce: 0.1988 - loss: 0.2511 - true_positive_rate: 0.8343 - weighted_bincrossentropy: 0.0754 - val_binary_accuracy: 0.9883 - val_dice_coef: 0.7900 - val_dice_loss: 0.2100 - val_dice_p_bce: 0.2108 - val_loss: 0.2647 - val_true_positive_rate: 0.8341 - val_weighted_bincrossentropy: 0.0816
# Epoch 110/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9903 - dice_coef: 0.8092 - dice_loss: 0.1908 - dice_p_bce: 0.1914 - loss: 0.2445 - true_positive_rate: 0.8470 - weighted_bincrossentropy: 0.0687 - val_binary_accuracy: 0.9889 - val_dice_coef: 0.7916 - val_dice_loss: 0.2084 - val_dice_p_bce: 0.2093 - val_loss: 0.2613 - val_true_positive_rate: 0.8108 - val_weighted_bincrossentropy: 0.0884
# Epoch 111/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9906 - dice_coef: 0.8122 - dice_loss: 0.1878 - dice_p_bce: 0.1885 - loss: 0.2408 - true_positive_rate: 0.8409 - weighted_bincrossentropy: 0.0692 - val_binary_accuracy: 0.9884 - val_dice_coef: 0.7937 - val_dice_loss: 0.2063 - val_dice_p_bce: 0.2071 - val_loss: 0.2598 - val_true_positive_rate: 0.8531 - val_weighted_bincrossentropy: 0.0740
# Epoch 112/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9907 - dice_coef: 0.8080 - dice_loss: 0.1920 - dice_p_bce: 0.1927 - loss: 0.2453 - true_positive_rate: 0.8494 - weighted_bincrossentropy: 0.0642 - val_binary_accuracy: 0.9886 - val_dice_coef: 0.7936 - val_dice_loss: 0.2064 - val_dice_p_bce: 0.2072 - val_loss: 0.2602 - val_true_positive_rate: 0.8365 - val_weighted_bincrossentropy: 0.0808
# Epoch 113/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9908 - dice_coef: 0.8128 - dice_loss: 0.1872 - dice_p_bce: 0.1879 - loss: 0.2402 - true_positive_rate: 0.8479 - weighted_bincrossentropy: 0.0667 - val_binary_accuracy: 0.9888 - val_dice_coef: 0.7952 - val_dice_loss: 0.2048 - val_dice_p_bce: 0.2057 - val_loss: 0.2575 - val_true_positive_rate: 0.8278 - val_weighted_bincrossentropy: 0.0854
# Epoch 114/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9906 - dice_coef: 0.8119 - dice_loss: 0.1881 - dice_p_bce: 0.1888 - loss: 0.2404 - true_positive_rate: 0.8465 - weighted_bincrossentropy: 0.0700 - val_binary_accuracy: 0.9887 - val_dice_coef: 0.7963 - val_dice_loss: 0.2037 - val_dice_p_bce: 0.2046 - val_loss: 0.2568 - val_true_positive_rate: 0.8405 - val_weighted_bincrossentropy: 0.0810
# Epoch 115/500
# ...
# Epoch 292/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9944 - dice_coef: 0.8831 - dice_loss: 0.1169 - dice_p_bce: 0.1175 - loss: 0.1557 - true_positive_rate: 0.9028 - weighted_bincrossentropy: 0.0615 - val_binary_accuracy: 0.9910 - val_dice_coef: 0.8400 - val_dice_loss: 0.1600 - val_dice_p_bce: 0.1609 - val_loss: 0.2060 - val_true_positive_rate: 0.8752 - val_weighted_bincrossentropy: 0.0899
# Epoch 293/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9941 - dice_coef: 0.8855 - dice_loss: 0.1145 - dice_p_bce: 0.1152 - loss: 0.1528 - true_positive_rate: 0.9075 - weighted_bincrossentropy: 0.0626 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8344 - val_dice_loss: 0.1656 - val_dice_p_bce: 0.1668 - val_loss: 0.2114 - val_true_positive_rate: 0.8255 - val_weighted_bincrossentropy: 0.1164
# Epoch 294/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9936 - dice_coef: 0.8783 - dice_loss: 0.1217 - dice_p_bce: 0.1224 - loss: 0.1605 - true_positive_rate: 0.8913 - weighted_bincrossentropy: 0.0703 - val_binary_accuracy: 0.9911 - val_dice_coef: 0.8394 - val_dice_loss: 0.1606 - val_dice_p_bce: 0.1616 - val_loss: 0.2067 - val_true_positive_rate: 0.8585 - val_weighted_bincrossentropy: 0.0952
# Epoch 295/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9940 - dice_coef: 0.8824 - dice_loss: 0.1176 - dice_p_bce: 0.1182 - loss: 0.1561 - true_positive_rate: 0.8938 - weighted_bincrossentropy: 0.0664 - val_binary_accuracy: 0.9898 - val_dice_coef: 0.8295 - val_dice_loss: 0.1705 - val_dice_p_bce: 0.1713 - val_loss: 0.2187 - val_true_positive_rate: 0.9106 - val_weighted_bincrossentropy: 0.0742
# Epoch 296/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9928 - dice_coef: 0.8666 - dice_loss: 0.1334 - dice_p_bce: 0.1340 - loss: 0.1755 - true_positive_rate: 0.9071 - weighted_bincrossentropy: 0.0611 - val_binary_accuracy: 0.9911 - val_dice_coef: 0.8369 - val_dice_loss: 0.1631 - val_dice_p_bce: 0.1642 - val_loss: 0.2097 - val_true_positive_rate: 0.8355 - val_weighted_bincrossentropy: 0.1147
# Epoch 297/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9935 - dice_coef: 0.8740 - dice_loss: 0.1260 - dice_p_bce: 0.1267 - loss: 0.1660 - true_positive_rate: 0.8802 - weighted_bincrossentropy: 0.0723 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8410 - val_dice_loss: 0.1590 - val_dice_p_bce: 0.1600 - val_loss: 0.2042 - val_true_positive_rate: 0.8528 - val_weighted_bincrossentropy: 0.0991
# Epoch 298/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9937 - dice_coef: 0.8785 - dice_loss: 0.1215 - dice_p_bce: 0.1221 - loss: 0.1608 - true_positive_rate: 0.8960 - weighted_bincrossentropy: 0.0651 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8409 - val_dice_loss: 0.1591 - val_dice_p_bce: 0.1600 - val_loss: 0.2049 - val_true_positive_rate: 0.8617 - val_weighted_bincrossentropy: 0.0951
# Epoch 299/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9941 - dice_coef: 0.8802 - dice_loss: 0.1198 - dice_p_bce: 0.1204 - loss: 0.1589 - true_positive_rate: 0.8982 - weighted_bincrossentropy: 0.0612 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8412 - val_dice_loss: 0.1588 - val_dice_p_bce: 0.1598 - val_loss: 0.2040 - val_true_positive_rate: 0.8516 - val_weighted_bincrossentropy: 0.1020
# Epoch 300/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9943 - dice_coef: 0.8845 - dice_loss: 0.1155 - dice_p_bce: 0.1161 - loss: 0.1542 - true_positive_rate: 0.9016 - weighted_bincrossentropy: 0.0603 - val_binary_accuracy: 0.9910 - val_dice_coef: 0.8409 - val_dice_loss: 0.1591 - val_dice_p_bce: 0.1600 - val_loss: 0.2048 - val_true_positive_rate: 0.8770 - val_weighted_bincrossentropy: 0.0873
# Epoch 301/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9943 - dice_coef: 0.8807 - dice_loss: 0.1193 - dice_p_bce: 0.1199 - loss: 0.1585 - true_positive_rate: 0.9018 - weighted_bincrossentropy: 0.0600 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8389 - val_dice_loss: 0.1611 - val_dice_p_bce: 0.1622 - val_loss: 0.2066 - val_true_positive_rate: 0.8381 - val_weighted_bincrossentropy: 0.1080
# Epoch 302/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9941 - dice_coef: 0.8813 - dice_loss: 0.1187 - dice_p_bce: 0.1193 - loss: 0.1571 - true_positive_rate: 0.8944 - weighted_bincrossentropy: 0.0645 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8415 - val_dice_loss: 0.1585 - val_dice_p_bce: 0.1594 - val_loss: 0.2044 - val_true_positive_rate: 0.8654 - val_weighted_bincrossentropy: 0.0916
# Epoch 303/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9944 - dice_coef: 0.8833 - dice_loss: 0.1167 - dice_p_bce: 0.1173 - loss: 0.1554 - true_positive_rate: 0.8993 - weighted_bincrossentropy: 0.0611 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8411 - val_dice_loss: 0.1589 - val_dice_p_bce: 0.1599 - val_loss: 0.2043 - val_true_positive_rate: 0.8523 - val_weighted_bincrossentropy: 0.1039
# Epoch 304/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9941 - dice_coef: 0.8851 - dice_loss: 0.1149 - dice_p_bce: 0.1156 - loss: 0.1526 - true_positive_rate: 0.9017 - weighted_bincrossentropy: 0.0650 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8429 - val_dice_loss: 0.1571 - val_dice_p_bce: 0.1580 - val_loss: 0.2024 - val_true_positive_rate: 0.8726 - val_weighted_bincrossentropy: 0.0905
# Epoch 305/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9940 - dice_coef: 0.8842 - dice_loss: 0.1158 - dice_p_bce: 0.1164 - loss: 0.1536 - true_positive_rate: 0.9057 - weighted_bincrossentropy: 0.0635 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8380 - val_dice_loss: 0.1620 - val_dice_p_bce: 0.1631 - val_loss: 0.2080 - val_true_positive_rate: 0.8322 - val_weighted_bincrossentropy: 0.1113
# Epoch 306/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9940 - dice_coef: 0.8806 - dice_loss: 0.1194 - dice_p_bce: 0.1201 - loss: 0.1577 - true_positive_rate: 0.8931 - weighted_bincrossentropy: 0.0664 - val_binary_accuracy: 0.9907 - val_dice_coef: 0.8392 - val_dice_loss: 0.1608 - val_dice_p_bce: 0.1616 - val_loss: 0.2070 - val_true_positive_rate: 0.8949 - val_weighted_bincrossentropy: 0.0798
# Epoch 307/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9937 - dice_coef: 0.8774 - dice_loss: 0.1226 - dice_p_bce: 0.1232 - loss: 0.1624 - true_positive_rate: 0.9087 - weighted_bincrossentropy: 0.0595 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8416 - val_dice_loss: 0.1584 - val_dice_p_bce: 0.1594 - val_loss: 0.2037 - val_true_positive_rate: 0.8492 - val_weighted_bincrossentropy: 0.1049
# Epoch 308/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9944 - dice_coef: 0.8835 - dice_loss: 0.1165 - dice_p_bce: 0.1172 - loss: 0.1549 - true_positive_rate: 0.8929 - weighted_bincrossentropy: 0.0651 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8434 - val_dice_loss: 0.1566 - val_dice_p_bce: 0.1574 - val_loss: 0.2020 - val_true_positive_rate: 0.8795 - val_weighted_bincrossentropy: 0.0848
# Epoch 309/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9941 - dice_coef: 0.8846 - dice_loss: 0.1154 - dice_p_bce: 0.1160 - loss: 0.1534 - true_positive_rate: 0.9086 - weighted_bincrossentropy: 0.0607 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8429 - val_dice_loss: 0.1571 - val_dice_p_bce: 0.1580 - val_loss: 0.2027 - val_true_positive_rate: 0.8684 - val_weighted_bincrossentropy: 0.0904
# Epoch 310/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9940 - dice_coef: 0.8859 - dice_loss: 0.1141 - dice_p_bce: 0.1148 - loss: 0.1514 - true_positive_rate: 0.9029 - weighted_bincrossentropy: 0.0647 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8436 - val_dice_loss: 0.1564 - val_dice_p_bce: 0.1573 - val_loss: 0.2014 - val_true_positive_rate: 0.8671 - val_weighted_bincrossentropy: 0.0938
# Epoch 311/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9943 - dice_coef: 0.8864 - dice_loss: 0.1136 - dice_p_bce: 0.1142 - loss: 0.1511 - true_positive_rate: 0.9084 - weighted_bincrossentropy: 0.0614 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8437 - val_dice_loss: 0.1563 - val_dice_p_bce: 0.1573 - val_loss: 0.2014 - val_true_positive_rate: 0.8588 - val_weighted_bincrossentropy: 0.0969
# Epoch 312/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8879 - dice_loss: 0.1121 - dice_p_bce: 0.1127 - loss: 0.1487 - true_positive_rate: 0.9061 - weighted_bincrossentropy: 0.0657 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8424 - val_dice_loss: 0.1576 - val_dice_p_bce: 0.1586 - val_loss: 0.2029 - val_true_positive_rate: 0.8507 - val_weighted_bincrossentropy: 0.1029
# Epoch 313/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9945 - dice_coef: 0.8874 - dice_loss: 0.1126 - dice_p_bce: 0.1132 - loss: 0.1497 - true_positive_rate: 0.9046 - weighted_bincrossentropy: 0.0622 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8434 - val_dice_loss: 0.1566 - val_dice_p_bce: 0.1576 - val_loss: 0.2019 - val_true_positive_rate: 0.8608 - val_weighted_bincrossentropy: 0.0988
# Epoch 314/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9948 - dice_coef: 0.8897 - dice_loss: 0.1103 - dice_p_bce: 0.1109 - loss: 0.1478 - true_positive_rate: 0.9071 - weighted_bincrossentropy: 0.0591 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8426 - val_dice_loss: 0.1574 - val_dice_p_bce: 0.1585 - val_loss: 0.2026 - val_true_positive_rate: 0.8501 - val_weighted_bincrossentropy: 0.1051
# Epoch 315/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step - binary_accuracy: 0.9948 - dice_coef: 0.8893 - dice_loss: 0.1107 - dice_p_bce: 0.1113 - loss: 0.1481 - true_positive_rate: 0.9032 - weighted_bincrossentropy: 0.0609 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8438 - val_dice_loss: 0.1562 - val_dice_p_bce: 0.1571 - val_loss: 0.2014 - val_true_positive_rate: 0.8683 - val_weighted_bincrossentropy: 0.0938
# Epoch 316/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9946 - dice_coef: 0.8882 - dice_loss: 0.1118 - dice_p_bce: 0.1125 - loss: 0.1490 - true_positive_rate: 0.9047 - weighted_bincrossentropy: 0.0629 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8429 - val_dice_loss: 0.1571 - val_dice_p_bce: 0.1581 - val_loss: 0.2026 - val_true_positive_rate: 0.8709 - val_weighted_bincrossentropy: 0.0943
# Epoch 317/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8868 - dice_loss: 0.1132 - dice_p_bce: 0.1138 - loss: 0.1501 - true_positive_rate: 0.9092 - weighted_bincrossentropy: 0.0643 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8427 - val_dice_loss: 0.1573 - val_dice_p_bce: 0.1583 - val_loss: 0.2025 - val_true_positive_rate: 0.8510 - val_weighted_bincrossentropy: 0.1057
# Epoch 318/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8882 - dice_loss: 0.1118 - dice_p_bce: 0.1125 - loss: 0.1485 - true_positive_rate: 0.9060 - weighted_bincrossentropy: 0.0655 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8418 - val_dice_loss: 0.1582 - val_dice_p_bce: 0.1593 - val_loss: 0.2035 - val_true_positive_rate: 0.8454 - val_weighted_bincrossentropy: 0.1088
# Epoch 319/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9944 - dice_coef: 0.8895 - dice_loss: 0.1105 - dice_p_bce: 0.1112 - loss: 0.1470 - true_positive_rate: 0.9038 - weighted_bincrossentropy: 0.0664 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8427 - val_dice_loss: 0.1573 - val_dice_p_bce: 0.1583 - val_loss: 0.2026 - val_true_positive_rate: 0.8612 - val_weighted_bincrossentropy: 0.1008
# Epoch 320/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8901 - dice_loss: 0.1099 - dice_p_bce: 0.1105 - loss: 0.1462 - true_positive_rate: 0.9082 - weighted_bincrossentropy: 0.0658 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8436 - val_dice_loss: 0.1564 - val_dice_p_bce: 0.1573 - val_loss: 0.2015 - val_true_positive_rate: 0.8616 - val_weighted_bincrossentropy: 0.0994
# Epoch 321/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9944 - dice_coef: 0.8888 - dice_loss: 0.1112 - dice_p_bce: 0.1118 - loss: 0.1480 - true_positive_rate: 0.9098 - weighted_bincrossentropy: 0.0624 - val_binary_accuracy: 0.9909 - val_dice_coef: 0.8416 - val_dice_loss: 0.1584 - val_dice_p_bce: 0.1593 - val_loss: 0.2042 - val_true_positive_rate: 0.8858 - val_weighted_bincrossentropy: 0.0874
# Epoch 322/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9941 - dice_coef: 0.8823 - dice_loss: 0.1177 - dice_p_bce: 0.1183 - loss: 0.1559 - true_positive_rate: 0.9096 - weighted_bincrossentropy: 0.0608 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8425 - val_dice_loss: 0.1575 - val_dice_p_bce: 0.1586 - val_loss: 0.2031 - val_true_positive_rate: 0.8440 - val_weighted_bincrossentropy: 0.1102
# Epoch 323/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9946 - dice_coef: 0.8864 - dice_loss: 0.1136 - dice_p_bce: 0.1142 - loss: 0.1516 - true_positive_rate: 0.9034 - weighted_bincrossentropy: 0.0603 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8435 - val_dice_loss: 0.1565 - val_dice_p_bce: 0.1575 - val_loss: 0.2017 - val_true_positive_rate: 0.8695 - val_weighted_bincrossentropy: 0.0972
# Epoch 324/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9941 - dice_coef: 0.8866 - dice_loss: 0.1134 - dice_p_bce: 0.1141 - loss: 0.1506 - true_positive_rate: 0.9020 - weighted_bincrossentropy: 0.0680 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8444 - val_dice_loss: 0.1556 - val_dice_p_bce: 0.1565 - val_loss: 0.2005 - val_true_positive_rate: 0.8680 - val_weighted_bincrossentropy: 0.0952
# Epoch 325/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9938 - dice_coef: 0.8842 - dice_loss: 0.1158 - dice_p_bce: 0.1164 - loss: 0.1531 - true_positive_rate: 0.9082 - weighted_bincrossentropy: 0.0659 - val_binary_accuracy: 0.9913 - val_dice_coef: 0.8438 - val_dice_loss: 0.1562 - val_dice_p_bce: 0.1572 - val_loss: 0.2017 - val_true_positive_rate: 0.8704 - val_weighted_bincrossentropy: 0.0915
# Epoch 326/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9941 - dice_coef: 0.8820 - dice_loss: 0.1180 - dice_p_bce: 0.1186 - loss: 0.1559 - true_positive_rate: 0.8981 - weighted_bincrossentropy: 0.0649 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8433 - val_dice_loss: 0.1567 - val_dice_p_bce: 0.1578 - val_loss: 0.2023 - val_true_positive_rate: 0.8461 - val_weighted_bincrossentropy: 0.1091
# Epoch 327/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9943 - dice_coef: 0.8876 - dice_loss: 0.1124 - dice_p_bce: 0.1130 - loss: 0.1499 - true_positive_rate: 0.9023 - weighted_bincrossentropy: 0.0628 - val_binary_accuracy: 0.9914 - val_dice_coef: 0.8436 - val_dice_loss: 0.1564 - val_dice_p_bce: 0.1574 - val_loss: 0.2013 - val_true_positive_rate: 0.8535 - val_weighted_bincrossentropy: 0.1052
# Epoch 328/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9941 - dice_coef: 0.8868 - dice_loss: 0.1132 - dice_p_bce: 0.1138 - loss: 0.1502 - true_positive_rate: 0.9013 - weighted_bincrossentropy: 0.0677 - val_binary_accuracy: 0.9912 - val_dice_coef: 0.8432 - val_dice_loss: 0.1568 - val_dice_p_bce: 0.1577 - val_loss: 0.2025 - val_true_positive_rate: 0.8703 - val_weighted_bincrossentropy: 0.0951
# Epoch 329/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9945 - dice_coef: 0.8866 - dice_loss: 0.1134 - dice_p_bce: 0.1140 - loss: 0.1509 - true_positive_rate: 0.9090 - weighted_bincrossentropy: 0.0599 - val_binary_accuracy: 0.9915 - val_dice_coef: 0.8408 - val_dice_loss: 0.1592 - val_dice_p_bce: 0.1604 - val_loss: 0.2046 - val_true_positive_rate: 0.8335 - val_weighted_bincrossentropy: 0.1158
# Epoch 330/500
# 4/6 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - binary_accuracy: 0.9946 - dice_coef: 0.8829 - dice_loss: 0.1171 - dice_p_bce: 0.1177 - loss: 0.1558 - true_positive_rate: 0.8901 - weighted_bincrossentropy: 0.0644

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('model dice coefficent')
plt.ylabel('dice coef')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# print("Max acc:", round(max(history.history['acc']),4))
# print("Max val_acc:", round(max(history.history['val_acc']),4))
# print("\nMin loss:", round(min(history.history['loss']),4))
# print("Min val_loss:", round(min(history.history['val_loss']),4))

# %% [markdown]
# ## Testing the model

# %%
## Save the Weights

#model.save_weights("UNetW.h5")

# %%
## Dataset for prediction
x, y = valid_gen.__getitem__(0)
result = model.predict(x)

result = result > 0.5

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)

r = random.randint(0, len(x)-1)


ax = fig.add_subplot(1, 2, 1)
ax.imshow(np.reshape(y[r]*255, (dim, dim)), cmap="gray")

ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(result[r]*255, (dim, dim)), cmap="gray")

# %%
fig, axes = plt.subplots(ncols = 3, )

fig.set_figwidth(3.6)
fig.set_figheight(2)


axes[0].imshow(x[0])
axes[0].set_xlabel('Raw Image')
axes[1].imshow(np.reshape(y[0]*255, (dim, dim)), cmap="gray")
axes[1].set_xlabel('Ground Truth')
axes[2].imshow(np.reshape(result[0]*255, (dim, dim)), cmap="gray")
axes[2].set_xlabel('Prediction')

matplotlib.rcParams.update({'font.size': 12, "font.family": "Times New Roman"})

for i, ax in enumerate(axes):
    axes[i].tick_params(
        axis='both',          # changes apply to the voth axis
        which='both', 
        left = False,   # both major and minor ticks are affected
        right = False,
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False) # labels along the bottom edge are off
    
    axes[i].xaxis.set_ticklabels([])
    axes[i].yaxis.set_ticklabels([])

    for j in ax.spines:
        axes[i].spines[j].set_visible(False)
        
    plt.savefig(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_example.pdf', dpi =300)

# %% [markdown]
# ## Save Model

# %%
import json

# %%
# !mkdir saved_models
# model.save(r'C:\Users\thoma\Desktop\CT_Segment_Full_v2.h5')

model.save(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}.keras')


save_dict = {'History': history.history, 'Loss Function': use_loss.__name__, 'Learning Rate': learning_rate, 'Num Training Images': len(train_imgs), 'Num Test Images': len(test_imgs), 'Batch Size': batch_size}

with open(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_history.json', 'w') as f:
    json.dump(save_dict, f)

# %%
# with open(r'C:\Users\chloe\DE4\Masters\Models\Model_3_history.pkl', 'r') as f:
#     hist = json.load(f)

# print(len(hist['History']['binary_accuray']))
