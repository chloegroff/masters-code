# %% [markdown]
# # UNET SEGMENTATION

# %%
## Imports
import os
import sys
import random
from glob import glob as glob
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import matplotlib
import matplotlib.image as Image
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split

tf.config.run_functions_eagerly(True)

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed

# %% [markdown]
# ## Hyperparameters

# %%
dim = 224

# get image and mask files
image_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data_1plus\*_i*')
mask_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data_1plus\*_s*')

# splits into test and training datasets
train_imgs, test_imgs, train_masks, test_masks = train_test_split(image_files, mask_files, test_size = 0.33, random_state= 123)

print(len(train_imgs))

batch_size = 32

count = 0
ratios = None
# Out:
# 197

# %% [markdown]
# ## Data Generator

# %%
class DataGen(keras.utils.Sequence):
    def __init__(self, image_files, mask_files,  batch_size, hls = False):
        self.img_files = image_files
        self.mask_files = mask_files
        self.batch_size = batch_size
        self.num_files = len(image_files)

        self.hls = hls

        self.current_ratios = None

    def ratio_Imgs(self, masks):
        rs = []
        for i in masks:
            i = np.reshape(i, (dim, dim))

            r = sum(i > 0.5)/ dim **2

            rs.append(r)
        
        self.current_ratios = np.array(rs)
        global ratios
        ratios = self.current_ratios


    def __getitem__(self, index):
        'Returns batch of images and labels'

        this_batch = self.batch_size
        # Changes batch size for final batch (no data missed)
        if(index+1)*self.batch_size > self.num_files:
            this_batch = self.num_files - index*self.batch_size
        
        # sets limits for batch
        start = index*self.batch_size
        stop = start + this_batch

        # takes images and masks files within batch
        img_batch = self.img_files[start : stop]
        mask_batch = self.mask_files[start : stop]

        images = []
        masks  = []
        
        # loads images and files and adds them to list
        for i, (img_file, mask_file) in enumerate(zip(img_batch,mask_batch)):
            # Normalises
            img = cv2.imread(img_file) 
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            if self.hls:
                img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
            
            img = img / 255

            mask = cv2.imread(mask_file, 0) / 255
            mask = np.array(mask, dtype=np.float32)
            mask = np.reshape(mask, (mask.shape[0], mask.shape[1], 1))
            images.append(img)
            masks.append(mask)
            
        images = np.array(images)
        #image = np.reshape(image, (batch_size, 256, 256, 1))
        masks  = np.array(masks)
        
        self.ratio_Imgs(masks)

        return images, masks
    
    def on_epoch_end(self):
        global count
        count = 0
    
    def __len__(self):
        'Returns Number of batches'
        return int(np.ceil(self.num_files // self.batch_size))

# %%
# data loader obj is created with training images and masks
gen = DataGen(image_files=train_imgs, mask_files=train_masks, batch_size=batch_size)
x, y = gen.__getitem__(0)
print(x.shape, y.shape)
# Out:
# (32, 224, 224, 3) (32, 224, 224, 1)

# %%
r = random.randint(0, len(x)-1)

fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(1, 2, 1)
ax.imshow(x[r])
ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(y[r], (dim, dim)), cmap="gray")

# %% [markdown]
# ## Different Convolutional Blocks

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %% [markdown]
# ## UNet Model

# %%
def UNet(image_size):
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    bn = bottleneck(p4, f[4])
    
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(1, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %% [markdown]
# ## Loss Function

# %%
#from keras import saving

# @keras.saving.register_keras_serializable()
def weighted_bincrossentropy(true, pred):
    """
    Calculates weighted binary cross entropy. The weights are fixed.
        
    This can be useful for unbalanced catagories.
    
    Adjust the weights here depending on what is required.
    
    For example if there are 10x as many positive classes as negative classes,
        if you adjust weight_zero = 1.0, weight_one = 0.1, then false positives 
        will be penalize 10 times as much as false negatives.
    """
    # y = keras.backend.flatten(true)
    # r = np.max(((keras.backend.sum(y).numpy()/dim**2)**3, 1e-8))
    # calculate the binary cross entropy
    bin_crossentropy = keras.backend.binary_crossentropy(true, pred)
    
    # apply the weights
    weights = true * np.log(13) + (1. - true) * 0.5
    weighted_bin_crossentropy = weights * bin_crossentropy 

    return keras.backend.mean(weighted_bin_crossentropy)

# @keras.saving.register_keras_serializable()
def mean_iou_loss(y_true, y_pred):

    pred_sum = keras.backend.sum(y_pred)
    gt_sum = keras.backend.sum(y_true)
    intersection = keras.backend.sum(tf.math.multiply(y_true,y_pred))
    
    union = pred_sum + gt_sum - intersection

    iou = intersection/union
    return 1 - iou

# @keras.saving.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1):
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)
    intersection = keras.backend.sum(y_true * y_pred, axis=[1,2,3])
    union = keras.backend.sum(y_true, axis=[1,2,3]) + keras.backend.sum(y_pred, axis=[1,2,3])
    return keras.backend.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# @keras.saving.register_keras_serializable()
def dice_loss(in_gt, in_pred):
    return 1 - dice_coef(in_gt, in_pred)

# @keras.saving.register_keras_serializable()
def dice_p_bce(in_gt, in_pred):
    """combine DICE and BCE"""
    # 0.01*keras.losses.binary_crossentropy(in_gt, in_pred)
    return 0.01*weighted_bincrossentropy(in_gt, in_pred) + (1- dice_coef(in_gt, in_pred))

# @keras.saving.register_keras_serializable()
def true_positive_rate(y_true, y_pred):
    return keras.backend.sum(keras.backend.flatten(y_true)*keras.backend.flatten(keras.backend.round(y_pred)))/keras.backend.sum(y_true)

# @keras.saving.register_keras_serializable()
def dice_mean_iou(in_gt, in_pred):
    return (dice_loss(in_gt, in_pred) + mean_iou_loss(in_gt, in_pred)) / 2

# %%
model = UNet(dim)

learning_rate = 0.0001
opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# opt = tf.keras.optimizers.SGD(learning_rate = 0.00001)
# model.compile(optimizer = opt, loss=weighted_bincrossentropy, metrics=["acc"])
cce = keras.losses.CategoricalFocalCrossentropy()

use_loss = dice_mean_iou
print(use_loss.__name__)
model.compile(optimizer = opt, loss=use_loss, metrics=[dice_coef, 'binary_accuracy', dice_p_bce, dice_loss, true_positive_rate, weighted_bincrossentropy])
model.summary()
# Out:
# dice_mean_iou
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 224, 224,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 224, 224,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 112, 112,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 112, 112,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 112, 112,  │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 56, 56,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 28, 28,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 14, 14,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 14, 14,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 14, 14,    │    590,080 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 28, 28,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 28, 28,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │    147,584 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 56, 56,    │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 56, 56,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 56, 56,    │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 56, 56,    │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 112, 112,  │          0 │ conv2d_13[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 112, 112,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 112, 112,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 112, 112,  │      9,248 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 224, 224,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 224, 224,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 224, 224,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 224, 224,  │      2,320 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 224, 224,  │         17 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,625 (7.49 MB)
#  Trainable params: 1,962,625 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the model

# %%
train_gen = DataGen(train_imgs, train_masks, batch_size= batch_size, hls = False)
valid_gen = DataGen(test_imgs, test_masks, batch_size=batch_size, hls = False)

# from sklearn.utils import class_weight
x, y = train_gen.__getitem__(5)

w1s = []
w2s = []
for i in y:
    i = np.reshape(i, (dim,dim))
    if np.sum(i) != 0:
        w1s.append(dim**2/(2 * np.sum(i)) )
        w2s.append(dim**2/(2 * (dim**2 - sum(i))))

print(np.mean(w1s), np.mean(w2s))


rs = []
for i in range(len(train_gen)):
    _, masks = train_gen.__getitem__(i)

    for j in masks:
        j = np.reshape(j, (dim,dim))
        r = sum(j > 0.5) / dim**2
        rs.append(r)

r = np.mean(rs)
print(r)
# Out:
# 20.169705912966954 0.50007147
# 0.00012771265383943755

# %%
model_num = 12

# %%
history = model.fit(train_gen, batch_size=batch_size, epochs = 500, validation_data= valid_gen)
# Out:
# Epoch 1/500
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - binary_accuracy: 0.4462 - dice_coef: 0.0556 - dice_loss: 0.9444 - dice_p_bce: 0.9483 - loss: 0.9576 - true_positive_rate: 0.7360 - weighted_bincrossentropy: 0.3895 - val_binary_accuracy: 0.7206 - val_dice_coef: 0.0585 - val_dice_loss: 0.9415 - val_dice_p_bce: 0.9454 - val_loss: 0.9554 - val_true_positive_rate: 0.8236 - val_weighted_bincrossentropy: 0.3907
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.7261 - dice_coef: 0.0547 - dice_loss: 0.9453 - dice_p_bce: 0.9491 - loss: 0.9583 - true_positive_rate: 0.8555 - weighted_bincrossentropy: 0.3872 - val_binary_accuracy: 0.7137 - val_dice_coef: 0.0588 - val_dice_loss: 0.9412 - val_dice_p_bce: 0.9451 - val_loss: 0.9551 - val_true_positive_rate: 0.8773 - val_weighted_bincrossentropy: 0.3891
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.7287 - dice_coef: 0.0539 - dice_loss: 0.9461 - dice_p_bce: 0.9500 - loss: 0.9589 - true_positive_rate: 0.8510 - weighted_bincrossentropy: 0.3837 - val_binary_accuracy: 0.7088 - val_dice_coef: 0.0595 - val_dice_loss: 0.9405 - val_dice_p_bce: 0.9443 - val_loss: 0.9545 - val_true_positive_rate: 0.8634 - val_weighted_bincrossentropy: 0.3849
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.7223 - dice_coef: 0.0537 - dice_loss: 0.9463 - dice_p_bce: 0.9501 - loss: 0.9591 - true_positive_rate: 0.8460 - weighted_bincrossentropy: 0.3778 - val_binary_accuracy: 0.6602 - val_dice_coef: 0.0612 - val_dice_loss: 0.9388 - val_dice_p_bce: 0.9425 - val_loss: 0.9532 - val_true_positive_rate: 0.8542 - val_weighted_bincrossentropy: 0.3765
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.6737 - dice_coef: 0.0582 - dice_loss: 0.9418 - dice_p_bce: 0.9455 - loss: 0.9556 - true_positive_rate: 0.8412 - weighted_bincrossentropy: 0.3687 - val_binary_accuracy: 0.6963 - val_dice_coef: 0.0673 - val_dice_loss: 0.9327 - val_dice_p_bce: 0.9362 - val_loss: 0.9485 - val_true_positive_rate: 0.8121 - val_weighted_bincrossentropy: 0.3509
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.7104 - dice_coef: 0.0676 - dice_loss: 0.9324 - dice_p_bce: 0.9357 - loss: 0.9483 - true_positive_rate: 0.7964 - weighted_bincrossentropy: 0.3324 - val_binary_accuracy: 0.7241 - val_dice_coef: 0.0980 - val_dice_loss: 0.9020 - val_dice_p_bce: 0.9050 - val_loss: 0.9245 - val_true_positive_rate: 0.7979 - val_weighted_bincrossentropy: 0.2965
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.7648 - dice_coef: 0.1017 - dice_loss: 0.8983 - dice_p_bce: 0.9011 - loss: 0.9217 - true_positive_rate: 0.7227 - weighted_bincrossentropy: 0.2803 - val_binary_accuracy: 0.7512 - val_dice_coef: 0.1454 - val_dice_loss: 0.8546 - val_dice_p_bce: 0.8587 - val_loss: 0.8870 - val_true_positive_rate: 0.7933 - val_weighted_bincrossentropy: 0.4033
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8126 - dice_coef: 0.1385 - dice_loss: 0.8615 - dice_p_bce: 0.8654 - loss: 0.8922 - true_positive_rate: 0.6403 - weighted_bincrossentropy: 0.3895 - val_binary_accuracy: 0.8256 - val_dice_coef: 0.1800 - val_dice_loss: 0.8200 - val_dice_p_bce: 0.8260 - val_loss: 0.8592 - val_true_positive_rate: 0.6559 - val_weighted_bincrossentropy: 0.6035
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8389 - dice_coef: 0.1570 - dice_loss: 0.8430 - dice_p_bce: 0.8495 - loss: 0.8776 - true_positive_rate: 0.5824 - weighted_bincrossentropy: 0.6534 - val_binary_accuracy: 0.8494 - val_dice_coef: 0.1925 - val_dice_loss: 0.8075 - val_dice_p_bce: 0.8159 - val_loss: 0.8501 - val_true_positive_rate: 0.5821 - val_weighted_bincrossentropy: 0.8411
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.8275 - dice_coef: 0.1657 - dice_loss: 0.8343 - dice_p_bce: 0.8435 - loss: 0.8712 - true_positive_rate: 0.6439 - weighted_bincrossentropy: 0.9178 - val_binary_accuracy: 0.8860 - val_dice_coef: 0.1878 - val_dice_loss: 0.8122 - val_dice_p_bce: 0.8210 - val_loss: 0.8524 - val_true_positive_rate: 0.4409 - val_weighted_bincrossentropy: 0.8763
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8671 - dice_coef: 0.1776 - dice_loss: 0.8224 - dice_p_bce: 0.8313 - loss: 0.8622 - true_positive_rate: 0.5321 - weighted_bincrossentropy: 0.8833 - val_binary_accuracy: 0.8503 - val_dice_coef: 0.1988 - val_dice_loss: 0.8012 - val_dice_p_bce: 0.8116 - val_loss: 0.8445 - val_true_positive_rate: 0.6047 - val_weighted_bincrossentropy: 1.0376
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8575 - dice_coef: 0.1790 - dice_loss: 0.8210 - dice_p_bce: 0.8307 - loss: 0.8615 - true_positive_rate: 0.5789 - weighted_bincrossentropy: 0.9727 - val_binary_accuracy: 0.8564 - val_dice_coef: 0.2033 - val_dice_loss: 0.7967 - val_dice_p_bce: 0.8071 - val_loss: 0.8411 - val_true_positive_rate: 0.5937 - val_weighted_bincrossentropy: 1.0451
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - binary_accuracy: 0.8634 - dice_coef: 0.1847 - dice_loss: 0.8153 - dice_p_bce: 0.8249 - loss: 0.8564 - true_positive_rate: 0.5753 - weighted_bincrossentropy: 0.9572 - val_binary_accuracy: 0.8662 - val_dice_coef: 0.2064 - val_dice_loss: 0.7936 - val_dice_p_bce: 0.8036 - val_loss: 0.8383 - val_true_positive_rate: 0.5668 - val_weighted_bincrossentropy: 0.9964
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 4s/step - binary_accuracy: 0.8689 - dice_coef: 0.2008 - dice_loss: 0.7992 - dice_p_bce: 0.8086 - loss: 0.8429 - true_positive_rate: 0.5688 - weighted_bincrossentropy: 0.9391 - val_binary_accuracy: 0.9175 - val_dice_coef: 0.1794 - val_dice_loss: 0.8206 - val_dice_p_bce: 0.8293 - val_loss: 0.8549 - val_true_positive_rate: 0.3291 - val_weighted_bincrossentropy: 0.8695
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - binary_accuracy: 0.8825 - dice_coef: 0.1795 - dice_loss: 0.8205 - dice_p_bce: 0.8295 - loss: 0.8593 - true_positive_rate: 0.4907 - weighted_bincrossentropy: 0.8959 - val_binary_accuracy: 0.9093 - val_dice_coef: 0.1925 - val_dice_loss: 0.8075 - val_dice_p_bce: 0.8160 - val_loss: 0.8454 - val_true_positive_rate: 0.3842 - val_weighted_bincrossentropy: 0.8558
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 23s 4s/step - binary_accuracy: 0.8873 - dice_coef: 0.1892 - dice_loss: 0.8108 - dice_p_bce: 0.8192 - loss: 0.8522 - true_positive_rate: 0.4870 - weighted_bincrossentropy: 0.8457 - val_binary_accuracy: 0.8594 - val_dice_coef: 0.2131 - val_dice_loss: 0.7869 - val_dice_p_bce: 0.7964 - val_loss: 0.8330 - val_true_positive_rate: 0.6168 - val_weighted_bincrossentropy: 0.9537
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8728 - dice_coef: 0.2044 - dice_loss: 0.7956 - dice_p_bce: 0.8043 - loss: 0.8399 - true_positive_rate: 0.5713 - weighted_bincrossentropy: 0.8646 - val_binary_accuracy: 0.8768 - val_dice_coef: 0.2111 - val_dice_loss: 0.7889 - val_dice_p_bce: 0.7976 - val_loss: 0.8344 - val_true_positive_rate: 0.5378 - val_weighted_bincrossentropy: 0.8749
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8765 - dice_coef: 0.2115 - dice_loss: 0.7885 - dice_p_bce: 0.7968 - loss: 0.8344 - true_positive_rate: 0.5634 - weighted_bincrossentropy: 0.8330 - val_binary_accuracy: 0.8740 - val_dice_coef: 0.2149 - val_dice_loss: 0.7851 - val_dice_p_bce: 0.7937 - val_loss: 0.8312 - val_true_positive_rate: 0.5636 - val_weighted_bincrossentropy: 0.8558
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8773 - dice_coef: 0.2065 - dice_loss: 0.7935 - dice_p_bce: 0.8014 - loss: 0.8387 - true_positive_rate: 0.5764 - weighted_bincrossentropy: 0.7922 - val_binary_accuracy: 0.8755 - val_dice_coef: 0.2194 - val_dice_loss: 0.7806 - val_dice_p_bce: 0.7890 - val_loss: 0.8275 - val_true_positive_rate: 0.5716 - val_weighted_bincrossentropy: 0.8353
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.8816 - dice_coef: 0.2051 - dice_loss: 0.7949 - dice_p_bce: 0.8026 - loss: 0.8387 - true_positive_rate: 0.5673 - weighted_bincrossentropy: 0.7691 - val_binary_accuracy: 0.8793 - val_dice_coef: 0.2242 - val_dice_loss: 0.7758 - val_dice_p_bce: 0.7837 - val_loss: 0.8232 - val_true_positive_rate: 0.5739 - val_weighted_bincrossentropy: 0.7925
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8909 - dice_coef: 0.2128 - dice_loss: 0.7872 - dice_p_bce: 0.7941 - loss: 0.8339 - true_positive_rate: 0.5460 - weighted_bincrossentropy: 0.6930 - val_binary_accuracy: 0.8855 - val_dice_coef: 0.2251 - val_dice_loss: 0.7749 - val_dice_p_bce: 0.7823 - val_loss: 0.8216 - val_true_positive_rate: 0.5552 - val_weighted_bincrossentropy: 0.7363
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.8944 - dice_coef: 0.2130 - dice_loss: 0.7870 - dice_p_bce: 0.7936 - loss: 0.8317 - true_positive_rate: 0.5337 - weighted_bincrossentropy: 0.6607 - val_binary_accuracy: 0.9052 - val_dice_coef: 0.2256 - val_dice_loss: 0.7744 - val_dice_p_bce: 0.7811 - val_loss: 0.8177 - val_true_positive_rate: 0.4940 - val_weighted_bincrossentropy: 0.6627
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8832 - dice_coef: 0.2075 - dice_loss: 0.7925 - dice_p_bce: 0.7994 - loss: 0.8356 - true_positive_rate: 0.5563 - weighted_bincrossentropy: 0.6881 - val_binary_accuracy: 0.9356 - val_dice_coef: 0.1948 - val_dice_loss: 0.8052 - val_dice_p_bce: 0.8123 - val_loss: 0.8363 - val_true_positive_rate: 0.3165 - val_weighted_bincrossentropy: 0.7110
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8976 - dice_coef: 0.2070 - dice_loss: 0.7930 - dice_p_bce: 0.7998 - loss: 0.8343 - true_positive_rate: 0.4930 - weighted_bincrossentropy: 0.6757 - val_binary_accuracy: 0.8720 - val_dice_coef: 0.2265 - val_dice_loss: 0.7735 - val_dice_p_bce: 0.7801 - val_loss: 0.8203 - val_true_positive_rate: 0.6227 - val_weighted_bincrossentropy: 0.6616
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8935 - dice_coef: 0.2079 - dice_loss: 0.7921 - dice_p_bce: 0.7982 - loss: 0.8356 - true_positive_rate: 0.5345 - weighted_bincrossentropy: 0.6015 - val_binary_accuracy: 0.8761 - val_dice_coef: 0.2281 - val_dice_loss: 0.7719 - val_dice_p_bce: 0.7780 - val_loss: 0.8184 - val_true_positive_rate: 0.6227 - val_weighted_bincrossentropy: 0.6160
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.8957 - dice_coef: 0.2149 - dice_loss: 0.7851 - dice_p_bce: 0.7905 - loss: 0.8297 - true_positive_rate: 0.5611 - weighted_bincrossentropy: 0.5448 - val_binary_accuracy: 0.9098 - val_dice_coef: 0.2346 - val_dice_loss: 0.7654 - val_dice_p_bce: 0.7710 - val_loss: 0.8069 - val_true_positive_rate: 0.5207 - val_weighted_bincrossentropy: 0.5556
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9201 - dice_coef: 0.2451 - dice_loss: 0.7549 - dice_p_bce: 0.7600 - loss: 0.7999 - true_positive_rate: 0.5048 - weighted_bincrossentropy: 0.5021 - val_binary_accuracy: 0.9281 - val_dice_coef: 0.2405 - val_dice_loss: 0.7595 - val_dice_p_bce: 0.7646 - val_loss: 0.7977 - val_true_positive_rate: 0.4605 - val_weighted_bincrossentropy: 0.5129
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9169 - dice_coef: 0.2285 - dice_loss: 0.7715 - dice_p_bce: 0.7763 - loss: 0.8115 - true_positive_rate: 0.5135 - weighted_bincrossentropy: 0.4800 - val_binary_accuracy: 0.8931 - val_dice_coef: 0.2478 - val_dice_loss: 0.7522 - val_dice_p_bce: 0.7571 - val_loss: 0.7969 - val_true_positive_rate: 0.6481 - val_weighted_bincrossentropy: 0.4930
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9167 - dice_coef: 0.2436 - dice_loss: 0.7564 - dice_p_bce: 0.7609 - loss: 0.7997 - true_positive_rate: 0.5543 - weighted_bincrossentropy: 0.4525 - val_binary_accuracy: 0.9325 - val_dice_coef: 0.2624 - val_dice_loss: 0.7376 - val_dice_p_bce: 0.7424 - val_loss: 0.7733 - val_true_positive_rate: 0.5191 - val_weighted_bincrossentropy: 0.4728
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9406 - dice_coef: 0.2593 - dice_loss: 0.7407 - dice_p_bce: 0.7452 - loss: 0.7820 - true_positive_rate: 0.4610 - weighted_bincrossentropy: 0.4480 - val_binary_accuracy: 0.9467 - val_dice_coef: 0.2668 - val_dice_loss: 0.7332 - val_dice_p_bce: 0.7377 - val_loss: 0.7638 - val_true_positive_rate: 0.4537 - val_weighted_bincrossentropy: 0.4535
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9520 - dice_coef: 0.2795 - dice_loss: 0.7205 - dice_p_bce: 0.7245 - loss: 0.7624 - true_positive_rate: 0.4324 - weighted_bincrossentropy: 0.4034 - val_binary_accuracy: 0.9477 - val_dice_coef: 0.2825 - val_dice_loss: 0.7175 - val_dice_p_bce: 0.7217 - val_loss: 0.7478 - val_true_positive_rate: 0.4987 - val_weighted_bincrossentropy: 0.4165
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9526 - dice_coef: 0.2890 - dice_loss: 0.7110 - dice_p_bce: 0.7147 - loss: 0.7509 - true_positive_rate: 0.4780 - weighted_bincrossentropy: 0.3642 - val_binary_accuracy: 0.9671 - val_dice_coef: 0.2739 - val_dice_loss: 0.7261 - val_dice_p_bce: 0.7308 - val_loss: 0.7410 - val_true_positive_rate: 0.3542 - val_weighted_bincrossentropy: 0.4646
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9545 - dice_coef: 0.3054 - dice_loss: 0.6946 - dice_p_bce: 0.6982 - loss: 0.7353 - true_positive_rate: 0.4736 - weighted_bincrossentropy: 0.3634 - val_binary_accuracy: 0.9561 - val_dice_coef: 0.3274 - val_dice_loss: 0.6726 - val_dice_p_bce: 0.6762 - val_loss: 0.7034 - val_true_positive_rate: 0.5294 - val_weighted_bincrossentropy: 0.3593
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9549 - dice_coef: 0.3289 - dice_loss: 0.6711 - dice_p_bce: 0.6746 - loss: 0.7125 - true_positive_rate: 0.5130 - weighted_bincrossentropy: 0.3494 - val_binary_accuracy: 0.9605 - val_dice_coef: 0.3508 - val_dice_loss: 0.6492 - val_dice_p_bce: 0.6527 - val_loss: 0.6800 - val_true_positive_rate: 0.5393 - val_weighted_bincrossentropy: 0.3440
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9610 - dice_coef: 0.3615 - dice_loss: 0.6385 - dice_p_bce: 0.6418 - loss: 0.6819 - true_positive_rate: 0.5245 - weighted_bincrossentropy: 0.3309 - val_binary_accuracy: 0.9584 - val_dice_coef: 0.3733 - val_dice_loss: 0.6267 - val_dice_p_bce: 0.6297 - val_loss: 0.6640 - val_true_positive_rate: 0.5953 - val_weighted_bincrossentropy: 0.3031
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9632 - dice_coef: 0.3796 - dice_loss: 0.6204 - dice_p_bce: 0.6233 - loss: 0.6670 - true_positive_rate: 0.5447 - weighted_bincrossentropy: 0.2894 - val_binary_accuracy: 0.9707 - val_dice_coef: 0.3703 - val_dice_loss: 0.6297 - val_dice_p_bce: 0.6332 - val_loss: 0.6544 - val_true_positive_rate: 0.4596 - val_weighted_bincrossentropy: 0.3542
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9643 - dice_coef: 0.3807 - dice_loss: 0.6193 - dice_p_bce: 0.6223 - loss: 0.6643 - true_positive_rate: 0.5298 - weighted_bincrossentropy: 0.3020 - val_binary_accuracy: 0.9708 - val_dice_coef: 0.3852 - val_dice_loss: 0.6148 - val_dice_p_bce: 0.6183 - val_loss: 0.6403 - val_true_positive_rate: 0.4838 - val_weighted_bincrossentropy: 0.3529
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9661 - dice_coef: 0.3849 - dice_loss: 0.6151 - dice_p_bce: 0.6179 - loss: 0.6577 - true_positive_rate: 0.5521 - weighted_bincrossentropy: 0.2815 - val_binary_accuracy: 0.9718 - val_dice_coef: 0.3886 - val_dice_loss: 0.6114 - val_dice_p_bce: 0.6148 - val_loss: 0.6361 - val_true_positive_rate: 0.4771 - val_weighted_bincrossentropy: 0.3454
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9685 - dice_coef: 0.4092 - dice_loss: 0.5908 - dice_p_bce: 0.5936 - loss: 0.6384 - true_positive_rate: 0.5369 - weighted_bincrossentropy: 0.2768 - val_binary_accuracy: 0.9605 - val_dice_coef: 0.4366 - val_dice_loss: 0.5634 - val_dice_p_bce: 0.5658 - val_loss: 0.6104 - val_true_positive_rate: 0.6917 - val_weighted_bincrossentropy: 0.2362
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9672 - dice_coef: 0.4159 - dice_loss: 0.5841 - dice_p_bce: 0.5865 - loss: 0.6325 - true_positive_rate: 0.6022 - weighted_bincrossentropy: 0.2417 - val_binary_accuracy: 0.9696 - val_dice_coef: 0.4542 - val_dice_loss: 0.5458 - val_dice_p_bce: 0.5483 - val_loss: 0.5862 - val_true_positive_rate: 0.6074 - val_weighted_bincrossentropy: 0.2522
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9691 - dice_coef: 0.4513 - dice_loss: 0.5487 - dice_p_bce: 0.5511 - loss: 0.5998 - true_positive_rate: 0.6049 - weighted_bincrossentropy: 0.2426 - val_binary_accuracy: 0.9665 - val_dice_coef: 0.4690 - val_dice_loss: 0.5310 - val_dice_p_bce: 0.5333 - val_loss: 0.5790 - val_true_positive_rate: 0.6672 - val_weighted_bincrossentropy: 0.2332
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9682 - dice_coef: 0.4801 - dice_loss: 0.5199 - dice_p_bce: 0.5221 - loss: 0.5758 - true_positive_rate: 0.6488 - weighted_bincrossentropy: 0.2154 - val_binary_accuracy: 0.9704 - val_dice_coef: 0.4877 - val_dice_loss: 0.5123 - val_dice_p_bce: 0.5144 - val_loss: 0.5589 - val_true_positive_rate: 0.6512 - val_weighted_bincrossentropy: 0.2100
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9721 - dice_coef: 0.4663 - dice_loss: 0.5337 - dice_p_bce: 0.5357 - loss: 0.5866 - true_positive_rate: 0.6169 - weighted_bincrossentropy: 0.2018 - val_binary_accuracy: 0.9744 - val_dice_coef: 0.4509 - val_dice_loss: 0.5491 - val_dice_p_bce: 0.5520 - val_loss: 0.5813 - val_true_positive_rate: 0.5313 - val_weighted_bincrossentropy: 0.2805
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9727 - dice_coef: 0.4753 - dice_loss: 0.5247 - dice_p_bce: 0.5267 - loss: 0.5761 - true_positive_rate: 0.6063 - weighted_bincrossentropy: 0.2038 - val_binary_accuracy: 0.9692 - val_dice_coef: 0.5046 - val_dice_loss: 0.4954 - val_dice_p_bce: 0.4975 - val_loss: 0.5470 - val_true_positive_rate: 0.6942 - val_weighted_bincrossentropy: 0.2072
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9737 - dice_coef: 0.5095 - dice_loss: 0.4905 - dice_p_bce: 0.4924 - loss: 0.5475 - true_positive_rate: 0.6488 - weighted_bincrossentropy: 0.1991 - val_binary_accuracy: 0.9716 - val_dice_coef: 0.5221 - val_dice_loss: 0.4779 - val_dice_p_bce: 0.4798 - val_loss: 0.5307 - val_true_positive_rate: 0.6859 - val_weighted_bincrossentropy: 0.1917
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9748 - dice_coef: 0.5123 - dice_loss: 0.4877 - dice_p_bce: 0.4894 - loss: 0.5436 - true_positive_rate: 0.6575 - weighted_bincrossentropy: 0.1743 - val_binary_accuracy: 0.9704 - val_dice_coef: 0.5305 - val_dice_loss: 0.4695 - val_dice_p_bce: 0.4712 - val_loss: 0.5250 - val_true_positive_rate: 0.7230 - val_weighted_bincrossentropy: 0.1750
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9748 - dice_coef: 0.5374 - dice_loss: 0.4626 - dice_p_bce: 0.4642 - loss: 0.5225 - true_positive_rate: 0.6845 - weighted_bincrossentropy: 0.1632 - val_binary_accuracy: 0.9766 - val_dice_coef: 0.5265 - val_dice_loss: 0.4735 - val_dice_p_bce: 0.4757 - val_loss: 0.5196 - val_true_positive_rate: 0.5988 - val_weighted_bincrossentropy: 0.2271
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9752 - dice_coef: 0.5300 - dice_loss: 0.4700 - dice_p_bce: 0.4719 - loss: 0.5234 - true_positive_rate: 0.6489 - weighted_bincrossentropy: 0.1875 - val_binary_accuracy: 0.9726 - val_dice_coef: 0.5524 - val_dice_loss: 0.4476 - val_dice_p_bce: 0.4493 - val_loss: 0.5045 - val_true_positive_rate: 0.7211 - val_weighted_bincrossentropy: 0.1727
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9754 - dice_coef: 0.5600 - dice_loss: 0.4400 - dice_p_bce: 0.4416 - loss: 0.4999 - true_positive_rate: 0.6958 - weighted_bincrossentropy: 0.1622 - val_binary_accuracy: 0.9751 - val_dice_coef: 0.5632 - val_dice_loss: 0.4368 - val_dice_p_bce: 0.4386 - val_loss: 0.4925 - val_true_positive_rate: 0.6891 - val_weighted_bincrossentropy: 0.1825
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9763 - dice_coef: 0.5749 - dice_loss: 0.4251 - dice_p_bce: 0.4268 - loss: 0.4855 - true_positive_rate: 0.6944 - weighted_bincrossentropy: 0.1629 - val_binary_accuracy: 0.9776 - val_dice_coef: 0.5613 - val_dice_loss: 0.4387 - val_dice_p_bce: 0.4408 - val_loss: 0.4908 - val_true_positive_rate: 0.6284 - val_weighted_bincrossentropy: 0.2134
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9762 - dice_coef: 0.5611 - dice_loss: 0.4389 - dice_p_bce: 0.4406 - loss: 0.4996 - true_positive_rate: 0.6706 - weighted_bincrossentropy: 0.1716 - val_binary_accuracy: 0.9736 - val_dice_coef: 0.5751 - val_dice_loss: 0.4249 - val_dice_p_bce: 0.4264 - val_loss: 0.4851 - val_true_positive_rate: 0.7421 - val_weighted_bincrossentropy: 0.1574
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9758 - dice_coef: 0.5699 - dice_loss: 0.4301 - dice_p_bce: 0.4317 - loss: 0.4929 - true_positive_rate: 0.6936 - weighted_bincrossentropy: 0.1574 - val_binary_accuracy: 0.9784 - val_dice_coef: 0.5713 - val_dice_loss: 0.4287 - val_dice_p_bce: 0.4308 - val_loss: 0.4812 - val_true_positive_rate: 0.6321 - val_weighted_bincrossentropy: 0.2125
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9776 - dice_coef: 0.5847 - dice_loss: 0.4153 - dice_p_bce: 0.4170 - loss: 0.4781 - true_positive_rate: 0.6887 - weighted_bincrossentropy: 0.1643 - val_binary_accuracy: 0.9741 - val_dice_coef: 0.5870 - val_dice_loss: 0.4130 - val_dice_p_bce: 0.4145 - val_loss: 0.4746 - val_true_positive_rate: 0.7608 - val_weighted_bincrossentropy: 0.1455
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9774 - dice_coef: 0.5959 - dice_loss: 0.4041 - dice_p_bce: 0.4055 - loss: 0.4684 - true_positive_rate: 0.7162 - weighted_bincrossentropy: 0.1376 - val_binary_accuracy: 0.9784 - val_dice_coef: 0.5935 - val_dice_loss: 0.4065 - val_dice_p_bce: 0.4083 - val_loss: 0.4622 - val_true_positive_rate: 0.6792 - val_weighted_bincrossentropy: 0.1828
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9788 - dice_coef: 0.5929 - dice_loss: 0.4071 - dice_p_bce: 0.4087 - loss: 0.4679 - true_positive_rate: 0.7021 - weighted_bincrossentropy: 0.1559 - val_binary_accuracy: 0.9793 - val_dice_coef: 0.5891 - val_dice_loss: 0.4109 - val_dice_p_bce: 0.4128 - val_loss: 0.4634 - val_true_positive_rate: 0.6498 - val_weighted_bincrossentropy: 0.1908
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9806 - dice_coef: 0.5920 - dice_loss: 0.4080 - dice_p_bce: 0.4095 - loss: 0.4666 - true_positive_rate: 0.6735 - weighted_bincrossentropy: 0.1528 - val_binary_accuracy: 0.9796 - val_dice_coef: 0.6065 - val_dice_loss: 0.3935 - val_dice_p_bce: 0.3952 - val_loss: 0.4483 - val_true_positive_rate: 0.6782 - val_weighted_bincrossentropy: 0.1760
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9803 - dice_coef: 0.6277 - dice_loss: 0.3723 - dice_p_bce: 0.3738 - loss: 0.4362 - true_positive_rate: 0.7084 - weighted_bincrossentropy: 0.1432 - val_binary_accuracy: 0.9800 - val_dice_coef: 0.6080 - val_dice_loss: 0.3920 - val_dice_p_bce: 0.3938 - val_loss: 0.4452 - val_true_positive_rate: 0.6770 - val_weighted_bincrossentropy: 0.1780
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9808 - dice_coef: 0.6328 - dice_loss: 0.3672 - dice_p_bce: 0.3685 - loss: 0.4309 - true_positive_rate: 0.7203 - weighted_bincrossentropy: 0.1340 - val_binary_accuracy: 0.9786 - val_dice_coef: 0.6212 - val_dice_loss: 0.3788 - val_dice_p_bce: 0.3802 - val_loss: 0.4362 - val_true_positive_rate: 0.7431 - val_weighted_bincrossentropy: 0.1433
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9807 - dice_coef: 0.6288 - dice_loss: 0.3712 - dice_p_bce: 0.3725 - loss: 0.4342 - true_positive_rate: 0.7314 - weighted_bincrossentropy: 0.1282 - val_binary_accuracy: 0.9809 - val_dice_coef: 0.6203 - val_dice_loss: 0.3797 - val_dice_p_bce: 0.3813 - val_loss: 0.4326 - val_true_positive_rate: 0.6825 - val_weighted_bincrossentropy: 0.1652
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9814 - dice_coef: 0.6330 - dice_loss: 0.3670 - dice_p_bce: 0.3683 - loss: 0.4283 - true_positive_rate: 0.7167 - weighted_bincrossentropy: 0.1314 - val_binary_accuracy: 0.9789 - val_dice_coef: 0.6302 - val_dice_loss: 0.3698 - val_dice_p_bce: 0.3711 - val_loss: 0.4271 - val_true_positive_rate: 0.7572 - val_weighted_bincrossentropy: 0.1363
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9811 - dice_coef: 0.6257 - dice_loss: 0.3743 - dice_p_bce: 0.3756 - loss: 0.4367 - true_positive_rate: 0.7465 - weighted_bincrossentropy: 0.1224 - val_binary_accuracy: 0.9817 - val_dice_coef: 0.6212 - val_dice_loss: 0.3788 - val_dice_p_bce: 0.3806 - val_loss: 0.4310 - val_true_positive_rate: 0.6545 - val_weighted_bincrossentropy: 0.1804
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9825 - dice_coef: 0.6447 - dice_loss: 0.3553 - dice_p_bce: 0.3565 - loss: 0.4198 - true_positive_rate: 0.7189 - weighted_bincrossentropy: 0.1246 - val_binary_accuracy: 0.9805 - val_dice_coef: 0.6417 - val_dice_loss: 0.3583 - val_dice_p_bce: 0.3597 - val_loss: 0.4146 - val_true_positive_rate: 0.7410 - val_weighted_bincrossentropy: 0.1397
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9832 - dice_coef: 0.6519 - dice_loss: 0.3481 - dice_p_bce: 0.3493 - loss: 0.4119 - true_positive_rate: 0.7267 - weighted_bincrossentropy: 0.1201 - val_binary_accuracy: 0.9793 - val_dice_coef: 0.6473 - val_dice_loss: 0.3527 - val_dice_p_bce: 0.3539 - val_loss: 0.4127 - val_true_positive_rate: 0.7908 - val_weighted_bincrossentropy: 0.1120
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9819 - dice_coef: 0.6574 - dice_loss: 0.3426 - dice_p_bce: 0.3437 - loss: 0.4061 - true_positive_rate: 0.7643 - weighted_bincrossentropy: 0.1088 - val_binary_accuracy: 0.9811 - val_dice_coef: 0.6592 - val_dice_loss: 0.3408 - val_dice_p_bce: 0.3421 - val_loss: 0.3993 - val_true_positive_rate: 0.7613 - val_weighted_bincrossentropy: 0.1239
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9827 - dice_coef: 0.6624 - dice_loss: 0.3376 - dice_p_bce: 0.3387 - loss: 0.3999 - true_positive_rate: 0.7520 - weighted_bincrossentropy: 0.1144 - val_binary_accuracy: 0.9814 - val_dice_coef: 0.6615 - val_dice_loss: 0.3385 - val_dice_p_bce: 0.3398 - val_loss: 0.3958 - val_true_positive_rate: 0.7553 - val_weighted_bincrossentropy: 0.1312
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9809 - dice_coef: 0.6441 - dice_loss: 0.3559 - dice_p_bce: 0.3571 - loss: 0.4171 - true_positive_rate: 0.7623 - weighted_bincrossentropy: 0.1206 - val_binary_accuracy: 0.9824 - val_dice_coef: 0.6101 - val_dice_loss: 0.3899 - val_dice_p_bce: 0.3921 - val_loss: 0.4404 - val_true_positive_rate: 0.6052 - val_weighted_bincrossentropy: 0.2218
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9826 - dice_coef: 0.6495 - dice_loss: 0.3505 - dice_p_bce: 0.3520 - loss: 0.4138 - true_positive_rate: 0.6998 - weighted_bincrossentropy: 0.1475 - val_binary_accuracy: 0.9810 - val_dice_coef: 0.6600 - val_dice_loss: 0.3400 - val_dice_p_bce: 0.3413 - val_loss: 0.3983 - val_true_positive_rate: 0.7663 - val_weighted_bincrossentropy: 0.1275
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9815 - dice_coef: 0.6641 - dice_loss: 0.3359 - dice_p_bce: 0.3370 - loss: 0.4000 - true_positive_rate: 0.7728 - weighted_bincrossentropy: 0.1151 - val_binary_accuracy: 0.9782 - val_dice_coef: 0.6494 - val_dice_loss: 0.3506 - val_dice_p_bce: 0.3516 - val_loss: 0.4119 - val_true_positive_rate: 0.8309 - val_weighted_bincrossentropy: 0.1027
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9822 - dice_coef: 0.6621 - dice_loss: 0.3379 - dice_p_bce: 0.3390 - loss: 0.4008 - true_positive_rate: 0.7672 - weighted_bincrossentropy: 0.1135 - val_binary_accuracy: 0.9831 - val_dice_coef: 0.6532 - val_dice_loss: 0.3468 - val_dice_p_bce: 0.3484 - val_loss: 0.4001 - val_true_positive_rate: 0.6855 - val_weighted_bincrossentropy: 0.1649
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9842 - dice_coef: 0.6784 - dice_loss: 0.3216 - dice_p_bce: 0.3229 - loss: 0.3828 - true_positive_rate: 0.7273 - weighted_bincrossentropy: 0.1286 - val_binary_accuracy: 0.9833 - val_dice_coef: 0.6730 - val_dice_loss: 0.3270 - val_dice_p_bce: 0.3284 - val_loss: 0.3837 - val_true_positive_rate: 0.7200 - val_weighted_bincrossentropy: 0.1382
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9850 - dice_coef: 0.6919 - dice_loss: 0.3081 - dice_p_bce: 0.3091 - loss: 0.3730 - true_positive_rate: 0.7550 - weighted_bincrossentropy: 0.1039 - val_binary_accuracy: 0.9820 - val_dice_coef: 0.6832 - val_dice_loss: 0.3168 - val_dice_p_bce: 0.3179 - val_loss: 0.3765 - val_true_positive_rate: 0.7876 - val_weighted_bincrossentropy: 0.1133
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9837 - dice_coef: 0.6987 - dice_loss: 0.3013 - dice_p_bce: 0.3023 - loss: 0.3644 - true_positive_rate: 0.7832 - weighted_bincrossentropy: 0.1020 - val_binary_accuracy: 0.9834 - val_dice_coef: 0.6860 - val_dice_loss: 0.3140 - val_dice_p_bce: 0.3153 - val_loss: 0.3718 - val_true_positive_rate: 0.7407 - val_weighted_bincrossentropy: 0.1311
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9852 - dice_coef: 0.6998 - dice_loss: 0.3002 - dice_p_bce: 0.3012 - loss: 0.3645 - true_positive_rate: 0.7645 - weighted_bincrossentropy: 0.1023 - val_binary_accuracy: 0.9839 - val_dice_coef: 0.6722 - val_dice_loss: 0.3278 - val_dice_p_bce: 0.3294 - val_loss: 0.3817 - val_true_positive_rate: 0.6932 - val_weighted_bincrossentropy: 0.1577
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9845 - dice_coef: 0.7028 - dice_loss: 0.2972 - dice_p_bce: 0.2984 - loss: 0.3588 - true_positive_rate: 0.7545 - weighted_bincrossentropy: 0.1173 - val_binary_accuracy: 0.9819 - val_dice_coef: 0.6891 - val_dice_loss: 0.3109 - val_dice_p_bce: 0.3120 - val_loss: 0.3712 - val_true_positive_rate: 0.8082 - val_weighted_bincrossentropy: 0.1075
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9843 - dice_coef: 0.7028 - dice_loss: 0.2972 - dice_p_bce: 0.2983 - loss: 0.3599 - true_positive_rate: 0.7824 - weighted_bincrossentropy: 0.1064 - val_binary_accuracy: 0.9839 - val_dice_coef: 0.6869 - val_dice_loss: 0.3131 - val_dice_p_bce: 0.3145 - val_loss: 0.3683 - val_true_positive_rate: 0.7337 - val_weighted_bincrossentropy: 0.1397
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - binary_accuracy: 0.9845 - dice_coef: 0.6934 - dice_loss: 0.3066 - dice_p_bce: 0.3077 - loss: 0.3701 - true_positive_rate: 0.7720 - weighted_bincrossentropy: 0.1036 - val_binary_accuracy: 0.9826 - val_dice_coef: 0.6962 - val_dice_loss: 0.3038 - val_dice_p_bce: 0.3049 - val_loss: 0.3633 - val_true_positive_rate: 0.8013 - val_weighted_bincrossentropy: 0.1104
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9845 - dice_coef: 0.7122 - dice_loss: 0.2878 - dice_p_bce: 0.2889 - loss: 0.3505 - true_positive_rate: 0.7831 - weighted_bincrossentropy: 0.1035 - val_binary_accuracy: 0.9842 - val_dice_coef: 0.6980 - val_dice_loss: 0.3020 - val_dice_p_bce: 0.3033 - val_loss: 0.3591 - val_true_positive_rate: 0.7435 - val_weighted_bincrossentropy: 0.1351
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9855 - dice_coef: 0.7092 - dice_loss: 0.2908 - dice_p_bce: 0.2919 - loss: 0.3529 - true_positive_rate: 0.7778 - weighted_bincrossentropy: 0.1015 - val_binary_accuracy: 0.9832 - val_dice_coef: 0.7031 - val_dice_loss: 0.2969 - val_dice_p_bce: 0.2979 - val_loss: 0.3565 - val_true_positive_rate: 0.7975 - val_weighted_bincrossentropy: 0.1070
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9849 - dice_coef: 0.7176 - dice_loss: 0.2824 - dice_p_bce: 0.2834 - loss: 0.3438 - true_positive_rate: 0.7796 - weighted_bincrossentropy: 0.1048 - val_binary_accuracy: 0.9836 - val_dice_coef: 0.7062 - val_dice_loss: 0.2938 - val_dice_p_bce: 0.2949 - val_loss: 0.3524 - val_true_positive_rate: 0.7896 - val_weighted_bincrossentropy: 0.1153
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9851 - dice_coef: 0.7207 - dice_loss: 0.2793 - dice_p_bce: 0.2802 - loss: 0.3422 - true_positive_rate: 0.8016 - weighted_bincrossentropy: 0.0947 - val_binary_accuracy: 0.9844 - val_dice_coef: 0.7044 - val_dice_loss: 0.2956 - val_dice_p_bce: 0.2969 - val_loss: 0.3521 - val_true_positive_rate: 0.7575 - val_weighted_bincrossentropy: 0.1306
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9866 - dice_coef: 0.7224 - dice_loss: 0.2776 - dice_p_bce: 0.2786 - loss: 0.3397 - true_positive_rate: 0.7762 - weighted_bincrossentropy: 0.1000 - val_binary_accuracy: 0.9841 - val_dice_coef: 0.7103 - val_dice_loss: 0.2897 - val_dice_p_bce: 0.2909 - val_loss: 0.3482 - val_true_positive_rate: 0.7809 - val_weighted_bincrossentropy: 0.1154
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9857 - dice_coef: 0.7285 - dice_loss: 0.2715 - dice_p_bce: 0.2725 - loss: 0.3325 - true_positive_rate: 0.7961 - weighted_bincrossentropy: 0.0984 - val_binary_accuracy: 0.9849 - val_dice_coef: 0.7070 - val_dice_loss: 0.2930 - val_dice_p_bce: 0.2944 - val_loss: 0.3492 - val_true_positive_rate: 0.7404 - val_weighted_bincrossentropy: 0.1344
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9866 - dice_coef: 0.7299 - dice_loss: 0.2701 - dice_p_bce: 0.2710 - loss: 0.3326 - true_positive_rate: 0.7862 - weighted_bincrossentropy: 0.0954 - val_binary_accuracy: 0.9845 - val_dice_coef: 0.7142 - val_dice_loss: 0.2858 - val_dice_p_bce: 0.2870 - val_loss: 0.3432 - val_true_positive_rate: 0.7779 - val_weighted_bincrossentropy: 0.1195
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9865 - dice_coef: 0.7365 - dice_loss: 0.2635 - dice_p_bce: 0.2645 - loss: 0.3251 - true_positive_rate: 0.7862 - weighted_bincrossentropy: 0.1015 - val_binary_accuracy: 0.9823 - val_dice_coef: 0.7062 - val_dice_loss: 0.2938 - val_dice_p_bce: 0.2948 - val_loss: 0.3544 - val_true_positive_rate: 0.8393 - val_weighted_bincrossentropy: 0.0989
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9862 - dice_coef: 0.7252 - dice_loss: 0.2748 - dice_p_bce: 0.2757 - loss: 0.3372 - true_positive_rate: 0.8078 - weighted_bincrossentropy: 0.0924 - val_binary_accuracy: 0.9851 - val_dice_coef: 0.7005 - val_dice_loss: 0.2995 - val_dice_p_bce: 0.3011 - val_loss: 0.3537 - val_true_positive_rate: 0.7126 - val_weighted_bincrossentropy: 0.1581
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9860 - dice_coef: 0.7290 - dice_loss: 0.2710 - dice_p_bce: 0.2721 - loss: 0.3307 - true_positive_rate: 0.7794 - weighted_bincrossentropy: 0.1108 - val_binary_accuracy: 0.9847 - val_dice_coef: 0.7222 - val_dice_loss: 0.2778 - val_dice_p_bce: 0.2789 - val_loss: 0.3360 - val_true_positive_rate: 0.7887 - val_weighted_bincrossentropy: 0.1157
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9872 - dice_coef: 0.7395 - dice_loss: 0.2605 - dice_p_bce: 0.2615 - loss: 0.3215 - true_positive_rate: 0.7919 - weighted_bincrossentropy: 0.0983 - val_binary_accuracy: 0.9836 - val_dice_coef: 0.7185 - val_dice_loss: 0.2815 - val_dice_p_bce: 0.2825 - val_loss: 0.3418 - val_true_positive_rate: 0.8197 - val_weighted_bincrossentropy: 0.1036
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9864 - dice_coef: 0.7415 - dice_loss: 0.2585 - dice_p_bce: 0.2594 - loss: 0.3199 - true_positive_rate: 0.8090 - weighted_bincrossentropy: 0.0935 - val_binary_accuracy: 0.9853 - val_dice_coef: 0.7223 - val_dice_loss: 0.2777 - val_dice_p_bce: 0.2790 - val_loss: 0.3343 - val_true_positive_rate: 0.7643 - val_weighted_bincrossentropy: 0.1275
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9868 - dice_coef: 0.7476 - dice_loss: 0.2524 - dice_p_bce: 0.2534 - loss: 0.3135 - true_positive_rate: 0.8035 - weighted_bincrossentropy: 0.0954 - val_binary_accuracy: 0.9853 - val_dice_coef: 0.7248 - val_dice_loss: 0.2752 - val_dice_p_bce: 0.2765 - val_loss: 0.3328 - val_true_positive_rate: 0.7642 - val_weighted_bincrossentropy: 0.1308
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9874 - dice_coef: 0.7494 - dice_loss: 0.2506 - dice_p_bce: 0.2516 - loss: 0.3119 - true_positive_rate: 0.8006 - weighted_bincrossentropy: 0.0950 - val_binary_accuracy: 0.9851 - val_dice_coef: 0.7289 - val_dice_loss: 0.2711 - val_dice_p_bce: 0.2723 - val_loss: 0.3291 - val_true_positive_rate: 0.7835 - val_weighted_bincrossentropy: 0.1179
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9872 - dice_coef: 0.7491 - dice_loss: 0.2509 - dice_p_bce: 0.2519 - loss: 0.3109 - true_positive_rate: 0.8012 - weighted_bincrossentropy: 0.0953 - val_binary_accuracy: 0.9848 - val_dice_coef: 0.7319 - val_dice_loss: 0.2681 - val_dice_p_bce: 0.2692 - val_loss: 0.3265 - val_true_positive_rate: 0.8127 - val_weighted_bincrossentropy: 0.1062
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9873 - dice_coef: 0.7530 - dice_loss: 0.2470 - dice_p_bce: 0.2479 - loss: 0.3080 - true_positive_rate: 0.8155 - weighted_bincrossentropy: 0.0893 - val_binary_accuracy: 0.9852 - val_dice_coef: 0.7317 - val_dice_loss: 0.2683 - val_dice_p_bce: 0.2695 - val_loss: 0.3260 - val_true_positive_rate: 0.7924 - val_weighted_bincrossentropy: 0.1187
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9873 - dice_coef: 0.7536 - dice_loss: 0.2464 - dice_p_bce: 0.2473 - loss: 0.3074 - true_positive_rate: 0.8155 - weighted_bincrossentropy: 0.0904 - val_binary_accuracy: 0.9858 - val_dice_coef: 0.7149 - val_dice_loss: 0.2851 - val_dice_p_bce: 0.2867 - val_loss: 0.3408 - val_true_positive_rate: 0.7119 - val_weighted_bincrossentropy: 0.1612
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9874 - dice_coef: 0.7474 - dice_loss: 0.2526 - dice_p_bce: 0.2535 - loss: 0.3141 - true_positive_rate: 0.7888 - weighted_bincrossentropy: 0.0980 - val_binary_accuracy: 0.9859 - val_dice_coef: 0.7257 - val_dice_loss: 0.2743 - val_dice_p_bce: 0.2757 - val_loss: 0.3289 - val_true_positive_rate: 0.7523 - val_weighted_bincrossentropy: 0.1363
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9871 - dice_coef: 0.7550 - dice_loss: 0.2450 - dice_p_bce: 0.2461 - loss: 0.3048 - true_positive_rate: 0.7938 - weighted_bincrossentropy: 0.1047 - val_binary_accuracy: 0.9855 - val_dice_coef: 0.7349 - val_dice_loss: 0.2651 - val_dice_p_bce: 0.2663 - val_loss: 0.3225 - val_true_positive_rate: 0.7901 - val_weighted_bincrossentropy: 0.1156
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9875 - dice_coef: 0.7558 - dice_loss: 0.2442 - dice_p_bce: 0.2451 - loss: 0.3035 - true_positive_rate: 0.8081 - weighted_bincrossentropy: 0.0935 - val_binary_accuracy: 0.9860 - val_dice_coef: 0.7343 - val_dice_loss: 0.2657 - val_dice_p_bce: 0.2670 - val_loss: 0.3218 - val_true_positive_rate: 0.7666 - val_weighted_bincrossentropy: 0.1260
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9881 - dice_coef: 0.7572 - dice_loss: 0.2428 - dice_p_bce: 0.2438 - loss: 0.3034 - true_positive_rate: 0.8084 - weighted_bincrossentropy: 0.0915 - val_binary_accuracy: 0.9860 - val_dice_coef: 0.7344 - val_dice_loss: 0.2656 - val_dice_p_bce: 0.2668 - val_loss: 0.3212 - val_true_positive_rate: 0.7677 - val_weighted_bincrossentropy: 0.1295
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9877 - dice_coef: 0.7630 - dice_loss: 0.2370 - dice_p_bce: 0.2380 - loss: 0.2969 - true_positive_rate: 0.8118 - weighted_bincrossentropy: 0.0961 - val_binary_accuracy: 0.9859 - val_dice_coef: 0.7404 - val_dice_loss: 0.2596 - val_dice_p_bce: 0.2608 - val_loss: 0.3163 - val_true_positive_rate: 0.7906 - val_weighted_bincrossentropy: 0.1177
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9877 - dice_coef: 0.7629 - dice_loss: 0.2371 - dice_p_bce: 0.2381 - loss: 0.2960 - true_positive_rate: 0.8058 - weighted_bincrossentropy: 0.0991 - val_binary_accuracy: 0.9847 - val_dice_coef: 0.7389 - val_dice_loss: 0.2611 - val_dice_p_bce: 0.2620 - val_loss: 0.3199 - val_true_positive_rate: 0.8395 - val_weighted_bincrossentropy: 0.0982
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9877 - dice_coef: 0.7607 - dice_loss: 0.2393 - dice_p_bce: 0.2402 - loss: 0.3000 - true_positive_rate: 0.8179 - weighted_bincrossentropy: 0.0894 - val_binary_accuracy: 0.9836 - val_dice_coef: 0.7307 - val_dice_loss: 0.2693 - val_dice_p_bce: 0.2703 - val_loss: 0.3298 - val_true_positive_rate: 0.8554 - val_weighted_bincrossentropy: 0.0933
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9869 - dice_coef: 0.7546 - dice_loss: 0.2454 - dice_p_bce: 0.2463 - loss: 0.3055 - true_positive_rate: 0.8243 - weighted_bincrossentropy: 0.0933 - val_binary_accuracy: 0.9856 - val_dice_coef: 0.7414 - val_dice_loss: 0.2586 - val_dice_p_bce: 0.2597 - val_loss: 0.3159 - val_true_positive_rate: 0.8066 - val_weighted_bincrossentropy: 0.1135
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9874 - dice_coef: 0.7634 - dice_loss: 0.2366 - dice_p_bce: 0.2375 - loss: 0.2962 - true_positive_rate: 0.8250 - weighted_bincrossentropy: 0.0914 - val_binary_accuracy: 0.9862 - val_dice_coef: 0.7408 - val_dice_loss: 0.2592 - val_dice_p_bce: 0.2605 - val_loss: 0.3150 - val_true_positive_rate: 0.7767 - val_weighted_bincrossentropy: 0.1268
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9886 - dice_coef: 0.7647 - dice_loss: 0.2353 - dice_p_bce: 0.2362 - loss: 0.2948 - true_positive_rate: 0.8024 - weighted_bincrossentropy: 0.0950 - val_binary_accuracy: 0.9858 - val_dice_coef: 0.7449 - val_dice_loss: 0.2551 - val_dice_p_bce: 0.2562 - val_loss: 0.3125 - val_true_positive_rate: 0.8060 - val_weighted_bincrossentropy: 0.1117
# Epoch 104/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9880 - dice_coef: 0.7703 - dice_loss: 0.2297 - dice_p_bce: 0.2306 - loss: 0.2884 - true_positive_rate: 0.8215 - weighted_bincrossentropy: 0.0897 - val_binary_accuracy: 0.9861 - val_dice_coef: 0.7438 - val_dice_loss: 0.2562 - val_dice_p_bce: 0.2574 - val_loss: 0.3123 - val_true_positive_rate: 0.7939 - val_weighted_bincrossentropy: 0.1161
# Epoch 105/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9880 - dice_coef: 0.7744 - dice_loss: 0.2256 - dice_p_bce: 0.2265 - loss: 0.2842 - true_positive_rate: 0.8196 - weighted_bincrossentropy: 0.0919 - val_binary_accuracy: 0.9861 - val_dice_coef: 0.7491 - val_dice_loss: 0.2509 - val_dice_p_bce: 0.2520 - val_loss: 0.3079 - val_true_positive_rate: 0.8088 - val_weighted_bincrossentropy: 0.1109
# Epoch 106/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9880 - dice_coef: 0.7744 - dice_loss: 0.2256 - dice_p_bce: 0.2265 - loss: 0.2838 - true_positive_rate: 0.8269 - weighted_bincrossentropy: 0.0897 - val_binary_accuracy: 0.9863 - val_dice_coef: 0.7483 - val_dice_loss: 0.2517 - val_dice_p_bce: 0.2529 - val_loss: 0.3076 - val_true_positive_rate: 0.7963 - val_weighted_bincrossentropy: 0.1168
# Epoch 107/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9884 - dice_coef: 0.7742 - dice_loss: 0.2258 - dice_p_bce: 0.2268 - loss: 0.2838 - true_positive_rate: 0.8211 - weighted_bincrossentropy: 0.0908 - val_binary_accuracy: 0.9867 - val_dice_coef: 0.7458 - val_dice_loss: 0.2542 - val_dice_p_bce: 0.2555 - val_loss: 0.3094 - val_true_positive_rate: 0.7660 - val_weighted_bincrossentropy: 0.1300
# Epoch 108/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9887 - dice_coef: 0.7715 - dice_loss: 0.2285 - dice_p_bce: 0.2294 - loss: 0.2869 - true_positive_rate: 0.8101 - weighted_bincrossentropy: 0.0917 - val_binary_accuracy: 0.9868 - val_dice_coef: 0.7401 - val_dice_loss: 0.2599 - val_dice_p_bce: 0.2613 - val_loss: 0.3149 - val_true_positive_rate: 0.7445 - val_weighted_bincrossentropy: 0.1411
# Epoch 109/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9882 - dice_coef: 0.7730 - dice_loss: 0.2270 - dice_p_bce: 0.2279 - loss: 0.2848 - true_positive_rate: 0.8095 - weighted_bincrossentropy: 0.0994 - val_binary_accuracy: 0.9868 - val_dice_coef: 0.7445 - val_dice_loss: 0.2555 - val_dice_p_bce: 0.2569 - val_loss: 0.3097 - val_true_positive_rate: 0.7625 - val_weighted_bincrossentropy: 0.1330
# Epoch 110/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9886 - dice_coef: 0.7769 - dice_loss: 0.2231 - dice_p_bce: 0.2241 - loss: 0.2813 - true_positive_rate: 0.8114 - weighted_bincrossentropy: 0.0940 - val_binary_accuracy: 0.9863 - val_dice_coef: 0.7527 - val_dice_loss: 0.2473 - val_dice_p_bce: 0.2485 - val_loss: 0.3033 - val_true_positive_rate: 0.8087 - val_weighted_bincrossentropy: 0.1136
# Epoch 111/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9889 - dice_coef: 0.7753 - dice_loss: 0.2247 - dice_p_bce: 0.2256 - loss: 0.2838 - true_positive_rate: 0.8157 - weighted_bincrossentropy: 0.0899 - val_binary_accuracy: 0.9851 - val_dice_coef: 0.7479 - val_dice_loss: 0.2521 - val_dice_p_bce: 0.2531 - val_loss: 0.3108 - val_true_positive_rate: 0.8498 - val_weighted_bincrossentropy: 0.0937
# Epoch 112/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9885 - dice_coef: 0.7731 - dice_loss: 0.2269 - dice_p_bce: 0.2277 - loss: 0.2867 - true_positive_rate: 0.8312 - weighted_bincrossentropy: 0.0863 - val_binary_accuracy: 0.9868 - val_dice_coef: 0.7521 - val_dice_loss: 0.2479 - val_dice_p_bce: 0.2491 - val_loss: 0.3035 - val_true_positive_rate: 0.7846 - val_weighted_bincrossentropy: 0.1228
# Epoch 113/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9884 - dice_coef: 0.7761 - dice_loss: 0.2239 - dice_p_bce: 0.2249 - loss: 0.2810 - true_positive_rate: 0.8193 - weighted_bincrossentropy: 0.0942 - val_binary_accuracy: 0.9869 - val_dice_coef: 0.7359 - val_dice_loss: 0.2641 - val_dice_p_bce: 0.2657 - val_loss: 0.3180 - val_true_positive_rate: 0.7277 - val_weighted_bincrossentropy: 0.1553
# Epoch 114/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 3s/step - binary_accuracy: 0.9883 - dice_coef: 0.7618 - dice_loss: 0.2382 - dice_p_bce: 0.2392 - loss: 0.2958 - true_positive_rate: 0.7973 - weighted_bincrossentropy: 0.1019 - val_binary_accuracy: 0.9868 - val_dice_coef: 0.7500 - val_dice_loss: 0.2500 - val_dice_p_bce: 0.2513 - val_loss: 0.3040 - val_true_positive_rate: 0.7844 - val_weighted_bincrossentropy: 0.1309
# Epoch 115/500
# ...
# Epoch 463/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8751 - dice_loss: 0.1249 - dice_p_bce: 0.1258 - loss: 0.1645 - true_positive_rate: 0.8839 - weighted_bincrossentropy: 0.0895 - val_binary_accuracy: 0.9900 - val_dice_coef: 0.8206 - val_dice_loss: 0.1794 - val_dice_p_bce: 0.1809 - val_loss: 0.2274 - val_true_positive_rate: 0.8492 - val_weighted_bincrossentropy: 0.1423
# Epoch 464/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8796 - dice_loss: 0.1204 - dice_p_bce: 0.1212 - loss: 0.1601 - true_positive_rate: 0.9036 - weighted_bincrossentropy: 0.0805 - val_binary_accuracy: 0.9895 - val_dice_coef: 0.8165 - val_dice_loss: 0.1835 - val_dice_p_bce: 0.1848 - val_loss: 0.2325 - val_true_positive_rate: 0.8703 - val_weighted_bincrossentropy: 0.1279
# Epoch 465/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8792 - dice_loss: 0.1208 - dice_p_bce: 0.1216 - loss: 0.1606 - true_positive_rate: 0.9021 - weighted_bincrossentropy: 0.0813 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8203 - val_dice_loss: 0.1797 - val_dice_p_bce: 0.1811 - val_loss: 0.2272 - val_true_positive_rate: 0.8392 - val_weighted_bincrossentropy: 0.1485
# Epoch 466/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8850 - dice_loss: 0.1150 - dice_p_bce: 0.1159 - loss: 0.1526 - true_positive_rate: 0.8975 - weighted_bincrossentropy: 0.0905 - val_binary_accuracy: 0.9899 - val_dice_coef: 0.8196 - val_dice_loss: 0.1804 - val_dice_p_bce: 0.1818 - val_loss: 0.2286 - val_true_positive_rate: 0.8516 - val_weighted_bincrossentropy: 0.1386
# Epoch 467/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9934 - dice_coef: 0.8763 - dice_loss: 0.1237 - dice_p_bce: 0.1246 - loss: 0.1629 - true_positive_rate: 0.8952 - weighted_bincrossentropy: 0.0902 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8186 - val_dice_loss: 0.1814 - val_dice_p_bce: 0.1831 - val_loss: 0.2289 - val_true_positive_rate: 0.8186 - val_weighted_bincrossentropy: 0.1626
# Epoch 468/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9941 - dice_coef: 0.8778 - dice_loss: 0.1222 - dice_p_bce: 0.1230 - loss: 0.1620 - true_positive_rate: 0.8918 - weighted_bincrossentropy: 0.0830 - val_binary_accuracy: 0.9899 - val_dice_coef: 0.8197 - val_dice_loss: 0.1803 - val_dice_p_bce: 0.1816 - val_loss: 0.2284 - val_true_positive_rate: 0.8566 - val_weighted_bincrossentropy: 0.1348
# Epoch 469/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8820 - dice_loss: 0.1180 - dice_p_bce: 0.1189 - loss: 0.1565 - true_positive_rate: 0.9055 - weighted_bincrossentropy: 0.0839 - val_binary_accuracy: 0.9900 - val_dice_coef: 0.8198 - val_dice_loss: 0.1802 - val_dice_p_bce: 0.1817 - val_loss: 0.2281 - val_true_positive_rate: 0.8495 - val_weighted_bincrossentropy: 0.1422
# Epoch 470/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8816 - dice_loss: 0.1184 - dice_p_bce: 0.1193 - loss: 0.1568 - true_positive_rate: 0.9013 - weighted_bincrossentropy: 0.0848 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8176 - val_dice_loss: 0.1824 - val_dice_p_bce: 0.1840 - val_loss: 0.2299 - val_true_positive_rate: 0.8149 - val_weighted_bincrossentropy: 0.1661
# Epoch 471/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8815 - dice_loss: 0.1185 - dice_p_bce: 0.1194 - loss: 0.1573 - true_positive_rate: 0.8943 - weighted_bincrossentropy: 0.0836 - val_binary_accuracy: 0.9899 - val_dice_coef: 0.8203 - val_dice_loss: 0.1797 - val_dice_p_bce: 0.1811 - val_loss: 0.2277 - val_true_positive_rate: 0.8550 - val_weighted_bincrossentropy: 0.1376
# Epoch 472/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9940 - dice_coef: 0.8831 - dice_loss: 0.1169 - dice_p_bce: 0.1177 - loss: 0.1550 - true_positive_rate: 0.9039 - weighted_bincrossentropy: 0.0843 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8205 - val_dice_loss: 0.1795 - val_dice_p_bce: 0.1810 - val_loss: 0.2271 - val_true_positive_rate: 0.8275 - val_weighted_bincrossentropy: 0.1577
# Epoch 473/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8873 - dice_loss: 0.1127 - dice_p_bce: 0.1136 - loss: 0.1500 - true_positive_rate: 0.9013 - weighted_bincrossentropy: 0.0867 - val_binary_accuracy: 0.9900 - val_dice_coef: 0.8203 - val_dice_loss: 0.1797 - val_dice_p_bce: 0.1811 - val_loss: 0.2275 - val_true_positive_rate: 0.8538 - val_weighted_bincrossentropy: 0.1408
# Epoch 474/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9941 - dice_coef: 0.8867 - dice_loss: 0.1133 - dice_p_bce: 0.1142 - loss: 0.1511 - true_positive_rate: 0.9052 - weighted_bincrossentropy: 0.0838 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8185 - val_dice_loss: 0.1815 - val_dice_p_bce: 0.1832 - val_loss: 0.2290 - val_true_positive_rate: 0.8178 - val_weighted_bincrossentropy: 0.1660
# Epoch 475/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8845 - dice_loss: 0.1155 - dice_p_bce: 0.1163 - loss: 0.1537 - true_positive_rate: 0.8968 - weighted_bincrossentropy: 0.0841 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.8200 - val_dice_loss: 0.1800 - val_dice_p_bce: 0.1815 - val_loss: 0.2277 - val_true_positive_rate: 0.8398 - val_weighted_bincrossentropy: 0.1500
# Epoch 476/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8860 - dice_loss: 0.1140 - dice_p_bce: 0.1149 - loss: 0.1510 - true_positive_rate: 0.9040 - weighted_bincrossentropy: 0.0903 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8183 - val_dice_loss: 0.1817 - val_dice_p_bce: 0.1833 - val_loss: 0.2290 - val_true_positive_rate: 0.8238 - val_weighted_bincrossentropy: 0.1628
# Epoch 477/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8861 - dice_loss: 0.1139 - dice_p_bce: 0.1147 - loss: 0.1512 - true_positive_rate: 0.9020 - weighted_bincrossentropy: 0.0870 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.8214 - val_dice_loss: 0.1786 - val_dice_p_bce: 0.1800 - val_loss: 0.2262 - val_true_positive_rate: 0.8466 - val_weighted_bincrossentropy: 0.1453
# Epoch 478/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8848 - dice_loss: 0.1152 - dice_p_bce: 0.1160 - loss: 0.1531 - true_positive_rate: 0.9057 - weighted_bincrossentropy: 0.0815 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8183 - val_dice_loss: 0.1817 - val_dice_p_bce: 0.1833 - val_loss: 0.2288 - val_true_positive_rate: 0.8261 - val_weighted_bincrossentropy: 0.1611
# Epoch 479/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8875 - dice_loss: 0.1125 - dice_p_bce: 0.1134 - loss: 0.1497 - true_positive_rate: 0.9032 - weighted_bincrossentropy: 0.0872 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.8205 - val_dice_loss: 0.1795 - val_dice_p_bce: 0.1810 - val_loss: 0.2272 - val_true_positive_rate: 0.8446 - val_weighted_bincrossentropy: 0.1478
# Epoch 480/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8868 - dice_loss: 0.1132 - dice_p_bce: 0.1140 - loss: 0.1506 - true_positive_rate: 0.9052 - weighted_bincrossentropy: 0.0843 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8193 - val_dice_loss: 0.1807 - val_dice_p_bce: 0.1823 - val_loss: 0.2281 - val_true_positive_rate: 0.8257 - val_weighted_bincrossentropy: 0.1614
# Epoch 481/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - binary_accuracy: 0.9943 - dice_coef: 0.8898 - dice_loss: 0.1102 - dice_p_bce: 0.1111 - loss: 0.1473 - true_positive_rate: 0.9042 - weighted_bincrossentropy: 0.0852 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8207 - val_dice_loss: 0.1793 - val_dice_p_bce: 0.1809 - val_loss: 0.2270 - val_true_positive_rate: 0.8345 - val_weighted_bincrossentropy: 0.1549
# Epoch 482/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9946 - dice_coef: 0.8886 - dice_loss: 0.1114 - dice_p_bce: 0.1123 - loss: 0.1489 - true_positive_rate: 0.9038 - weighted_bincrossentropy: 0.0819 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8204 - val_dice_loss: 0.1796 - val_dice_p_bce: 0.1812 - val_loss: 0.2271 - val_true_positive_rate: 0.8357 - val_weighted_bincrossentropy: 0.1538
# Epoch 483/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8867 - dice_loss: 0.1133 - dice_p_bce: 0.1141 - loss: 0.1502 - true_positive_rate: 0.9034 - weighted_bincrossentropy: 0.0875 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8211 - val_dice_loss: 0.1789 - val_dice_p_bce: 0.1804 - val_loss: 0.2264 - val_true_positive_rate: 0.8411 - val_weighted_bincrossentropy: 0.1498
# Epoch 484/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9945 - dice_coef: 0.8871 - dice_loss: 0.1129 - dice_p_bce: 0.1137 - loss: 0.1503 - true_positive_rate: 0.9057 - weighted_bincrossentropy: 0.0820 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8210 - val_dice_loss: 0.1790 - val_dice_p_bce: 0.1805 - val_loss: 0.2266 - val_true_positive_rate: 0.8368 - val_weighted_bincrossentropy: 0.1549
# Epoch 485/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9944 - dice_coef: 0.8885 - dice_loss: 0.1115 - dice_p_bce: 0.1124 - loss: 0.1484 - true_positive_rate: 0.9057 - weighted_bincrossentropy: 0.0858 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8196 - val_dice_loss: 0.1804 - val_dice_p_bce: 0.1821 - val_loss: 0.2278 - val_true_positive_rate: 0.8274 - val_weighted_bincrossentropy: 0.1613
# Epoch 486/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8873 - dice_loss: 0.1127 - dice_p_bce: 0.1136 - loss: 0.1497 - true_positive_rate: 0.9048 - weighted_bincrossentropy: 0.0865 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.8209 - val_dice_loss: 0.1791 - val_dice_p_bce: 0.1806 - val_loss: 0.2270 - val_true_positive_rate: 0.8408 - val_weighted_bincrossentropy: 0.1518
# Epoch 487/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9944 - dice_coef: 0.8909 - dice_loss: 0.1091 - dice_p_bce: 0.1100 - loss: 0.1457 - true_positive_rate: 0.9064 - weighted_bincrossentropy: 0.0868 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.8208 - val_dice_loss: 0.1792 - val_dice_p_bce: 0.1807 - val_loss: 0.2268 - val_true_positive_rate: 0.8443 - val_weighted_bincrossentropy: 0.1501
# Epoch 488/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8902 - dice_loss: 0.1098 - dice_p_bce: 0.1107 - loss: 0.1462 - true_positive_rate: 0.9089 - weighted_bincrossentropy: 0.0877 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8202 - val_dice_loss: 0.1798 - val_dice_p_bce: 0.1813 - val_loss: 0.2272 - val_true_positive_rate: 0.8349 - val_weighted_bincrossentropy: 0.1567
# Epoch 489/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9948 - dice_coef: 0.8895 - dice_loss: 0.1105 - dice_p_bce: 0.1113 - loss: 0.1477 - true_positive_rate: 0.9059 - weighted_bincrossentropy: 0.0810 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.8208 - val_dice_loss: 0.1792 - val_dice_p_bce: 0.1807 - val_loss: 0.2270 - val_true_positive_rate: 0.8430 - val_weighted_bincrossentropy: 0.1511
# Epoch 490/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8881 - dice_loss: 0.1119 - dice_p_bce: 0.1128 - loss: 0.1486 - true_positive_rate: 0.9076 - weighted_bincrossentropy: 0.0867 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8201 - val_dice_loss: 0.1799 - val_dice_p_bce: 0.1816 - val_loss: 0.2275 - val_true_positive_rate: 0.8226 - val_weighted_bincrossentropy: 0.1656
# Epoch 491/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8869 - dice_loss: 0.1131 - dice_p_bce: 0.1140 - loss: 0.1503 - true_positive_rate: 0.9025 - weighted_bincrossentropy: 0.0876 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8210 - val_dice_loss: 0.1790 - val_dice_p_bce: 0.1806 - val_loss: 0.2266 - val_true_positive_rate: 0.8318 - val_weighted_bincrossentropy: 0.1595
# Epoch 492/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9944 - dice_coef: 0.8891 - dice_loss: 0.1109 - dice_p_bce: 0.1117 - loss: 0.1476 - true_positive_rate: 0.9051 - weighted_bincrossentropy: 0.0876 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8200 - val_dice_loss: 0.1800 - val_dice_p_bce: 0.1816 - val_loss: 0.2276 - val_true_positive_rate: 0.8295 - val_weighted_bincrossentropy: 0.1620
# Epoch 493/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8886 - dice_loss: 0.1114 - dice_p_bce: 0.1123 - loss: 0.1478 - true_positive_rate: 0.9048 - weighted_bincrossentropy: 0.0908 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8204 - val_dice_loss: 0.1796 - val_dice_p_bce: 0.1812 - val_loss: 0.2270 - val_true_positive_rate: 0.8386 - val_weighted_bincrossentropy: 0.1543
# Epoch 494/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9942 - dice_coef: 0.8887 - dice_loss: 0.1113 - dice_p_bce: 0.1122 - loss: 0.1478 - true_positive_rate: 0.9043 - weighted_bincrossentropy: 0.0910 - val_binary_accuracy: 0.9900 - val_dice_coef: 0.8203 - val_dice_loss: 0.1797 - val_dice_p_bce: 0.1812 - val_loss: 0.2278 - val_true_positive_rate: 0.8529 - val_weighted_bincrossentropy: 0.1438
# Epoch 495/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9943 - dice_coef: 0.8870 - dice_loss: 0.1130 - dice_p_bce: 0.1138 - loss: 0.1506 - true_positive_rate: 0.9077 - weighted_bincrossentropy: 0.0837 - val_binary_accuracy: 0.9902 - val_dice_coef: 0.8204 - val_dice_loss: 0.1796 - val_dice_p_bce: 0.1812 - val_loss: 0.2274 - val_true_positive_rate: 0.8316 - val_weighted_bincrossentropy: 0.1613
# Epoch 496/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9945 - dice_coef: 0.8923 - dice_loss: 0.1077 - dice_p_bce: 0.1086 - loss: 0.1442 - true_positive_rate: 0.9084 - weighted_bincrossentropy: 0.0842 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8213 - val_dice_loss: 0.1787 - val_dice_p_bce: 0.1803 - val_loss: 0.2262 - val_true_positive_rate: 0.8335 - val_weighted_bincrossentropy: 0.1589
# Epoch 497/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9944 - dice_coef: 0.8903 - dice_loss: 0.1097 - dice_p_bce: 0.1106 - loss: 0.1463 - true_positive_rate: 0.9045 - weighted_bincrossentropy: 0.0873 - val_binary_accuracy: 0.9901 - val_dice_coef: 0.8215 - val_dice_loss: 0.1785 - val_dice_p_bce: 0.1800 - val_loss: 0.2265 - val_true_positive_rate: 0.8497 - val_weighted_bincrossentropy: 0.1470
# Epoch 498/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - binary_accuracy: 0.9940 - dice_coef: 0.8887 - dice_loss: 0.1113 - dice_p_bce: 0.1122 - loss: 0.1477 - true_positive_rate: 0.9063 - weighted_bincrossentropy: 0.0913 - val_binary_accuracy: 0.9898 - val_dice_coef: 0.8186 - val_dice_loss: 0.1814 - val_dice_p_bce: 0.1828 - val_loss: 0.2295 - val_true_positive_rate: 0.8572 - val_weighted_bincrossentropy: 0.1439
# Epoch 499/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9940 - dice_coef: 0.8848 - dice_loss: 0.1152 - dice_p_bce: 0.1160 - loss: 0.1533 - true_positive_rate: 0.9059 - weighted_bincrossentropy: 0.0854 - val_binary_accuracy: 0.9903 - val_dice_coef: 0.8198 - val_dice_loss: 0.1802 - val_dice_p_bce: 0.1819 - val_loss: 0.2278 - val_true_positive_rate: 0.8224 - val_weighted_bincrossentropy: 0.1664
# Epoch 500/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - binary_accuracy: 0.9946 - dice_coef: 0.8877 - dice_loss: 0.1123 - dice_p_bce: 0.1131 - loss: 0.1500 - true_positive_rate: 0.8995 - weighted_bincrossentropy: 0.0835 - val_binary_accuracy: 0.9897 - val_dice_coef: 0.8182 - val_dice_loss: 0.1818 - val_dice_p_bce: 0.1832 - val_loss: 0.2302 - val_true_positive_rate: 0.8603 - val_weighted_bincrossentropy: 0.1403

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('model dice coefficent')
plt.ylabel('dice coef')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# print("Max acc:", round(max(history.history['acc']),4))
# print("Max val_acc:", round(max(history.history['val_acc']),4))
# print("\nMin loss:", round(min(history.history['loss']),4))
# print("Min val_loss:", round(min(history.history['val_loss']),4))

# %% [markdown]
# ## Testing the model

# %%
## Save the Weights

#model.save_weights("UNetW.h5")

# %%
## Dataset for prediction
x, y = valid_gen.__getitem__(0)
result = model.predict(x)

result = result > 0.5
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)

r = random.randint(0, len(x)-1)


ax = fig.add_subplot(1, 2, 1)
ax.imshow(np.reshape(y[r]*255, (dim, dim)), cmap="gray")

ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(result[r]*255, (dim, dim)), cmap="gray")

# %%
fig, axes = plt.subplots(ncols = 3, )

fig.set_figwidth(3.6)
fig.set_figheight(2)


axes[0].imshow(x[0])
axes[0].set_xlabel('Raw Image')
axes[1].imshow(np.reshape(y[0]*255, (dim, dim)), cmap="gray")
axes[1].set_xlabel('Ground Truth')
axes[2].imshow(np.reshape(result[0]*255, (dim, dim)), cmap="gray")
axes[2].set_xlabel('Prediction')

matplotlib.rcParams.update({'font.size': 12, "font.family": "Times New Roman"})

for i, ax in enumerate(axes):
    axes[i].tick_params(
        axis='both',          # changes apply to the voth axis
        which='both', 
        left = False,   # both major and minor ticks are affected
        right = False,
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False) # labels along the bottom edge are off
    
    axes[i].xaxis.set_ticklabels([])
    axes[i].yaxis.set_ticklabels([])

    for j in ax.spines:
        axes[i].spines[j].set_visible(False)
        
    plt.savefig(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_example.pdf', dpi =300)

# %% [markdown]
# ## Save Model

# %%
import json

# %%
# !mkdir saved_models
# model.save(r'C:\Users\thoma\Desktop\CT_Segment_Full_v2.h5')

model.save(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}.keras')


save_dict = {'History': history.history, 'Loss Function': use_loss.__name__, 'Learning Rate': learning_rate, 'Num Training Images': len(train_imgs), 'Num Test Images': len(test_imgs), 'Batch Size': batch_size}

with open(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_history.json', 'w') as f:
    json.dump(save_dict, f)

# %%
# with open(r'C:\Users\chloe\DE4\Masters\Models\Model_3_history.pkl', 'r') as f:
#     hist = json.load(f)

# print(len(hist['History']['binary_accuray']))
