# %% [markdown]
# # UNET SEGMENTATION

# %%
## Imports
import os
import sys
import random
from glob import glob as glob
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import matplotlib
import matplotlib.image as Image
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split

tf.config.run_functions_eagerly(True)

## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed


'tf-models-official >=2.5.1, <2.16.0',
'tensorflow_io',
#'keras',
# Out:
# ('tensorflow_io',)

# %% [markdown]
# ## Hyperparameters

# %%
dim = 224

# get image and mask files
image_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data\*_i*')
mask_files = glob(r'C:\Users\chloe\DE4\Masters\Dataset\Training_Data\*_s*')

# splits into test and training datasets
train_imgs, test_imgs, train_masks, test_masks = train_test_split(image_files, mask_files, test_size = 0.33, random_state= 123)

print(len(train_imgs))

epochs = 5
batch_size = 32

count = 0
ratios = None
# Out:
# 167

# %% [markdown]
# ## Data Generator

# %%
class DataGen(keras.utils.Sequence):
    def __init__(self, image_files, mask_files,  batch_size, hls = False):
        self.img_files = image_files
        self.mask_files = mask_files
        self.batch_size = batch_size
        self.num_files = len(image_files)

        self.hls = hls

        self.current_ratios = None

    def ratio_Imgs(self, masks):
        rs = []
        for i in masks:
            i = np.reshape(i, (dim, dim))

            r = sum(i > 0.5)/ dim **2

            rs.append(r)
        
        self.current_ratios = np.array(rs)
        global ratios
        ratios = self.current_ratios

    # def __load__(self, id_name):
    #     ## Path
    #     image_path = os.path.join(self.path, id_name, "images", id_name) + ".png"
    #     mask_path = os.path.join(self.path, id_name, "masks/")
    #     all_masks = os.listdir(mask_path)
        
    #     ## Reading Image
        
    #     image = cv2.imread(image_path, 1)
    #     #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #     image = cv2.resize(image, (self.image_size, self.image_size))
        
    #     mask = np.zeros((self.image_size, self.image_size, 1))
        
    #     ## Reading Masks
    #     for name in all_masks:
    #         _mask_path = mask_path + name
    #         _mask_image = cv2.imread(_mask_path, -1)
    #         _mask_image = cv2.resize(_mask_image, (self.image_size, self.image_size)) #128x128
    #         _mask_image = np.expand_dims(_mask_image, axis=-1)
    #         mask = np.maximum(mask, _mask_image)
                
    #     ## Normalizaing 
    #     image = image/255.0
    #     mask = mask/255.0
        
    #     return image, mask
    def __getitem__(self, index):
        'Returns batch of images and labels'

        this_batch = self.batch_size
        # Changes batch size for final batch (no data missed)
        if(index+1)*self.batch_size > self.num_files:
            this_batch = self.num_files - index*self.batch_size
        
        # sets limits for batch
        start = index*self.batch_size
        stop = start + this_batch

        # takes images and masks files within batch
        img_batch = self.img_files[start : stop]
        mask_batch = self.mask_files[start : stop]

        images = []
        masks  = []
        
        # loads images and files and adds them to list
        for i, (img_file, mask_file) in enumerate(zip(img_batch,mask_batch)):
            # Normalises
            img = cv2.imread(img_file) 
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            
            if self.hls:
                img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
            
            img = img / 255

            mask = cv2.imread(mask_file, 0) / 255
            mask = np.array(mask, dtype=np.float32)
            mask = np.reshape(mask, (mask.shape[0], mask.shape[1], 1))
            images.append(img)
            masks.append(mask)
            
        images = np.array(images)
        #image = np.reshape(image, (batch_size, 256, 256, 1))
        masks  = np.array(masks)
        
        self.ratio_Imgs(masks)

        return images, masks
    
    def on_epoch_end(self):
        global count
        count = 0
    
    def __len__(self):
        'Returns Number of batches'
        return int(np.ceil(self.num_files // self.batch_size))

# %%
# data loader obj is created with training images and masks
gen = DataGen(image_files=train_imgs, mask_files=train_masks, batch_size=batch_size)
x, y = gen.__getitem__(0)
print(x.shape, y.shape)
# Out:
# (32, 224, 224, 3) (32, 224, 224, 1)

# %%
r = random.randint(0, len(x)-1)

fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(1, 2, 1)
ax.imshow(x[r])
ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(y[r], (dim, dim)), cmap="gray")

# %% [markdown]
# ## Different Convolutional Blocks

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %% [markdown]
# ## UNet Model

# %%
def UNet(image_size):
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    bn = bottleneck(p4, f[4])
    
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(1, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %% [markdown]
# ## Loss Function

# %%
from keras import saving

# @keras.saving.register_keras_serializable()
def weighted_bincrossentropy(true, pred):
    """
    Calculates weighted binary cross entropy. The weights are fixed.
        
    This can be useful for unbalanced catagories.
    
    Adjust the weights here depending on what is required.
    
    For example if there are 10x as many positive classes as negative classes,
        if you adjust weight_zero = 1.0, weight_one = 0.1, then false positives 
        will be penalize 10 times as much as false negatives.
    """
    # y = keras.backend.flatten(true)
    # r = np.max(((keras.backend.sum(y).numpy()/dim**2)**3, 1e-8))
    # calculate the binary cross entropy
    bin_crossentropy = keras.backend.binary_crossentropy(true, pred)
    
    # apply the weights
    weights = true * np.log(13) + (1. - true) * 0.5
    weighted_bin_crossentropy = weights * bin_crossentropy 

    return keras.backend.mean(weighted_bin_crossentropy)

# @keras.saving.register_keras_serializable()
def mean_iou_loss(y_true, y_pred):

    pred_sum = keras.backend.sum(y_pred)
    gt_sum = keras.backend.sum(y_true)
    intersection = keras.backend.sum(tf.math.multiply(y_true,y_pred))
    
    union = pred_sum + gt_sum - intersection

    iou = intersection/union
    return 1 - iou

# @keras.saving.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1):
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)
    intersection = keras.backend.sum(y_true * y_pred, axis=[1,2,3])
    union = keras.backend.sum(y_true, axis=[1,2,3]) + keras.backend.sum(y_pred, axis=[1,2,3])
    return keras.backend.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

# @keras.saving.register_keras_serializable()
def dice_loss(in_gt, in_pred):
    return 1 - dice_coef(in_gt, in_pred)

# @keras.saving.register_keras_serializable()
def dice_p_bce(in_gt, in_pred):
    """combine DICE and BCE"""
    # 0.01*keras.losses.binary_crossentropy(in_gt, in_pred)
    return 0.01*weighted_bincrossentropy(in_gt, in_pred) + (1- dice_coef(in_gt, in_pred))

# @keras.saving.register_keras_serializable()
def true_positive_rate(y_true, y_pred):
    return keras.backend.sum(keras.backend.flatten(y_true)*keras.backend.flatten(keras.backend.round(y_pred)))/keras.backend.sum(y_true)

# @keras.saving.register_keras_serializable()
def dice_mean_iou(in_gt, in_pred):
    return (dice_loss(in_gt, in_pred) + mean_iou_loss(in_gt, in_pred)) / 2

# %%
model = UNet(dim)
# learning_rate = learning_rate=0.0001
learning_rate = 0.0001
opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)
# opt = tf.keras.optimizers.SGD(learning_rate = 0.00001)
# model.compile(optimizer = opt, loss=weighted_bincrossentropy, metrics=["acc"])
cce = keras.losses.CategoricalFocalCrossentropy()

use_loss = dice_mean_iou
print(use_loss.__name__)
model.compile(optimizer = opt, loss=use_loss, metrics=[dice_coef, 'binary_accuracy', dice_p_bce, dice_loss, true_positive_rate, weighted_bincrossentropy])
model.summary()
# Out:
# dice_mean_iou
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 224, 224,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 224, 224,  │      2,320 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 112, 112,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 112, 112,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 112, 112,  │      9,248 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 56, 56,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,928 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 28, 28,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │    147,584 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 14, 14,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 14, 14,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 14, 14,    │    590,080 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 28, 28,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 28, 28,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │    147,584 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 56, 56,    │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 56, 56,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 56, 56,    │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 56, 56,    │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 112, 112,  │          0 │ conv2d_13[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 112, 112,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 112, 112,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 112, 112,  │      9,248 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 224, 224,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 224, 224,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 48)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 224, 224,  │      6,928 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 224, 224,  │      2,320 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 224, 224,  │         17 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,962,625 (7.49 MB)
#  Trainable params: 1,962,625 (7.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the model

# %%
train_gen = DataGen(train_imgs, train_masks, batch_size= batch_size, hls = False)
valid_gen = DataGen(test_imgs, test_masks, batch_size=batch_size, hls = False)

from sklearn.utils import class_weight
x, y = train_gen.__getitem__(5)

w1s = []
w2s = []
for i in y:
    i = np.reshape(i, (dim,dim))
    if np.sum(i) != 0:
        w1s.append(dim**2/(2 * np.sum(i)) )
        w2s.append(dim**2/(2 * (dim**2 - sum(i))))

print(np.mean(w1s), np.mean(w2s))


rs = []
for i in range(len(train_gen)):
    _, masks = train_gen.__getitem__(i)

    for j in masks:
        j = np.reshape(j, (dim,dim))
        r = sum(j > 0.5) / dim**2
        rs.append(r)

r = np.mean(rs)
print(r)
# Out:
# 26.792731480340642 0.50007826
# 0.00015991978325579674

# %%
model_num = 8

# %%
history = model.fit(train_gen, batch_size=batch_size, epochs = 500, validation_data= valid_gen)
# Out:
# Epoch 1/500
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# C:\Users\chloe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - binary_accuracy: 0.4437 - dice_coef: 0.0662 - dice_loss: 0.9338 - dice_p_bce: 0.9378 - loss: 0.9492 - true_positive_rate: 0.4025 - weighted_bincrossentropy: 0.3996 - val_binary_accuracy: 0.9166 - val_dice_coef: 0.0849 - val_dice_loss: 0.9151 - val_dice_p_bce: 0.9192 - val_loss: 0.9344 - val_true_positive_rate: 0.1199 - val_weighted_bincrossentropy: 0.4136
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9341 - dice_coef: 0.0649 - dice_loss: 0.9351 - dice_p_bce: 0.9391 - loss: 0.9503 - true_positive_rate: 0.0996 - weighted_bincrossentropy: 0.3942 - val_binary_accuracy: 0.9308 - val_dice_coef: 0.0854 - val_dice_loss: 0.9146 - val_dice_p_bce: 0.9187 - val_loss: 0.9340 - val_true_positive_rate: 0.0768 - val_weighted_bincrossentropy: 0.4096
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9439 - dice_coef: 0.0672 - dice_loss: 0.9328 - dice_p_bce: 0.9367 - loss: 0.9484 - true_positive_rate: 0.0485 - weighted_bincrossentropy: 0.3910 - val_binary_accuracy: 0.9383 - val_dice_coef: 0.0859 - val_dice_loss: 0.9141 - val_dice_p_bce: 0.9182 - val_loss: 0.9336 - val_true_positive_rate: 0.0251 - val_weighted_bincrossentropy: 0.4039
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9517 - dice_coef: 0.0649 - dice_loss: 0.9351 - dice_p_bce: 0.9389 - loss: 0.9503 - true_positive_rate: 0.0220 - weighted_bincrossentropy: 0.3832 - val_binary_accuracy: 0.9399 - val_dice_coef: 0.0864 - val_dice_loss: 0.9136 - val_dice_p_bce: 0.9176 - val_loss: 0.9332 - val_true_positive_rate: 0.0428 - val_weighted_bincrossentropy: 0.4006
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9529 - dice_coef: 0.0654 - dice_loss: 0.9346 - dice_p_bce: 0.9384 - loss: 0.9499 - true_positive_rate: 0.0317 - weighted_bincrossentropy: 0.3791 - val_binary_accuracy: 0.9439 - val_dice_coef: 0.0872 - val_dice_loss: 0.9128 - val_dice_p_bce: 0.9168 - val_loss: 0.9326 - val_true_positive_rate: 0.0530 - val_weighted_bincrossentropy: 0.3946
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - binary_accuracy: 0.9579 - dice_coef: 0.0644 - dice_loss: 0.9356 - dice_p_bce: 0.9393 - loss: 0.9507 - true_positive_rate: 0.0386 - weighted_bincrossentropy: 0.3712 - val_binary_accuracy: 0.9471 - val_dice_coef: 0.0884 - val_dice_loss: 0.9116 - val_dice_p_bce: 0.9154 - val_loss: 0.9316 - val_true_positive_rate: 0.0704 - val_weighted_bincrossentropy: 0.3860
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9603 - dice_coef: 0.0666 - dice_loss: 0.9334 - dice_p_bce: 0.9370 - loss: 0.9489 - true_positive_rate: 0.0526 - weighted_bincrossentropy: 0.3616 - val_binary_accuracy: 0.9480 - val_dice_coef: 0.0908 - val_dice_loss: 0.9092 - val_dice_p_bce: 0.9129 - val_loss: 0.9297 - val_true_positive_rate: 0.0765 - val_weighted_bincrossentropy: 0.3712
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9605 - dice_coef: 0.0696 - dice_loss: 0.9304 - dice_p_bce: 0.9338 - loss: 0.9465 - true_positive_rate: 0.0609 - weighted_bincrossentropy: 0.3441 - val_binary_accuracy: 0.9483 - val_dice_coef: 0.0969 - val_dice_loss: 0.9031 - val_dice_p_bce: 0.9065 - val_loss: 0.9248 - val_true_positive_rate: 0.0934 - val_weighted_bincrossentropy: 0.3409
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9607 - dice_coef: 0.0743 - dice_loss: 0.9257 - dice_p_bce: 0.9287 - loss: 0.9428 - true_positive_rate: 0.0793 - weighted_bincrossentropy: 0.3020 - val_binary_accuracy: 0.9308 - val_dice_coef: 0.1146 - val_dice_loss: 0.8854 - val_dice_p_bce: 0.8883 - val_loss: 0.9106 - val_true_positive_rate: 0.2201 - val_weighted_bincrossentropy: 0.2847
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9331 - dice_coef: 0.0960 - dice_loss: 0.9040 - dice_p_bce: 0.9064 - loss: 0.9254 - true_positive_rate: 0.2304 - weighted_bincrossentropy: 0.2393 - val_binary_accuracy: 0.9036 - val_dice_coef: 0.1428 - val_dice_loss: 0.8572 - val_dice_p_bce: 0.8601 - val_loss: 0.8860 - val_true_positive_rate: 0.2499 - val_weighted_bincrossentropy: 0.2909
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.8613 - dice_coef: 0.1198 - dice_loss: 0.8802 - dice_p_bce: 0.8825 - loss: 0.9054 - true_positive_rate: 0.4017 - weighted_bincrossentropy: 0.2338 - val_binary_accuracy: 0.8089 - val_dice_coef: 0.1740 - val_dice_loss: 0.8260 - val_dice_p_bce: 0.8289 - val_loss: 0.8619 - val_true_positive_rate: 0.5826 - val_weighted_bincrossentropy: 0.2942
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.7922 - dice_coef: 0.1433 - dice_loss: 0.8567 - dice_p_bce: 0.8593 - loss: 0.8866 - true_positive_rate: 0.6351 - weighted_bincrossentropy: 0.2612 - val_binary_accuracy: 0.8798 - val_dice_coef: 0.1695 - val_dice_loss: 0.8305 - val_dice_p_bce: 0.8357 - val_loss: 0.8615 - val_true_positive_rate: 0.4005 - val_weighted_bincrossentropy: 0.5200
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.8381 - dice_coef: 0.1499 - dice_loss: 0.8501 - dice_p_bce: 0.8536 - loss: 0.8804 - true_positive_rate: 0.5363 - weighted_bincrossentropy: 0.3540 - val_binary_accuracy: 0.8749 - val_dice_coef: 0.1871 - val_dice_loss: 0.8129 - val_dice_p_bce: 0.8187 - val_loss: 0.8456 - val_true_positive_rate: 0.4524 - val_weighted_bincrossentropy: 0.5795
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.8750 - dice_coef: 0.1551 - dice_loss: 0.8449 - dice_p_bce: 0.8496 - loss: 0.8744 - true_positive_rate: 0.4480 - weighted_bincrossentropy: 0.4685 - val_binary_accuracy: 0.7547 - val_dice_coef: 0.2060 - val_dice_loss: 0.7940 - val_dice_p_bce: 0.7978 - val_loss: 0.8356 - val_true_positive_rate: 0.7687 - val_weighted_bincrossentropy: 0.3779
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.8360 - dice_coef: 0.1699 - dice_loss: 0.8301 - dice_p_bce: 0.8349 - loss: 0.8612 - true_positive_rate: 0.5716 - weighted_bincrossentropy: 0.4830 - val_binary_accuracy: 0.7564 - val_dice_coef: 0.2154 - val_dice_loss: 0.7846 - val_dice_p_bce: 0.7892 - val_loss: 0.8278 - val_true_positive_rate: 0.7690 - val_weighted_bincrossentropy: 0.4591
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.7860 - dice_coef: 0.1759 - dice_loss: 0.8241 - dice_p_bce: 0.8288 - loss: 0.8612 - true_positive_rate: 0.7081 - weighted_bincrossentropy: 0.4724 - val_binary_accuracy: 0.9200 - val_dice_coef: 0.2025 - val_dice_loss: 0.7975 - val_dice_p_bce: 0.8067 - val_loss: 0.8207 - val_true_positive_rate: 0.3314 - val_weighted_bincrossentropy: 0.9259
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.8997 - dice_coef: 0.1725 - dice_loss: 0.8275 - dice_p_bce: 0.8345 - loss: 0.8540 - true_positive_rate: 0.4025 - weighted_bincrossentropy: 0.7013 - val_binary_accuracy: 0.9057 - val_dice_coef: 0.2333 - val_dice_loss: 0.7667 - val_dice_p_bce: 0.7753 - val_loss: 0.7945 - val_true_positive_rate: 0.4368 - val_weighted_bincrossentropy: 0.8613
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.8956 - dice_coef: 0.1986 - dice_loss: 0.8014 - dice_p_bce: 0.8083 - loss: 0.8327 - true_positive_rate: 0.4652 - weighted_bincrossentropy: 0.6909 - val_binary_accuracy: 0.8978 - val_dice_coef: 0.2479 - val_dice_loss: 0.7521 - val_dice_p_bce: 0.7604 - val_loss: 0.7825 - val_true_positive_rate: 0.4963 - val_weighted_bincrossentropy: 0.8332
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9028 - dice_coef: 0.1984 - dice_loss: 0.8016 - dice_p_bce: 0.8092 - loss: 0.8315 - true_positive_rate: 0.4438 - weighted_bincrossentropy: 0.7587 - val_binary_accuracy: 0.8697 - val_dice_coef: 0.2550 - val_dice_loss: 0.7450 - val_dice_p_bce: 0.7527 - val_loss: 0.7815 - val_true_positive_rate: 0.6032 - val_weighted_bincrossentropy: 0.7654
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9017 - dice_coef: 0.2112 - dice_loss: 0.7888 - dice_p_bce: 0.7959 - loss: 0.8184 - true_positive_rate: 0.4748 - weighted_bincrossentropy: 0.7161 - val_binary_accuracy: 0.9152 - val_dice_coef: 0.2556 - val_dice_loss: 0.7444 - val_dice_p_bce: 0.7526 - val_loss: 0.7681 - val_true_positive_rate: 0.4724 - val_weighted_bincrossentropy: 0.8166
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9144 - dice_coef: 0.2265 - dice_loss: 0.7735 - dice_p_bce: 0.7800 - loss: 0.8060 - true_positive_rate: 0.4749 - weighted_bincrossentropy: 0.6562 - val_binary_accuracy: 0.8931 - val_dice_coef: 0.2716 - val_dice_loss: 0.7284 - val_dice_p_bce: 0.7352 - val_loss: 0.7604 - val_true_positive_rate: 0.5947 - val_weighted_bincrossentropy: 0.6844
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9089 - dice_coef: 0.2459 - dice_loss: 0.7541 - dice_p_bce: 0.7602 - loss: 0.7885 - true_positive_rate: 0.5322 - weighted_bincrossentropy: 0.6085 - val_binary_accuracy: 0.9253 - val_dice_coef: 0.2755 - val_dice_loss: 0.7245 - val_dice_p_bce: 0.7313 - val_loss: 0.7431 - val_true_positive_rate: 0.5070 - val_weighted_bincrossentropy: 0.6793
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9084 - dice_coef: 0.2002 - dice_loss: 0.7998 - dice_p_bce: 0.8061 - loss: 0.8198 - true_positive_rate: 0.4909 - weighted_bincrossentropy: 0.6359 - val_binary_accuracy: 0.8723 - val_dice_coef: 0.2792 - val_dice_loss: 0.7208 - val_dice_p_bce: 0.7261 - val_loss: 0.7584 - val_true_positive_rate: 0.7021 - val_weighted_bincrossentropy: 0.5357
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.8881 - dice_coef: 0.2448 - dice_loss: 0.7552 - dice_p_bce: 0.7604 - loss: 0.7910 - true_positive_rate: 0.6187 - weighted_bincrossentropy: 0.5198 - val_binary_accuracy: 0.8833 - val_dice_coef: 0.2871 - val_dice_loss: 0.7129 - val_dice_p_bce: 0.7176 - val_loss: 0.7480 - val_true_positive_rate: 0.6964 - val_weighted_bincrossentropy: 0.4692
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9142 - dice_coef: 0.2561 - dice_loss: 0.7439 - dice_p_bce: 0.7486 - loss: 0.7786 - true_positive_rate: 0.5709 - weighted_bincrossentropy: 0.4678 - val_binary_accuracy: 0.8555 - val_dice_coef: 0.2763 - val_dice_loss: 0.7237 - val_dice_p_bce: 0.7279 - val_loss: 0.7628 - val_true_positive_rate: 0.7793 - val_weighted_bincrossentropy: 0.4130
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - binary_accuracy: 0.8846 - dice_coef: 0.2559 - dice_loss: 0.7441 - dice_p_bce: 0.7482 - loss: 0.7799 - true_positive_rate: 0.6666 - weighted_bincrossentropy: 0.4130 - val_binary_accuracy: 0.9144 - val_dice_coef: 0.3125 - val_dice_loss: 0.6875 - val_dice_p_bce: 0.6913 - val_loss: 0.7135 - val_true_positive_rate: 0.6705 - val_weighted_bincrossentropy: 0.3734
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9300 - dice_coef: 0.2915 - dice_loss: 0.7085 - dice_p_bce: 0.7122 - loss: 0.7418 - true_positive_rate: 0.5913 - weighted_bincrossentropy: 0.3610 - val_binary_accuracy: 0.8991 - val_dice_coef: 0.3163 - val_dice_loss: 0.6837 - val_dice_p_bce: 0.6868 - val_loss: 0.7170 - val_true_positive_rate: 0.7602 - val_weighted_bincrossentropy: 0.3108
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9303 - dice_coef: 0.2909 - dice_loss: 0.7091 - dice_p_bce: 0.7127 - loss: 0.7421 - true_positive_rate: 0.5991 - weighted_bincrossentropy: 0.3534 - val_binary_accuracy: 0.9180 - val_dice_coef: 0.3410 - val_dice_loss: 0.6590 - val_dice_p_bce: 0.6620 - val_loss: 0.6893 - val_true_positive_rate: 0.7332 - val_weighted_bincrossentropy: 0.3024
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9445 - dice_coef: 0.3056 - dice_loss: 0.6944 - dice_p_bce: 0.6980 - loss: 0.7228 - true_positive_rate: 0.5630 - weighted_bincrossentropy: 0.3535 - val_binary_accuracy: 0.9320 - val_dice_coef: 0.3670 - val_dice_loss: 0.6330 - val_dice_p_bce: 0.6362 - val_loss: 0.6593 - val_true_positive_rate: 0.7055 - val_weighted_bincrossentropy: 0.3161
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9519 - dice_coef: 0.3373 - dice_loss: 0.6627 - dice_p_bce: 0.6665 - loss: 0.6914 - true_positive_rate: 0.5488 - weighted_bincrossentropy: 0.3831 - val_binary_accuracy: 0.9447 - val_dice_coef: 0.3874 - val_dice_loss: 0.6126 - val_dice_p_bce: 0.6161 - val_loss: 0.6338 - val_true_positive_rate: 0.6557 - val_weighted_bincrossentropy: 0.3538
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9545 - dice_coef: 0.3560 - dice_loss: 0.6440 - dice_p_bce: 0.6478 - loss: 0.6713 - true_positive_rate: 0.5609 - weighted_bincrossentropy: 0.3760 - val_binary_accuracy: 0.9488 - val_dice_coef: 0.4003 - val_dice_loss: 0.5997 - val_dice_p_bce: 0.6034 - val_loss: 0.6201 - val_true_positive_rate: 0.6427 - val_weighted_bincrossentropy: 0.3680
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9588 - dice_coef: 0.3808 - dice_loss: 0.6192 - dice_p_bce: 0.6229 - loss: 0.6502 - true_positive_rate: 0.5653 - weighted_bincrossentropy: 0.3735 - val_binary_accuracy: 0.9497 - val_dice_coef: 0.4120 - val_dice_loss: 0.5880 - val_dice_p_bce: 0.5915 - val_loss: 0.6088 - val_true_positive_rate: 0.6551 - val_weighted_bincrossentropy: 0.3526
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9607 - dice_coef: 0.4050 - dice_loss: 0.5950 - dice_p_bce: 0.5983 - loss: 0.6325 - true_positive_rate: 0.5873 - weighted_bincrossentropy: 0.3297 - val_binary_accuracy: 0.9569 - val_dice_coef: 0.4054 - val_dice_loss: 0.5946 - val_dice_p_bce: 0.5989 - val_loss: 0.6091 - val_true_positive_rate: 0.5739 - val_weighted_bincrossentropy: 0.4264
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9610 - dice_coef: 0.4173 - dice_loss: 0.5827 - dice_p_bce: 0.5861 - loss: 0.6172 - true_positive_rate: 0.5906 - weighted_bincrossentropy: 0.3463 - val_binary_accuracy: 0.9551 - val_dice_coef: 0.4383 - val_dice_loss: 0.5617 - val_dice_p_bce: 0.5652 - val_loss: 0.5842 - val_true_positive_rate: 0.6413 - val_weighted_bincrossentropy: 0.3530
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9631 - dice_coef: 0.4449 - dice_loss: 0.5551 - dice_p_bce: 0.5578 - loss: 0.5982 - true_positive_rate: 0.6287 - weighted_bincrossentropy: 0.2757 - val_binary_accuracy: 0.9520 - val_dice_coef: 0.4583 - val_dice_loss: 0.5417 - val_dice_p_bce: 0.5446 - val_loss: 0.5713 - val_true_positive_rate: 0.7126 - val_weighted_bincrossentropy: 0.2905
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - binary_accuracy: 0.9636 - dice_coef: 0.4550 - dice_loss: 0.5450 - dice_p_bce: 0.5477 - loss: 0.5858 - true_positive_rate: 0.6452 - weighted_bincrossentropy: 0.2683 - val_binary_accuracy: 0.9588 - val_dice_coef: 0.4695 - val_dice_loss: 0.5305 - val_dice_p_bce: 0.5337 - val_loss: 0.5572 - val_true_positive_rate: 0.6491 - val_weighted_bincrossentropy: 0.3244
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 3s/step - binary_accuracy: 0.9654 - dice_coef: 0.4910 - dice_loss: 0.5090 - dice_p_bce: 0.5114 - loss: 0.5583 - true_positive_rate: 0.6612 - weighted_bincrossentropy: 0.2449 - val_binary_accuracy: 0.9629 - val_dice_coef: 0.4759 - val_dice_loss: 0.5241 - val_dice_p_bce: 0.5274 - val_loss: 0.5480 - val_true_positive_rate: 0.6193 - val_weighted_bincrossentropy: 0.3260
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9685 - dice_coef: 0.4951 - dice_loss: 0.5049 - dice_p_bce: 0.5074 - loss: 0.5489 - true_positive_rate: 0.6382 - weighted_bincrossentropy: 0.2429 - val_binary_accuracy: 0.9499 - val_dice_coef: 0.4901 - val_dice_loss: 0.5099 - val_dice_p_bce: 0.5120 - val_loss: 0.5466 - val_true_positive_rate: 0.8085 - val_weighted_bincrossentropy: 0.2123
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9654 - dice_coef: 0.5135 - dice_loss: 0.4865 - dice_p_bce: 0.4885 - loss: 0.5389 - true_positive_rate: 0.7229 - weighted_bincrossentropy: 0.2004 - val_binary_accuracy: 0.9660 - val_dice_coef: 0.5030 - val_dice_loss: 0.4970 - val_dice_p_bce: 0.4998 - val_loss: 0.5216 - val_true_positive_rate: 0.6430 - val_weighted_bincrossentropy: 0.2766
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9695 - dice_coef: 0.5055 - dice_loss: 0.4945 - dice_p_bce: 0.4966 - loss: 0.5343 - true_positive_rate: 0.6701 - weighted_bincrossentropy: 0.2068 - val_binary_accuracy: 0.9657 - val_dice_coef: 0.5301 - val_dice_loss: 0.4699 - val_dice_p_bce: 0.4723 - val_loss: 0.4972 - val_true_positive_rate: 0.7058 - val_weighted_bincrossentropy: 0.2320
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9710 - dice_coef: 0.5396 - dice_loss: 0.4604 - dice_p_bce: 0.4623 - loss: 0.5057 - true_positive_rate: 0.6961 - weighted_bincrossentropy: 0.1897 - val_binary_accuracy: 0.9697 - val_dice_coef: 0.4966 - val_dice_loss: 0.5034 - val_dice_p_bce: 0.5065 - val_loss: 0.5269 - val_true_positive_rate: 0.5566 - val_weighted_bincrossentropy: 0.3127
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9701 - dice_coef: 0.5033 - dice_loss: 0.4967 - dice_p_bce: 0.4988 - loss: 0.5380 - true_positive_rate: 0.6574 - weighted_bincrossentropy: 0.2125 - val_binary_accuracy: 0.9520 - val_dice_coef: 0.5288 - val_dice_loss: 0.4712 - val_dice_p_bce: 0.4729 - val_loss: 0.5140 - val_true_positive_rate: 0.8611 - val_weighted_bincrossentropy: 0.1711
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9660 - dice_coef: 0.5439 - dice_loss: 0.4561 - dice_p_bce: 0.4578 - loss: 0.5054 - true_positive_rate: 0.7705 - weighted_bincrossentropy: 0.1703 - val_binary_accuracy: 0.9636 - val_dice_coef: 0.5615 - val_dice_loss: 0.4385 - val_dice_p_bce: 0.4402 - val_loss: 0.4743 - val_true_positive_rate: 0.8036 - val_weighted_bincrossentropy: 0.1710
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9739 - dice_coef: 0.5859 - dice_loss: 0.4141 - dice_p_bce: 0.4157 - loss: 0.4706 - true_positive_rate: 0.7371 - weighted_bincrossentropy: 0.1517 - val_binary_accuracy: 0.9713 - val_dice_coef: 0.5681 - val_dice_loss: 0.4319 - val_dice_p_bce: 0.4340 - val_loss: 0.4587 - val_true_positive_rate: 0.7034 - val_weighted_bincrossentropy: 0.2104
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9743 - dice_coef: 0.5822 - dice_loss: 0.4178 - dice_p_bce: 0.4194 - loss: 0.4686 - true_positive_rate: 0.7268 - weighted_bincrossentropy: 0.1585 - val_binary_accuracy: 0.9685 - val_dice_coef: 0.5963 - val_dice_loss: 0.4037 - val_dice_p_bce: 0.4053 - val_loss: 0.4402 - val_true_positive_rate: 0.7936 - val_weighted_bincrossentropy: 0.1663
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9754 - dice_coef: 0.6034 - dice_loss: 0.3966 - dice_p_bce: 0.3982 - loss: 0.4550 - true_positive_rate: 0.7281 - weighted_bincrossentropy: 0.1593 - val_binary_accuracy: 0.9707 - val_dice_coef: 0.5903 - val_dice_loss: 0.4097 - val_dice_p_bce: 0.4119 - val_loss: 0.4410 - val_true_positive_rate: 0.7306 - val_weighted_bincrossentropy: 0.2210
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9740 - dice_coef: 0.6031 - dice_loss: 0.3969 - dice_p_bce: 0.3985 - loss: 0.4492 - true_positive_rate: 0.7498 - weighted_bincrossentropy: 0.1614 - val_binary_accuracy: 0.9617 - val_dice_coef: 0.5973 - val_dice_loss: 0.4027 - val_dice_p_bce: 0.4040 - val_loss: 0.4512 - val_true_positive_rate: 0.8664 - val_weighted_bincrossentropy: 0.1371
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9742 - dice_coef: 0.6149 - dice_loss: 0.3851 - dice_p_bce: 0.3865 - loss: 0.4436 - true_positive_rate: 0.7793 - weighted_bincrossentropy: 0.1395 - val_binary_accuracy: 0.9739 - val_dice_coef: 0.5883 - val_dice_loss: 0.4117 - val_dice_p_bce: 0.4141 - val_loss: 0.4397 - val_true_positive_rate: 0.6689 - val_weighted_bincrossentropy: 0.2423
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9776 - dice_coef: 0.6200 - dice_loss: 0.3800 - dice_p_bce: 0.3816 - loss: 0.4310 - true_positive_rate: 0.7187 - weighted_bincrossentropy: 0.1634 - val_binary_accuracy: 0.9706 - val_dice_coef: 0.6260 - val_dice_loss: 0.3740 - val_dice_p_bce: 0.3757 - val_loss: 0.4132 - val_true_positive_rate: 0.7957 - val_weighted_bincrossentropy: 0.1678
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9766 - dice_coef: 0.6421 - dice_loss: 0.3579 - dice_p_bce: 0.3592 - loss: 0.4123 - true_positive_rate: 0.7841 - weighted_bincrossentropy: 0.1328 - val_binary_accuracy: 0.9673 - val_dice_coef: 0.6298 - val_dice_loss: 0.3702 - val_dice_p_bce: 0.3717 - val_loss: 0.4160 - val_true_positive_rate: 0.8475 - val_weighted_bincrossentropy: 0.1498
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9762 - dice_coef: 0.6452 - dice_loss: 0.3548 - dice_p_bce: 0.3562 - loss: 0.4107 - true_positive_rate: 0.7782 - weighted_bincrossentropy: 0.1432 - val_binary_accuracy: 0.9676 - val_dice_coef: 0.6412 - val_dice_loss: 0.3588 - val_dice_p_bce: 0.3602 - val_loss: 0.4084 - val_true_positive_rate: 0.8486 - val_weighted_bincrossentropy: 0.1425
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9778 - dice_coef: 0.6568 - dice_loss: 0.3432 - dice_p_bce: 0.3446 - loss: 0.4035 - true_positive_rate: 0.7878 - weighted_bincrossentropy: 0.1382 - val_binary_accuracy: 0.9729 - val_dice_coef: 0.6427 - val_dice_loss: 0.3573 - val_dice_p_bce: 0.3592 - val_loss: 0.3964 - val_true_positive_rate: 0.7696 - val_weighted_bincrossentropy: 0.1873
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9777 - dice_coef: 0.6569 - dice_loss: 0.3431 - dice_p_bce: 0.3445 - loss: 0.3953 - true_positive_rate: 0.7828 - weighted_bincrossentropy: 0.1438 - val_binary_accuracy: 0.9716 - val_dice_coef: 0.6531 - val_dice_loss: 0.3469 - val_dice_p_bce: 0.3485 - val_loss: 0.3924 - val_true_positive_rate: 0.7959 - val_weighted_bincrossentropy: 0.1661
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9792 - dice_coef: 0.6721 - dice_loss: 0.3279 - dice_p_bce: 0.3294 - loss: 0.3845 - true_positive_rate: 0.7708 - weighted_bincrossentropy: 0.1457 - val_binary_accuracy: 0.9712 - val_dice_coef: 0.6562 - val_dice_loss: 0.3438 - val_dice_p_bce: 0.3454 - val_loss: 0.3887 - val_true_positive_rate: 0.8250 - val_weighted_bincrossentropy: 0.1629
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9792 - dice_coef: 0.6727 - dice_loss: 0.3273 - dice_p_bce: 0.3287 - loss: 0.3855 - true_positive_rate: 0.7860 - weighted_bincrossentropy: 0.1407 - val_binary_accuracy: 0.9696 - val_dice_coef: 0.6636 - val_dice_loss: 0.3364 - val_dice_p_bce: 0.3378 - val_loss: 0.3877 - val_true_positive_rate: 0.8427 - val_weighted_bincrossentropy: 0.1435
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9798 - dice_coef: 0.6859 - dice_loss: 0.3141 - dice_p_bce: 0.3154 - loss: 0.3729 - true_positive_rate: 0.7913 - weighted_bincrossentropy: 0.1319 - val_binary_accuracy: 0.9682 - val_dice_coef: 0.6547 - val_dice_loss: 0.3453 - val_dice_p_bce: 0.3468 - val_loss: 0.3951 - val_true_positive_rate: 0.8658 - val_weighted_bincrossentropy: 0.1449
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9785 - dice_coef: 0.6664 - dice_loss: 0.3336 - dice_p_bce: 0.3350 - loss: 0.3914 - true_positive_rate: 0.7937 - weighted_bincrossentropy: 0.1456 - val_binary_accuracy: 0.9712 - val_dice_coef: 0.6670 - val_dice_loss: 0.3330 - val_dice_p_bce: 0.3345 - val_loss: 0.3794 - val_true_positive_rate: 0.8433 - val_weighted_bincrossentropy: 0.1518
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9788 - dice_coef: 0.6863 - dice_loss: 0.3137 - dice_p_bce: 0.3151 - loss: 0.3680 - true_positive_rate: 0.8108 - weighted_bincrossentropy: 0.1343 - val_binary_accuracy: 0.9765 - val_dice_coef: 0.6662 - val_dice_loss: 0.3338 - val_dice_p_bce: 0.3357 - val_loss: 0.3699 - val_true_positive_rate: 0.7616 - val_weighted_bincrossentropy: 0.1886
# Epoch 59/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9803 - dice_coef: 0.6823 - dice_loss: 0.3177 - dice_p_bce: 0.3192 - loss: 0.3706 - true_positive_rate: 0.7660 - weighted_bincrossentropy: 0.1526 - val_binary_accuracy: 0.9698 - val_dice_coef: 0.6703 - val_dice_loss: 0.3297 - val_dice_p_bce: 0.3310 - val_loss: 0.3802 - val_true_positive_rate: 0.8724 - val_weighted_bincrossentropy: 0.1323
# Epoch 60/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9805 - dice_coef: 0.6950 - dice_loss: 0.3050 - dice_p_bce: 0.3063 - loss: 0.3643 - true_positive_rate: 0.8024 - weighted_bincrossentropy: 0.1293 - val_binary_accuracy: 0.9759 - val_dice_coef: 0.6848 - val_dice_loss: 0.3152 - val_dice_p_bce: 0.3167 - val_loss: 0.3561 - val_true_positive_rate: 0.8136 - val_weighted_bincrossentropy: 0.1567
# Epoch 61/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9801 - dice_coef: 0.6996 - dice_loss: 0.3004 - dice_p_bce: 0.3017 - loss: 0.3558 - true_positive_rate: 0.7994 - weighted_bincrossentropy: 0.1334 - val_binary_accuracy: 0.9765 - val_dice_coef: 0.6863 - val_dice_loss: 0.3137 - val_dice_p_bce: 0.3154 - val_loss: 0.3541 - val_true_positive_rate: 0.7956 - val_weighted_bincrossentropy: 0.1679
# Epoch 62/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9809 - dice_coef: 0.7062 - dice_loss: 0.2938 - dice_p_bce: 0.2951 - loss: 0.3495 - true_positive_rate: 0.8035 - weighted_bincrossentropy: 0.1291 - val_binary_accuracy: 0.9778 - val_dice_coef: 0.6768 - val_dice_loss: 0.3232 - val_dice_p_bce: 0.3250 - val_loss: 0.3563 - val_true_positive_rate: 0.7760 - val_weighted_bincrossentropy: 0.1787
# Epoch 63/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9819 - dice_coef: 0.7055 - dice_loss: 0.2945 - dice_p_bce: 0.2958 - loss: 0.3475 - true_positive_rate: 0.7879 - weighted_bincrossentropy: 0.1336 - val_binary_accuracy: 0.9726 - val_dice_coef: 0.6819 - val_dice_loss: 0.3181 - val_dice_p_bce: 0.3195 - val_loss: 0.3637 - val_true_positive_rate: 0.8704 - val_weighted_bincrossentropy: 0.1343
# Epoch 64/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9803 - dice_coef: 0.6978 - dice_loss: 0.3022 - dice_p_bce: 0.3035 - loss: 0.3594 - true_positive_rate: 0.8126 - weighted_bincrossentropy: 0.1270 - val_binary_accuracy: 0.9763 - val_dice_coef: 0.6738 - val_dice_loss: 0.3262 - val_dice_p_bce: 0.3279 - val_loss: 0.3621 - val_true_positive_rate: 0.7983 - val_weighted_bincrossentropy: 0.1662
# Epoch 65/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9812 - dice_coef: 0.7002 - dice_loss: 0.2998 - dice_p_bce: 0.3011 - loss: 0.3539 - true_positive_rate: 0.8079 - weighted_bincrossentropy: 0.1322 - val_binary_accuracy: 0.9725 - val_dice_coef: 0.6681 - val_dice_loss: 0.3319 - val_dice_p_bce: 0.3335 - val_loss: 0.3712 - val_true_positive_rate: 0.8566 - val_weighted_bincrossentropy: 0.1654
# Epoch 66/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9799 - dice_coef: 0.6915 - dice_loss: 0.3085 - dice_p_bce: 0.3098 - loss: 0.3640 - true_positive_rate: 0.8241 - weighted_bincrossentropy: 0.1309 - val_binary_accuracy: 0.9751 - val_dice_coef: 0.6841 - val_dice_loss: 0.3159 - val_dice_p_bce: 0.3172 - val_loss: 0.3562 - val_true_positive_rate: 0.8488 - val_weighted_bincrossentropy: 0.1342
# Epoch 67/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9810 - dice_coef: 0.7055 - dice_loss: 0.2945 - dice_p_bce: 0.2958 - loss: 0.3472 - true_positive_rate: 0.8075 - weighted_bincrossentropy: 0.1276 - val_binary_accuracy: 0.9781 - val_dice_coef: 0.6844 - val_dice_loss: 0.3156 - val_dice_p_bce: 0.3177 - val_loss: 0.3529 - val_true_positive_rate: 0.7522 - val_weighted_bincrossentropy: 0.2054
# Epoch 68/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9816 - dice_coef: 0.7081 - dice_loss: 0.2919 - dice_p_bce: 0.2933 - loss: 0.3467 - true_positive_rate: 0.7858 - weighted_bincrossentropy: 0.1435 - val_binary_accuracy: 0.9758 - val_dice_coef: 0.6967 - val_dice_loss: 0.3033 - val_dice_p_bce: 0.3046 - val_loss: 0.3449 - val_true_positive_rate: 0.8543 - val_weighted_bincrossentropy: 0.1295
# Epoch 69/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9821 - dice_coef: 0.7184 - dice_loss: 0.2816 - dice_p_bce: 0.2828 - loss: 0.3387 - true_positive_rate: 0.8096 - weighted_bincrossentropy: 0.1217 - val_binary_accuracy: 0.9784 - val_dice_coef: 0.6949 - val_dice_loss: 0.3051 - val_dice_p_bce: 0.3069 - val_loss: 0.3413 - val_true_positive_rate: 0.7802 - val_weighted_bincrossentropy: 0.1842
# Epoch 70/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9826 - dice_coef: 0.7184 - dice_loss: 0.2816 - dice_p_bce: 0.2830 - loss: 0.3403 - true_positive_rate: 0.7940 - weighted_bincrossentropy: 0.1356 - val_binary_accuracy: 0.9791 - val_dice_coef: 0.6916 - val_dice_loss: 0.3084 - val_dice_p_bce: 0.3102 - val_loss: 0.3420 - val_true_positive_rate: 0.7669 - val_weighted_bincrossentropy: 0.1844
# Epoch 71/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9832 - dice_coef: 0.7185 - dice_loss: 0.2815 - dice_p_bce: 0.2828 - loss: 0.3390 - true_positive_rate: 0.7797 - weighted_bincrossentropy: 0.1337 - val_binary_accuracy: 0.9759 - val_dice_coef: 0.6995 - val_dice_loss: 0.3005 - val_dice_p_bce: 0.3019 - val_loss: 0.3406 - val_true_positive_rate: 0.8573 - val_weighted_bincrossentropy: 0.1410
# Epoch 72/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9819 - dice_coef: 0.7259 - dice_loss: 0.2741 - dice_p_bce: 0.2754 - loss: 0.3299 - true_positive_rate: 0.8226 - weighted_bincrossentropy: 0.1296 - val_binary_accuracy: 0.9794 - val_dice_coef: 0.6957 - val_dice_loss: 0.3043 - val_dice_p_bce: 0.3062 - val_loss: 0.3385 - val_true_positive_rate: 0.7641 - val_weighted_bincrossentropy: 0.1869
# Epoch 73/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9834 - dice_coef: 0.7274 - dice_loss: 0.2726 - dice_p_bce: 0.2740 - loss: 0.3298 - true_positive_rate: 0.7831 - weighted_bincrossentropy: 0.1348 - val_binary_accuracy: 0.9751 - val_dice_coef: 0.6983 - val_dice_loss: 0.3017 - val_dice_p_bce: 0.3030 - val_loss: 0.3445 - val_true_positive_rate: 0.8679 - val_weighted_bincrossentropy: 0.1315
# Epoch 74/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9824 - dice_coef: 0.7252 - dice_loss: 0.2748 - dice_p_bce: 0.2760 - loss: 0.3306 - true_positive_rate: 0.8229 - weighted_bincrossentropy: 0.1231 - val_binary_accuracy: 0.9797 - val_dice_coef: 0.6852 - val_dice_loss: 0.3148 - val_dice_p_bce: 0.3169 - val_loss: 0.3434 - val_true_positive_rate: 0.7522 - val_weighted_bincrossentropy: 0.2031
# Epoch 75/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9827 - dice_coef: 0.7161 - dice_loss: 0.2839 - dice_p_bce: 0.2854 - loss: 0.3347 - true_positive_rate: 0.7883 - weighted_bincrossentropy: 0.1430 - val_binary_accuracy: 0.9766 - val_dice_coef: 0.7065 - val_dice_loss: 0.2935 - val_dice_p_bce: 0.2949 - val_loss: 0.3336 - val_true_positive_rate: 0.8598 - val_weighted_bincrossentropy: 0.1382
# Epoch 76/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9821 - dice_coef: 0.7322 - dice_loss: 0.2678 - dice_p_bce: 0.2690 - loss: 0.3225 - true_positive_rate: 0.8323 - weighted_bincrossentropy: 0.1174 - val_binary_accuracy: 0.9795 - val_dice_coef: 0.7119 - val_dice_loss: 0.2881 - val_dice_p_bce: 0.2896 - val_loss: 0.3244 - val_true_positive_rate: 0.8047 - val_weighted_bincrossentropy: 0.1584
# Epoch 77/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9834 - dice_coef: 0.7362 - dice_loss: 0.2638 - dice_p_bce: 0.2651 - loss: 0.3190 - true_positive_rate: 0.8014 - weighted_bincrossentropy: 0.1277 - val_binary_accuracy: 0.9785 - val_dice_coef: 0.7139 - val_dice_loss: 0.2861 - val_dice_p_bce: 0.2876 - val_loss: 0.3236 - val_true_positive_rate: 0.8397 - val_weighted_bincrossentropy: 0.1459
# Epoch 78/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9827 - dice_coef: 0.7392 - dice_loss: 0.2608 - dice_p_bce: 0.2620 - loss: 0.3144 - true_positive_rate: 0.8295 - weighted_bincrossentropy: 0.1195 - val_binary_accuracy: 0.9801 - val_dice_coef: 0.7066 - val_dice_loss: 0.2934 - val_dice_p_bce: 0.2951 - val_loss: 0.3262 - val_true_positive_rate: 0.7823 - val_weighted_bincrossentropy: 0.1729
# Epoch 79/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9844 - dice_coef: 0.7428 - dice_loss: 0.2572 - dice_p_bce: 0.2584 - loss: 0.3123 - true_positive_rate: 0.8051 - weighted_bincrossentropy: 0.1211 - val_binary_accuracy: 0.9780 - val_dice_coef: 0.7162 - val_dice_loss: 0.2838 - val_dice_p_bce: 0.2851 - val_loss: 0.3230 - val_true_positive_rate: 0.8544 - val_weighted_bincrossentropy: 0.1373
# Epoch 80/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9839 - dice_coef: 0.7471 - dice_loss: 0.2529 - dice_p_bce: 0.2540 - loss: 0.3092 - true_positive_rate: 0.8273 - weighted_bincrossentropy: 0.1154 - val_binary_accuracy: 0.9803 - val_dice_coef: 0.7130 - val_dice_loss: 0.2870 - val_dice_p_bce: 0.2887 - val_loss: 0.3205 - val_true_positive_rate: 0.7909 - val_weighted_bincrossentropy: 0.1685
# Epoch 81/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9848 - dice_coef: 0.7490 - dice_loss: 0.2510 - dice_p_bce: 0.2521 - loss: 0.3062 - true_positive_rate: 0.8139 - weighted_bincrossentropy: 0.1156 - val_binary_accuracy: 0.9794 - val_dice_coef: 0.7248 - val_dice_loss: 0.2752 - val_dice_p_bce: 0.2766 - val_loss: 0.3134 - val_true_positive_rate: 0.8354 - val_weighted_bincrossentropy: 0.1420
# Epoch 82/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9838 - dice_coef: 0.7472 - dice_loss: 0.2528 - dice_p_bce: 0.2539 - loss: 0.3066 - true_positive_rate: 0.8213 - weighted_bincrossentropy: 0.1169 - val_binary_accuracy: 0.9779 - val_dice_coef: 0.7202 - val_dice_loss: 0.2798 - val_dice_p_bce: 0.2811 - val_loss: 0.3197 - val_true_positive_rate: 0.8655 - val_weighted_bincrossentropy: 0.1295
# Epoch 83/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9838 - dice_coef: 0.7413 - dice_loss: 0.2587 - dice_p_bce: 0.2599 - loss: 0.3140 - true_positive_rate: 0.8288 - weighted_bincrossentropy: 0.1159 - val_binary_accuracy: 0.9786 - val_dice_coef: 0.7254 - val_dice_loss: 0.2746 - val_dice_p_bce: 0.2759 - val_loss: 0.3141 - val_true_positive_rate: 0.8595 - val_weighted_bincrossentropy: 0.1308
# Epoch 84/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9842 - dice_coef: 0.7532 - dice_loss: 0.2468 - dice_p_bce: 0.2479 - loss: 0.3009 - true_positive_rate: 0.8358 - weighted_bincrossentropy: 0.1103 - val_binary_accuracy: 0.9801 - val_dice_coef: 0.7309 - val_dice_loss: 0.2691 - val_dice_p_bce: 0.2705 - val_loss: 0.3070 - val_true_positive_rate: 0.8320 - val_weighted_bincrossentropy: 0.1440
# Epoch 85/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9846 - dice_coef: 0.7528 - dice_loss: 0.2472 - dice_p_bce: 0.2483 - loss: 0.3026 - true_positive_rate: 0.8235 - weighted_bincrossentropy: 0.1119 - val_binary_accuracy: 0.9799 - val_dice_coef: 0.7311 - val_dice_loss: 0.2689 - val_dice_p_bce: 0.2704 - val_loss: 0.3072 - val_true_positive_rate: 0.8356 - val_weighted_bincrossentropy: 0.1439
# Epoch 86/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9850 - dice_coef: 0.7604 - dice_loss: 0.2396 - dice_p_bce: 0.2407 - loss: 0.2951 - true_positive_rate: 0.8283 - weighted_bincrossentropy: 0.1112 - val_binary_accuracy: 0.9790 - val_dice_coef: 0.7303 - val_dice_loss: 0.2697 - val_dice_p_bce: 0.2710 - val_loss: 0.3099 - val_true_positive_rate: 0.8582 - val_weighted_bincrossentropy: 0.1319
# Epoch 87/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9845 - dice_coef: 0.7541 - dice_loss: 0.2459 - dice_p_bce: 0.2470 - loss: 0.2992 - true_positive_rate: 0.8317 - weighted_bincrossentropy: 0.1102 - val_binary_accuracy: 0.9766 - val_dice_coef: 0.7220 - val_dice_loss: 0.2780 - val_dice_p_bce: 0.2791 - val_loss: 0.3211 - val_true_positive_rate: 0.8922 - val_weighted_bincrossentropy: 0.1153
# Epoch 88/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9834 - dice_coef: 0.7446 - dice_loss: 0.2554 - dice_p_bce: 0.2565 - loss: 0.3104 - true_positive_rate: 0.8382 - weighted_bincrossentropy: 0.1113 - val_binary_accuracy: 0.9813 - val_dice_coef: 0.7191 - val_dice_loss: 0.2809 - val_dice_p_bce: 0.2826 - val_loss: 0.3118 - val_true_positive_rate: 0.7907 - val_weighted_bincrossentropy: 0.1704
# Epoch 89/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9843 - dice_coef: 0.7508 - dice_loss: 0.2492 - dice_p_bce: 0.2504 - loss: 0.2994 - true_positive_rate: 0.8226 - weighted_bincrossentropy: 0.1195 - val_binary_accuracy: 0.9799 - val_dice_coef: 0.7341 - val_dice_loss: 0.2659 - val_dice_p_bce: 0.2673 - val_loss: 0.3044 - val_true_positive_rate: 0.8445 - val_weighted_bincrossentropy: 0.1406
# Epoch 90/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9845 - dice_coef: 0.7592 - dice_loss: 0.2408 - dice_p_bce: 0.2420 - loss: 0.2947 - true_positive_rate: 0.8286 - weighted_bincrossentropy: 0.1151 - val_binary_accuracy: 0.9812 - val_dice_coef: 0.7228 - val_dice_loss: 0.2772 - val_dice_p_bce: 0.2788 - val_loss: 0.3078 - val_true_positive_rate: 0.8076 - val_weighted_bincrossentropy: 0.1629
# Epoch 91/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9843 - dice_coef: 0.7562 - dice_loss: 0.2438 - dice_p_bce: 0.2450 - loss: 0.2944 - true_positive_rate: 0.8308 - weighted_bincrossentropy: 0.1175 - val_binary_accuracy: 0.9799 - val_dice_coef: 0.7383 - val_dice_loss: 0.2617 - val_dice_p_bce: 0.2630 - val_loss: 0.3006 - val_true_positive_rate: 0.8547 - val_weighted_bincrossentropy: 0.1336
# Epoch 92/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9853 - dice_coef: 0.7643 - dice_loss: 0.2357 - dice_p_bce: 0.2368 - loss: 0.2911 - true_positive_rate: 0.8295 - weighted_bincrossentropy: 0.1106 - val_binary_accuracy: 0.9815 - val_dice_coef: 0.7394 - val_dice_loss: 0.2606 - val_dice_p_bce: 0.2622 - val_loss: 0.2979 - val_true_positive_rate: 0.8053 - val_weighted_bincrossentropy: 0.1568
# Epoch 93/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9853 - dice_coef: 0.7668 - dice_loss: 0.2332 - dice_p_bce: 0.2343 - loss: 0.2871 - true_positive_rate: 0.8243 - weighted_bincrossentropy: 0.1113 - val_binary_accuracy: 0.9799 - val_dice_coef: 0.7388 - val_dice_loss: 0.2612 - val_dice_p_bce: 0.2625 - val_loss: 0.3006 - val_true_positive_rate: 0.8536 - val_weighted_bincrossentropy: 0.1336
# Epoch 94/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9856 - dice_coef: 0.7683 - dice_loss: 0.2317 - dice_p_bce: 0.2328 - loss: 0.2851 - true_positive_rate: 0.8361 - weighted_bincrossentropy: 0.1108 - val_binary_accuracy: 0.9816 - val_dice_coef: 0.7405 - val_dice_loss: 0.2595 - val_dice_p_bce: 0.2610 - val_loss: 0.2952 - val_true_positive_rate: 0.8158 - val_weighted_bincrossentropy: 0.1551
# Epoch 95/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9855 - dice_coef: 0.7724 - dice_loss: 0.2276 - dice_p_bce: 0.2287 - loss: 0.2812 - true_positive_rate: 0.8260 - weighted_bincrossentropy: 0.1118 - val_binary_accuracy: 0.9811 - val_dice_coef: 0.7428 - val_dice_loss: 0.2572 - val_dice_p_bce: 0.2587 - val_loss: 0.2942 - val_true_positive_rate: 0.8324 - val_weighted_bincrossentropy: 0.1496
# Epoch 96/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9861 - dice_coef: 0.7719 - dice_loss: 0.2281 - dice_p_bce: 0.2292 - loss: 0.2832 - true_positive_rate: 0.8315 - weighted_bincrossentropy: 0.1108 - val_binary_accuracy: 0.9816 - val_dice_coef: 0.7437 - val_dice_loss: 0.2563 - val_dice_p_bce: 0.2578 - val_loss: 0.2917 - val_true_positive_rate: 0.8300 - val_weighted_bincrossentropy: 0.1489
# Epoch 97/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9860 - dice_coef: 0.7716 - dice_loss: 0.2284 - dice_p_bce: 0.2294 - loss: 0.2838 - true_positive_rate: 0.8333 - weighted_bincrossentropy: 0.1027 - val_binary_accuracy: 0.9818 - val_dice_coef: 0.7176 - val_dice_loss: 0.2824 - val_dice_p_bce: 0.2846 - val_loss: 0.3163 - val_true_positive_rate: 0.7340 - val_weighted_bincrossentropy: 0.2211
# Epoch 98/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9858 - dice_coef: 0.7653 - dice_loss: 0.2347 - dice_p_bce: 0.2359 - loss: 0.2872 - true_positive_rate: 0.8068 - weighted_bincrossentropy: 0.1199 - val_binary_accuracy: 0.9804 - val_dice_coef: 0.7441 - val_dice_loss: 0.2559 - val_dice_p_bce: 0.2571 - val_loss: 0.2937 - val_true_positive_rate: 0.8627 - val_weighted_bincrossentropy: 0.1281
# Epoch 99/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9853 - dice_coef: 0.7679 - dice_loss: 0.2321 - dice_p_bce: 0.2332 - loss: 0.2830 - true_positive_rate: 0.8394 - weighted_bincrossentropy: 0.1075 - val_binary_accuracy: 0.9806 - val_dice_coef: 0.7469 - val_dice_loss: 0.2531 - val_dice_p_bce: 0.2544 - val_loss: 0.2922 - val_true_positive_rate: 0.8587 - val_weighted_bincrossentropy: 0.1298
# Epoch 100/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9851 - dice_coef: 0.7609 - dice_loss: 0.2391 - dice_p_bce: 0.2402 - loss: 0.2934 - true_positive_rate: 0.8394 - weighted_bincrossentropy: 0.1074 - val_binary_accuracy: 0.9805 - val_dice_coef: 0.7349 - val_dice_loss: 0.2651 - val_dice_p_bce: 0.2665 - val_loss: 0.2984 - val_true_positive_rate: 0.8529 - val_weighted_bincrossentropy: 0.1432
# Epoch 101/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9846 - dice_coef: 0.7603 - dice_loss: 0.2397 - dice_p_bce: 0.2410 - loss: 0.2915 - true_positive_rate: 0.8233 - weighted_bincrossentropy: 0.1292 - val_binary_accuracy: 0.9822 - val_dice_coef: 0.7306 - val_dice_loss: 0.2694 - val_dice_p_bce: 0.2710 - val_loss: 0.3009 - val_true_positive_rate: 0.7894 - val_weighted_bincrossentropy: 0.1641
# Epoch 102/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9861 - dice_coef: 0.7637 - dice_loss: 0.2363 - dice_p_bce: 0.2374 - loss: 0.2868 - true_positive_rate: 0.8078 - weighted_bincrossentropy: 0.1120 - val_binary_accuracy: 0.9820 - val_dice_coef: 0.7410 - val_dice_loss: 0.2590 - val_dice_p_bce: 0.2608 - val_loss: 0.2948 - val_true_positive_rate: 0.7943 - val_weighted_bincrossentropy: 0.1841
# Epoch 103/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9861 - dice_coef: 0.7709 - dice_loss: 0.2291 - dice_p_bce: 0.2303 - loss: 0.2841 - true_positive_rate: 0.8220 - weighted_bincrossentropy: 0.1165 - val_binary_accuracy: 0.9791 - val_dice_coef: 0.7450 - val_dice_loss: 0.2550 - val_dice_p_bce: 0.2561 - val_loss: 0.2970 - val_true_positive_rate: 0.8908 - val_weighted_bincrossentropy: 0.1103
# Epoch 104/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9853 - dice_coef: 0.7670 - dice_loss: 0.2330 - dice_p_bce: 0.2340 - loss: 0.2861 - true_positive_rate: 0.8529 - weighted_bincrossentropy: 0.1016 - val_binary_accuracy: 0.9820 - val_dice_coef: 0.7554 - val_dice_loss: 0.2446 - val_dice_p_bce: 0.2461 - val_loss: 0.2823 - val_true_positive_rate: 0.8343 - val_weighted_bincrossentropy: 0.1446
# Epoch 105/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9858 - dice_coef: 0.7765 - dice_loss: 0.2235 - dice_p_bce: 0.2247 - loss: 0.2739 - true_positive_rate: 0.8317 - weighted_bincrossentropy: 0.1136 - val_binary_accuracy: 0.9827 - val_dice_coef: 0.7426 - val_dice_loss: 0.2574 - val_dice_p_bce: 0.2591 - val_loss: 0.2904 - val_true_positive_rate: 0.7907 - val_weighted_bincrossentropy: 0.1717
# Epoch 106/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9857 - dice_coef: 0.7738 - dice_loss: 0.2262 - dice_p_bce: 0.2274 - loss: 0.2764 - true_positive_rate: 0.8274 - weighted_bincrossentropy: 0.1199 - val_binary_accuracy: 0.9816 - val_dice_coef: 0.7561 - val_dice_loss: 0.2439 - val_dice_p_bce: 0.2453 - val_loss: 0.2816 - val_true_positive_rate: 0.8524 - val_weighted_bincrossentropy: 0.1404
# Epoch 107/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9857 - dice_coef: 0.7810 - dice_loss: 0.2190 - dice_p_bce: 0.2201 - loss: 0.2696 - true_positive_rate: 0.8522 - weighted_bincrossentropy: 0.1054 - val_binary_accuracy: 0.9825 - val_dice_coef: 0.7588 - val_dice_loss: 0.2412 - val_dice_p_bce: 0.2427 - val_loss: 0.2782 - val_true_positive_rate: 0.8320 - val_weighted_bincrossentropy: 0.1455
# Epoch 108/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9870 - dice_coef: 0.7871 - dice_loss: 0.2129 - dice_p_bce: 0.2140 - loss: 0.2647 - true_positive_rate: 0.8357 - weighted_bincrossentropy: 0.1070 - val_binary_accuracy: 0.9826 - val_dice_coef: 0.7572 - val_dice_loss: 0.2428 - val_dice_p_bce: 0.2443 - val_loss: 0.2784 - val_true_positive_rate: 0.8309 - val_weighted_bincrossentropy: 0.1515
# Epoch 109/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9870 - dice_coef: 0.7894 - dice_loss: 0.2106 - dice_p_bce: 0.2116 - loss: 0.2613 - true_positive_rate: 0.8484 - weighted_bincrossentropy: 0.0994 - val_binary_accuracy: 0.9824 - val_dice_coef: 0.7580 - val_dice_loss: 0.2420 - val_dice_p_bce: 0.2435 - val_loss: 0.2777 - val_true_positive_rate: 0.8389 - val_weighted_bincrossentropy: 0.1494
# Epoch 110/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9864 - dice_coef: 0.7865 - dice_loss: 0.2135 - dice_p_bce: 0.2147 - loss: 0.2642 - true_positive_rate: 0.8370 - weighted_bincrossentropy: 0.1148 - val_binary_accuracy: 0.9822 - val_dice_coef: 0.7628 - val_dice_loss: 0.2372 - val_dice_p_bce: 0.2386 - val_loss: 0.2753 - val_true_positive_rate: 0.8501 - val_weighted_bincrossentropy: 0.1360
# Epoch 111/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9873 - dice_coef: 0.7927 - dice_loss: 0.2073 - dice_p_bce: 0.2083 - loss: 0.2579 - true_positive_rate: 0.8531 - weighted_bincrossentropy: 0.0976 - val_binary_accuracy: 0.9827 - val_dice_coef: 0.7595 - val_dice_loss: 0.2405 - val_dice_p_bce: 0.2421 - val_loss: 0.2757 - val_true_positive_rate: 0.8327 - val_weighted_bincrossentropy: 0.1544
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9875 - dice_coef: 0.7911 - dice_loss: 0.2089 - dice_p_bce: 0.2100 - loss: 0.2609 - true_positive_rate: 0.8401 - weighted_bincrossentropy: 0.1043 - val_binary_accuracy: 0.9821 - val_dice_coef: 0.7613 - val_dice_loss: 0.2387 - val_dice_p_bce: 0.2401 - val_loss: 0.2757 - val_true_positive_rate: 0.8576 - val_weighted_bincrossentropy: 0.1368
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9864 - dice_coef: 0.7907 - dice_loss: 0.2093 - dice_p_bce: 0.2104 - loss: 0.2602 - true_positive_rate: 0.8482 - weighted_bincrossentropy: 0.1085 - val_binary_accuracy: 0.9830 - val_dice_coef: 0.7593 - val_dice_loss: 0.2407 - val_dice_p_bce: 0.2423 - val_loss: 0.2753 - val_true_positive_rate: 0.8257 - val_weighted_bincrossentropy: 0.1557
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9873 - dice_coef: 0.7920 - dice_loss: 0.2080 - dice_p_bce: 0.2091 - loss: 0.2593 - true_positive_rate: 0.8386 - weighted_bincrossentropy: 0.1077 - val_binary_accuracy: 0.9822 - val_dice_coef: 0.7633 - val_dice_loss: 0.2367 - val_dice_p_bce: 0.2381 - val_loss: 0.2738 - val_true_positive_rate: 0.8570 - val_weighted_bincrossentropy: 0.1394
# Epoch 115/500
# ...
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9934 - dice_coef: 0.8951 - dice_loss: 0.1049 - dice_p_bce: 0.1058 - loss: 0.1375 - true_positive_rate: 0.9142 - weighted_bincrossentropy: 0.0903 - val_binary_accuracy: 0.9864 - val_dice_coef: 0.8301 - val_dice_loss: 0.1699 - val_dice_p_bce: 0.1716 - val_loss: 0.2079 - val_true_positive_rate: 0.8735 - val_weighted_bincrossentropy: 0.1696
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9937 - dice_coef: 0.8978 - dice_loss: 0.1022 - dice_p_bce: 0.1031 - loss: 0.1350 - true_positive_rate: 0.9168 - weighted_bincrossentropy: 0.0861 - val_binary_accuracy: 0.9869 - val_dice_coef: 0.8300 - val_dice_loss: 0.1700 - val_dice_p_bce: 0.1718 - val_loss: 0.2058 - val_true_positive_rate: 0.8638 - val_weighted_bincrossentropy: 0.1775
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9937 - dice_coef: 0.8973 - dice_loss: 0.1027 - dice_p_bce: 0.1035 - loss: 0.1349 - true_positive_rate: 0.9154 - weighted_bincrossentropy: 0.0876 - val_binary_accuracy: 0.9862 - val_dice_coef: 0.8294 - val_dice_loss: 0.1706 - val_dice_p_bce: 0.1722 - val_loss: 0.2089 - val_true_positive_rate: 0.8793 - val_weighted_bincrossentropy: 0.1650
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9933 - dice_coef: 0.8949 - dice_loss: 0.1051 - dice_p_bce: 0.1060 - loss: 0.1381 - true_positive_rate: 0.9180 - weighted_bincrossentropy: 0.0893 - val_binary_accuracy: 0.9874 - val_dice_coef: 0.8306 - val_dice_loss: 0.1694 - val_dice_p_bce: 0.1712 - val_loss: 0.2032 - val_true_positive_rate: 0.8604 - val_weighted_bincrossentropy: 0.1813
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8960 - dice_loss: 0.1040 - dice_p_bce: 0.1049 - loss: 0.1369 - true_positive_rate: 0.9106 - weighted_bincrossentropy: 0.0896 - val_binary_accuracy: 0.9865 - val_dice_coef: 0.8294 - val_dice_loss: 0.1706 - val_dice_p_bce: 0.1723 - val_loss: 0.2084 - val_true_positive_rate: 0.8687 - val_weighted_bincrossentropy: 0.1746
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8973 - dice_loss: 0.1027 - dice_p_bce: 0.1035 - loss: 0.1355 - true_positive_rate: 0.9152 - weighted_bincrossentropy: 0.0863 - val_binary_accuracy: 0.9867 - val_dice_coef: 0.8297 - val_dice_loss: 0.1703 - val_dice_p_bce: 0.1720 - val_loss: 0.2069 - val_true_positive_rate: 0.8676 - val_weighted_bincrossentropy: 0.1764
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8959 - dice_loss: 0.1041 - dice_p_bce: 0.1050 - loss: 0.1381 - true_positive_rate: 0.9102 - weighted_bincrossentropy: 0.0900 - val_binary_accuracy: 0.9863 - val_dice_coef: 0.8290 - val_dice_loss: 0.1710 - val_dice_p_bce: 0.1728 - val_loss: 0.2093 - val_true_positive_rate: 0.8674 - val_weighted_bincrossentropy: 0.1771
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9935 - dice_coef: 0.8960 - dice_loss: 0.1040 - dice_p_bce: 0.1049 - loss: 0.1363 - true_positive_rate: 0.9161 - weighted_bincrossentropy: 0.0889 - val_binary_accuracy: 0.9856 - val_dice_coef: 0.8270 - val_dice_loss: 0.1730 - val_dice_p_bce: 0.1746 - val_loss: 0.2128 - val_true_positive_rate: 0.8891 - val_weighted_bincrossentropy: 0.1596
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9937 - dice_coef: 0.8951 - dice_loss: 0.1049 - dice_p_bce: 0.1058 - loss: 0.1385 - true_positive_rate: 0.9174 - weighted_bincrossentropy: 0.0844 - val_binary_accuracy: 0.9867 - val_dice_coef: 0.8306 - val_dice_loss: 0.1694 - val_dice_p_bce: 0.1711 - val_loss: 0.2058 - val_true_positive_rate: 0.8714 - val_weighted_bincrossentropy: 0.1720
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9936 - dice_coef: 0.8939 - dice_loss: 0.1061 - dice_p_bce: 0.1070 - loss: 0.1396 - true_positive_rate: 0.9109 - weighted_bincrossentropy: 0.0908 - val_binary_accuracy: 0.9870 - val_dice_coef: 0.8300 - val_dice_loss: 0.1700 - val_dice_p_bce: 0.1718 - val_loss: 0.2054 - val_true_positive_rate: 0.8641 - val_weighted_bincrossentropy: 0.1781
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9936 - dice_coef: 0.8971 - dice_loss: 0.1029 - dice_p_bce: 0.1038 - loss: 0.1347 - true_positive_rate: 0.9154 - weighted_bincrossentropy: 0.0892 - val_binary_accuracy: 0.9863 - val_dice_coef: 0.8297 - val_dice_loss: 0.1703 - val_dice_p_bce: 0.1721 - val_loss: 0.2089 - val_true_positive_rate: 0.8671 - val_weighted_bincrossentropy: 0.1789
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9936 - dice_coef: 0.8979 - dice_loss: 0.1021 - dice_p_bce: 0.1030 - loss: 0.1346 - true_positive_rate: 0.9171 - weighted_bincrossentropy: 0.0892 - val_binary_accuracy: 0.9864 - val_dice_coef: 0.8299 - val_dice_loss: 0.1701 - val_dice_p_bce: 0.1718 - val_loss: 0.2077 - val_true_positive_rate: 0.8784 - val_weighted_bincrossentropy: 0.1674
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8987 - dice_loss: 0.1013 - dice_p_bce: 0.1021 - loss: 0.1339 - true_positive_rate: 0.9186 - weighted_bincrossentropy: 0.0855 - val_binary_accuracy: 0.9871 - val_dice_coef: 0.8288 - val_dice_loss: 0.1712 - val_dice_p_bce: 0.1731 - val_loss: 0.2063 - val_true_positive_rate: 0.8551 - val_weighted_bincrossentropy: 0.1890
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9933 - dice_coef: 0.8957 - dice_loss: 0.1043 - dice_p_bce: 0.1052 - loss: 0.1362 - true_positive_rate: 0.9137 - weighted_bincrossentropy: 0.0919 - val_binary_accuracy: 0.9858 - val_dice_coef: 0.8284 - val_dice_loss: 0.1716 - val_dice_p_bce: 0.1732 - val_loss: 0.2114 - val_true_positive_rate: 0.8839 - val_weighted_bincrossentropy: 0.1643
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8954 - dice_loss: 0.1046 - dice_p_bce: 0.1055 - loss: 0.1383 - true_positive_rate: 0.9178 - weighted_bincrossentropy: 0.0852 - val_binary_accuracy: 0.9868 - val_dice_coef: 0.8304 - val_dice_loss: 0.1696 - val_dice_p_bce: 0.1714 - val_loss: 0.2059 - val_true_positive_rate: 0.8668 - val_weighted_bincrossentropy: 0.1777
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9937 - dice_coef: 0.8957 - dice_loss: 0.1043 - dice_p_bce: 0.1053 - loss: 0.1375 - true_positive_rate: 0.9130 - weighted_bincrossentropy: 0.0904 - val_binary_accuracy: 0.9868 - val_dice_coef: 0.8294 - val_dice_loss: 0.1706 - val_dice_p_bce: 0.1724 - val_loss: 0.2070 - val_true_positive_rate: 0.8602 - val_weighted_bincrossentropy: 0.1822
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8984 - dice_loss: 0.1016 - dice_p_bce: 0.1025 - loss: 0.1338 - true_positive_rate: 0.9133 - weighted_bincrossentropy: 0.0888 - val_binary_accuracy: 0.9864 - val_dice_coef: 0.8309 - val_dice_loss: 0.1691 - val_dice_p_bce: 0.1708 - val_loss: 0.2071 - val_true_positive_rate: 0.8735 - val_weighted_bincrossentropy: 0.1720
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8996 - dice_loss: 0.1004 - dice_p_bce: 0.1012 - loss: 0.1318 - true_positive_rate: 0.9191 - weighted_bincrossentropy: 0.0864 - val_binary_accuracy: 0.9870 - val_dice_coef: 0.8313 - val_dice_loss: 0.1687 - val_dice_p_bce: 0.1704 - val_loss: 0.2040 - val_true_positive_rate: 0.8716 - val_weighted_bincrossentropy: 0.1739
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9938 - dice_coef: 0.8977 - dice_loss: 0.1023 - dice_p_bce: 0.1032 - loss: 0.1351 - true_positive_rate: 0.9157 - weighted_bincrossentropy: 0.0904 - val_binary_accuracy: 0.9863 - val_dice_coef: 0.8301 - val_dice_loss: 0.1699 - val_dice_p_bce: 0.1716 - val_loss: 0.2086 - val_true_positive_rate: 0.8705 - val_weighted_bincrossentropy: 0.1768
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9940 - dice_coef: 0.9005 - dice_loss: 0.0995 - dice_p_bce: 0.1003 - loss: 0.1311 - true_positive_rate: 0.9192 - weighted_bincrossentropy: 0.0863 - val_binary_accuracy: 0.9869 - val_dice_coef: 0.8295 - val_dice_loss: 0.1705 - val_dice_p_bce: 0.1723 - val_loss: 0.2064 - val_true_positive_rate: 0.8596 - val_weighted_bincrossentropy: 0.1872
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9936 - dice_coef: 0.8982 - dice_loss: 0.1018 - dice_p_bce: 0.1028 - loss: 0.1339 - true_positive_rate: 0.9153 - weighted_bincrossentropy: 0.0933 - val_binary_accuracy: 0.9861 - val_dice_coef: 0.8300 - val_dice_loss: 0.1700 - val_dice_p_bce: 0.1717 - val_loss: 0.2091 - val_true_positive_rate: 0.8807 - val_weighted_bincrossentropy: 0.1682
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8982 - dice_loss: 0.1018 - dice_p_bce: 0.1027 - loss: 0.1352 - true_positive_rate: 0.9162 - weighted_bincrossentropy: 0.0878 - val_binary_accuracy: 0.9873 - val_dice_coef: 0.8299 - val_dice_loss: 0.1701 - val_dice_p_bce: 0.1720 - val_loss: 0.2047 - val_true_positive_rate: 0.8550 - val_weighted_bincrossentropy: 0.1909
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9936 - dice_coef: 0.8975 - dice_loss: 0.1025 - dice_p_bce: 0.1034 - loss: 0.1346 - true_positive_rate: 0.9151 - weighted_bincrossentropy: 0.0927 - val_binary_accuracy: 0.9859 - val_dice_coef: 0.8302 - val_dice_loss: 0.1698 - val_dice_p_bce: 0.1715 - val_loss: 0.2100 - val_true_positive_rate: 0.8771 - val_weighted_bincrossentropy: 0.1729
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9937 - dice_coef: 0.8961 - dice_loss: 0.1039 - dice_p_bce: 0.1048 - loss: 0.1371 - true_positive_rate: 0.9134 - weighted_bincrossentropy: 0.0914 - val_binary_accuracy: 0.9865 - val_dice_coef: 0.8261 - val_dice_loss: 0.1739 - val_dice_p_bce: 0.1760 - val_loss: 0.2120 - val_true_positive_rate: 0.8451 - val_weighted_bincrossentropy: 0.2013
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9933 - dice_coef: 0.8896 - dice_loss: 0.1104 - dice_p_bce: 0.1114 - loss: 0.1446 - true_positive_rate: 0.9007 - weighted_bincrossentropy: 0.0946 - val_binary_accuracy: 0.9875 - val_dice_coef: 0.8273 - val_dice_loss: 0.1727 - val_dice_p_bce: 0.1746 - val_loss: 0.2059 - val_true_positive_rate: 0.8451 - val_weighted_bincrossentropy: 0.1988
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9930 - dice_coef: 0.8869 - dice_loss: 0.1131 - dice_p_bce: 0.1140 - loss: 0.1487 - true_positive_rate: 0.9064 - weighted_bincrossentropy: 0.0919 - val_binary_accuracy: 0.9875 - val_dice_coef: 0.8297 - val_dice_loss: 0.1703 - val_dice_p_bce: 0.1722 - val_loss: 0.2034 - val_true_positive_rate: 0.8532 - val_weighted_bincrossentropy: 0.1894
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9929 - dice_coef: 0.8897 - dice_loss: 0.1103 - dice_p_bce: 0.1113 - loss: 0.1433 - true_positive_rate: 0.9100 - weighted_bincrossentropy: 0.0934 - val_binary_accuracy: 0.9873 - val_dice_coef: 0.8312 - val_dice_loss: 0.1688 - val_dice_p_bce: 0.1706 - val_loss: 0.2028 - val_true_positive_rate: 0.8677 - val_weighted_bincrossentropy: 0.1766
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9932 - dice_coef: 0.8945 - dice_loss: 0.1055 - dice_p_bce: 0.1064 - loss: 0.1382 - true_positive_rate: 0.9145 - weighted_bincrossentropy: 0.0922 - val_binary_accuracy: 0.9863 - val_dice_coef: 0.8281 - val_dice_loss: 0.1719 - val_dice_p_bce: 0.1738 - val_loss: 0.2115 - val_true_positive_rate: 0.8546 - val_weighted_bincrossentropy: 0.1899
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9933 - dice_coef: 0.8901 - dice_loss: 0.1099 - dice_p_bce: 0.1108 - loss: 0.1436 - true_positive_rate: 0.9029 - weighted_bincrossentropy: 0.0935 - val_binary_accuracy: 0.9866 - val_dice_coef: 0.8279 - val_dice_loss: 0.1721 - val_dice_p_bce: 0.1740 - val_loss: 0.2094 - val_true_positive_rate: 0.8551 - val_weighted_bincrossentropy: 0.1905
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9932 - dice_coef: 0.8931 - dice_loss: 0.1069 - dice_p_bce: 0.1078 - loss: 0.1391 - true_positive_rate: 0.9119 - weighted_bincrossentropy: 0.0920 - val_binary_accuracy: 0.9873 - val_dice_coef: 0.8330 - val_dice_loss: 0.1670 - val_dice_p_bce: 0.1687 - val_loss: 0.2009 - val_true_positive_rate: 0.8767 - val_weighted_bincrossentropy: 0.1664
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9932 - dice_coef: 0.8932 - dice_loss: 0.1068 - dice_p_bce: 0.1076 - loss: 0.1397 - true_positive_rate: 0.9170 - weighted_bincrossentropy: 0.0890 - val_binary_accuracy: 0.9853 - val_dice_coef: 0.8282 - val_dice_loss: 0.1718 - val_dice_p_bce: 0.1733 - val_loss: 0.2127 - val_true_positive_rate: 0.8959 - val_weighted_bincrossentropy: 0.1524
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9935 - dice_coef: 0.8927 - dice_loss: 0.1073 - dice_p_bce: 0.1081 - loss: 0.1416 - true_positive_rate: 0.9173 - weighted_bincrossentropy: 0.0853 - val_binary_accuracy: 0.9873 - val_dice_coef: 0.8334 - val_dice_loss: 0.1666 - val_dice_p_bce: 0.1684 - val_loss: 0.2014 - val_true_positive_rate: 0.8670 - val_weighted_bincrossentropy: 0.1746
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9937 - dice_coef: 0.8976 - dice_loss: 0.1024 - dice_p_bce: 0.1033 - loss: 0.1344 - true_positive_rate: 0.9125 - weighted_bincrossentropy: 0.0895 - val_binary_accuracy: 0.9866 - val_dice_coef: 0.8313 - val_dice_loss: 0.1687 - val_dice_p_bce: 0.1705 - val_loss: 0.2060 - val_true_positive_rate: 0.8689 - val_weighted_bincrossentropy: 0.1760
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9935 - dice_coef: 0.8977 - dice_loss: 0.1023 - dice_p_bce: 0.1032 - loss: 0.1345 - true_positive_rate: 0.9163 - weighted_bincrossentropy: 0.0905 - val_binary_accuracy: 0.9869 - val_dice_coef: 0.8317 - val_dice_loss: 0.1683 - val_dice_p_bce: 0.1700 - val_loss: 0.2039 - val_true_positive_rate: 0.8742 - val_weighted_bincrossentropy: 0.1701
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9936 - dice_coef: 0.8992 - dice_loss: 0.1008 - dice_p_bce: 0.1017 - loss: 0.1331 - true_positive_rate: 0.9181 - weighted_bincrossentropy: 0.0889 - val_binary_accuracy: 0.9870 - val_dice_coef: 0.8319 - val_dice_loss: 0.1681 - val_dice_p_bce: 0.1698 - val_loss: 0.2037 - val_true_positive_rate: 0.8690 - val_weighted_bincrossentropy: 0.1744
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9939 - dice_coef: 0.8996 - dice_loss: 0.1004 - dice_p_bce: 0.1013 - loss: 0.1330 - true_positive_rate: 0.9155 - weighted_bincrossentropy: 0.0879 - val_binary_accuracy: 0.9872 - val_dice_coef: 0.8319 - val_dice_loss: 0.1681 - val_dice_p_bce: 0.1699 - val_loss: 0.2028 - val_true_positive_rate: 0.8657 - val_weighted_bincrossentropy: 0.1787
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - binary_accuracy: 0.9941 - dice_coef: 0.8995 - dice_loss: 0.1005 - dice_p_bce: 0.1014 - loss: 0.1332 - true_positive_rate: 0.9139 - weighted_bincrossentropy: 0.0880 - val_binary_accuracy: 0.9872 - val_dice_coef: 0.8326 - val_dice_loss: 0.1674 - val_dice_p_bce: 0.1691 - val_loss: 0.2020 - val_true_positive_rate: 0.8702 - val_weighted_bincrossentropy: 0.1756
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - binary_accuracy: 0.9940 - dice_coef: 0.9019 - dice_loss: 0.0981 - dice_p_bce: 0.0990 - loss: 0.1302 - true_positive_rate: 0.9194 - weighted_bincrossentropy: 0.0866 - val_binary_accuracy: 0.9870 - val_dice_coef: 0.8321 - val_dice_loss: 0.1679 - val_dice_p_bce: 0.1696 - val_loss: 0.2035 - val_true_positive_rate: 0.8715 - val_weighted_bincrossentropy: 0.1750

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('model dice coefficent')
plt.ylabel('dice coef')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# print("Max acc:", round(max(history.history['acc']),4))
# print("Max val_acc:", round(max(history.history['val_acc']),4))
# print("\nMin loss:", round(min(history.history['loss']),4))
# print("Min val_loss:", round(min(history.history['val_loss']),4))

# %% [markdown]
# ## Testing the model

# %%
## Save the Weights

#model.save_weights("UNetW.h5")

# %%
## Dataset for prediction
x, y = valid_gen.__getitem__(0)
result = model.predict(x)

result = result > 0.5
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)

r = random.randint(0, len(x)-1)


ax = fig.add_subplot(1, 2, 1)
ax.imshow(np.reshape(y[r]*255, (dim, dim)), cmap="gray")

ax = fig.add_subplot(1, 2, 2)
ax.imshow(np.reshape(result[r]*255, (dim, dim)), cmap="gray")

# %%
fig, axes = plt.subplots(ncols = 3, )

fig.set_figwidth(3.6)
fig.set_figheight(2)


axes[0].imshow(x[0])
axes[0].set_xlabel('Raw Image')
axes[1].imshow(np.reshape(y[0]*255, (dim, dim)), cmap="gray")
axes[1].set_xlabel('Ground Truth')
axes[2].imshow(np.reshape(result[0]*255, (dim, dim)), cmap="gray")
axes[2].set_xlabel('Prediction')

matplotlib.rcParams.update({'font.size': 12, "font.family": "Times New Roman"})

for i, ax in enumerate(axes):
    axes[i].tick_params(
        axis='both',          # changes apply to the voth axis
        which='both', 
        left = False,   # both major and minor ticks are affected
        right = False,
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False) # labels along the bottom edge are off
    
    axes[i].xaxis.set_ticklabels([])
    axes[i].yaxis.set_ticklabels([])

    for j in ax.spines:
        axes[i].spines[j].set_visible(False)
        
    plt.savefig(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_example.pdf', dpi =300)

# %% [markdown]
# ## Save Model

# %%
import json

# %%
# !mkdir saved_models
# model.save(r'C:\Users\thoma\Desktop\CT_Segment_Full_v2.h5')




model.save(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}.keras')


save_dict = {'History': history.history, 'Loss Function': use_loss.__name__, 'Learning Rate': learning_rate, 'Num Training Images': len(train_imgs), 'Num Test Images': len(test_imgs), 'Batch Size': batch_size}

with open(rf'C:\Users\chloe\DE4\Masters\Models\Model_{model_num}_history.json', 'w') as f:
    json.dump(save_dict, f)

# %%
# with open(r'C:\Users\chloe\DE4\Masters\Models\Model_3_history.pkl', 'r') as f:
#     hist = json.load(f)

# print(len(hist['History']['binary_accuray']))
